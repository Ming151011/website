# %%
from scipy import special
import numpy as np
import matplotlib.pyplot as plt

# %%
t= np.linspace(-4,4,1000000);
print("erfc(h) =",special.erfc( np.sqrt(2) *t));
y= 0.5 * special.erfc(np.sqrt(2) *t);
plt.plot(t,y)
# Out:
# erfc(h) = [2.00000000e+00 2.00000000e+00 2.00000000e+00 ... 1.24451550e-15
#  1.24435380e-15 1.24419211e-15]
