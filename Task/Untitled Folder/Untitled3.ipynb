# %%
import meep as mp
import numpy
import matplotlib.pyplot as plt

res = 25  # pixels/μm
three_d = False  # 3d calculation?
d = 0.30  # branch separation

gdsII_file = "coupler.gds"
CELL_LAYER = 0
PORT1_LAYER = 1
PORT2_LAYER = 2
PORT3_LAYER = 3
PORT4_LAYER = 4
SOURCE_LAYER = 5
UPPER_BRANCH_LAYER = 31
LOWER_BRANCH_LAYER = 32
default_d = 0.3

t_oxide = 1.0
t_Si = 0.22
t_air = 0.78

dpml = 1
cell_thickness = dpml + t_oxide + t_Si + t_air + dpml

oxide = mp.Medium(epsilon=2.25)
silicon = mp.Medium(epsilon=12)

lcen = 1.55
fcen = 1 / lcen
df = 0.2 * fcen

cell_zmax = 0.5 * cell_thickness if three_d else 0
cell_zmin = -0.5 * cell_thickness if three_d else 0
si_zmax = 0.5 * t_Si if three_d else 10
si_zmin = -0.5 * t_Si if three_d else -10

# read cell size, volumes for source region and flux monitors,
# and coupler geometry from GDSII file
upper_branch = mp.get_GDSII_prisms(
    silicon, gdsII_file, UPPER_BRANCH_LAYER, si_zmin, si_zmax
)
lower_branch = mp.get_GDSII_prisms(
    silicon, gdsII_file, LOWER_BRANCH_LAYER, si_zmin, si_zmax
)

cell = mp.GDSII_vol(gdsII_file, CELL_LAYER, cell_zmin, cell_zmax)
p1 = mp.GDSII_vol(gdsII_file, PORT1_LAYER, si_zmin, si_zmax)
p2 = mp.GDSII_vol(gdsII_file, PORT2_LAYER, si_zmin, si_zmax)
p3 = mp.GDSII_vol(gdsII_file, PORT3_LAYER, si_zmin, si_zmax)
p4 = mp.GDSII_vol(gdsII_file, PORT4_LAYER, si_zmin, si_zmax)
src_vol = mp.GDSII_vol(gdsII_file, SOURCE_LAYER, si_zmin, si_zmax)

# displace upper and lower branches of coupler (as well as source and flux regions)
if d != default_d:
    delta_y = 0.5 * (d - default_d)
    delta = mp.Vector3(y=delta_y)
    p1.center += delta
    p2.center -= delta
    p3.center += delta
    p4.center -= delta
    src_vol.center += delta
    cell.size += 2 * delta
    for np in range(len(lower_branch)):
        lower_branch[np].center -= delta
        for nv in range(len(lower_branch[np].vertices)):
            lower_branch[np].vertices[nv] -= delta
    for np in range(len(upper_branch)):
        upper_branch[np].center += delta
        for nv in range(len(upper_branch[np].vertices)):
            upper_branch[np].vertices[nv] += delta

geometry = upper_branch + lower_branch

if three_d:
    oxide_center = mp.Vector3(z=-0.5 * t_oxide)
    oxide_size = mp.Vector3(cell.size.x, cell.size.y, t_oxide)
    oxide_layer = [mp.Block(material=oxide, center=oxide_center, size=oxide_size)]
    geometry = geometry + oxide_layer

sources = [
    mp.EigenModeSource(
        src=mp.GaussianSource(fcen, fwidth=df),
        size=src_vol.size,
        center=src_vol.center,
        eig_band=1,
        eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z,
        eig_match_freq=True,
    )
]

sim = mp.Simulation(
    resolution=res,
    cell_size=cell.size,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
    geometry=geometry,
)

mode1 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p1))
mode2 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p2))
mode3 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p3))
mode4 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p4))

sim.run(until_after_sources=100)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0193701 s
# Working in 2D dimensions.
# Computational cell is 34.4 x 8 x 0 with resolution 25
#      prism, center = (-9.09425,1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-4,0.15,-10)
#           (-4.108,0.151,-10)
#           (-4.215,0.152,-10)
#           (-4.322,0.155,-10)
#           (-4.429,0.16,-10)
#           (-4.535,0.165,-10)
#           (-4.641,0.171,-10)
#           (-4.747,0.179,-10)
#           (-4.852,0.187,-10)
#           (-5.062,0.207,-10)
#           (-5.167,0.219,-10)
#           (-5.271,0.231,-10)
#           (-5.479,0.259,-10)
#           (-5.582,0.274,-10)
#           (-5.685,0.29,-10)
#           (-5.788,0.307,-10)
#           (-5.891,0.325,-10)
#           (-5.993,0.343,-10)
#           (-6.095,0.362,-10)
#           (-6.197,0.382,-10)
#           (-6.299,0.403,-10)
#           (-6.4,0.424,-10)
#           (-6.501,0.446,-10)
#           (-6.703,0.492,-10)
#           (-6.803,0.515,-10)
#           (-6.904,0.54,-10)
#           (-7.204,0.615,-10)
#           (-7.303,0.642,-10)
#           (-7.403,0.668,-10)
#           (-7.502,0.695,-10)
#           (-7.601,0.723,-10)
#           (-7.7,0.75,-10)
#           (-7.799,0.778,-10)
#           (-7.898,0.807,-10)
#           (-7.996,0.835,-10)
#           (-8.095,0.864,-10)
#           (-8.193,0.893,-10)
#           (-8.291,0.923,-10)
#           (-8.389,0.952,-10)
#           (-8.487,0.982,-10)
#           (-8.585,1.011,-10)
#           (-8.781,1.071,-10)
#           (-8.878,1.101,-10)
#           (-9.074,1.161,-10)
#           (-9.268,1.221,-10)
#           (-9.366,1.251,-10)
#           (-9.463,1.281,-10)
#           (-9.56,1.31,-10)
#           (-9.658,1.34,-10)
#           (-9.949,1.427,-10)
#           (-10.047,1.456,-10)
#           (-10.144,1.485,-10)
#           (-10.338,1.541,-10)
#           (-10.436,1.568,-10)
#           (-10.533,1.596,-10)
#           (-10.63,1.623,-10)
#           (-10.728,1.649,-10)
#           (-10.922,1.701,-10)
#           (-11.02,1.726,-10)
#           (-11.117,1.75,-10)
#           (-11.215,1.775,-10)
#           (-11.313,1.798,-10)
#           (-11.41,1.821,-10)
#           (-11.508,1.844,-10)
#           (-11.606,1.866,-10)
#           (-11.704,1.887,-10)
#           (-11.802,1.907,-10)
#           (-11.901,1.927,-10)
#           (-11.999,1.946,-10)
#           (-12.098,1.965,-10)
#           (-12.196,1.983,-10)
#           (-12.295,2,-10)
#           (-12.394,2.016,-10)
#           (-12.592,2.046,-10)
#           (-12.691,2.06,-10)
#           (-12.791,2.072,-10)
#           (-12.89,2.084,-10)
#           (-12.99,2.095,-10)
#           (-13.19,2.115,-10)
#           (-13.291,2.123,-10)
#           (-13.392,2.13,-10)
#           (-13.492,2.136,-10)
#           (-13.593,2.141,-10)
#           (-13.695,2.145,-10)
#           (-13.796,2.148,-10)
#           (-14,2.15,-10)
#           (-17.2,2.15,-10)
#           (-17.2,2.65,-10)
#           (-14,2.65,-10)
#           (-13.892,2.649,-10)
#           (-13.785,2.648,-10)
#           (-13.678,2.645,-10)
#           (-13.571,2.64,-10)
#           (-13.465,2.635,-10)
#           (-13.359,2.629,-10)
#           (-13.253,2.621,-10)
#           (-13.148,2.613,-10)
#           (-12.938,2.593,-10)
#           (-12.833,2.581,-10)
#           (-12.729,2.569,-10)
#           (-12.521,2.541,-10)
#           (-12.418,2.526,-10)
#           (-12.315,2.51,-10)
#           (-12.212,2.493,-10)
#           (-12.109,2.475,-10)
#           (-12.007,2.457,-10)
#           (-11.905,2.438,-10)
#           (-11.803,2.418,-10)
#           (-11.701,2.397,-10)
#           (-11.6,2.376,-10)
#           (-11.499,2.354,-10)
#           (-11.297,2.308,-10)
#           (-11.197,2.285,-10)
#           (-11.096,2.26,-10)
#           (-10.796,2.185,-10)
#           (-10.697,2.158,-10)
#           (-10.597,2.132,-10)
#           (-10.498,2.105,-10)
#           (-10.399,2.077,-10)
#           (-10.3,2.05,-10)
#           (-10.201,2.022,-10)
#           (-10.102,1.993,-10)
#           (-10.004,1.965,-10)
#           (-9.905,1.936,-10)
#           (-9.807,1.907,-10)
#           (-9.709,1.877,-10)
#           (-9.611,1.848,-10)
#           (-9.513,1.818,-10)
#           (-9.415,1.789,-10)
#           (-9.219,1.729,-10)
#           (-9.122,1.699,-10)
#           (-8.926,1.639,-10)
#           (-8.732,1.579,-10)
#           (-8.634,1.549,-10)
#           (-8.537,1.519,-10)
#           (-8.44,1.49,-10)
#           (-8.342,1.46,-10)
#           (-8.051,1.373,-10)
#           (-7.953,1.344,-10)
#           (-7.856,1.315,-10)
#           (-7.662,1.259,-10)
#           (-7.564,1.232,-10)
#           (-7.467,1.204,-10)
#           (-7.37,1.177,-10)
#           (-7.272,1.151,-10)
#           (-7.078,1.099,-10)
#           (-6.98,1.074,-10)
#           (-6.883,1.05,-10)
#           (-6.785,1.025,-10)
#           (-6.687,1.002,-10)
#           (-6.59,0.979,-10)
#           (-6.492,0.956,-10)
#           (-6.394,0.934,-10)
#           (-6.296,0.913,-10)
#           (-6.198,0.893,-10)
#           (-6.099,0.873,-10)
#           (-6.001,0.854,-10)
#           (-5.902,0.835,-10)
#           (-5.804,0.817,-10)
#           (-5.705,0.8,-10)
#           (-5.606,0.784,-10)
#           (-5.408,0.754,-10)
#           (-5.309,0.74,-10)
#           (-5.209,0.728,-10)
#           (-5.11,0.716,-10)
#           (-5.01,0.705,-10)
#           (-4.81,0.685,-10)
#           (-4.709,0.677,-10)
#           (-4.608,0.67,-10)
#           (-4.508,0.664,-10)
#           (-4.407,0.659,-10)
#           (-4.305,0.655,-10)
#           (-4.204,0.652,-10)
#           (-4,0.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (4,0.15,-10)
#           (4,0.65,-10)
#           (4.204,0.652,-10)
#           (4.305,0.655,-10)
#           (4.407,0.659,-10)
#           (4.508,0.664,-10)
#           (4.608,0.67,-10)
#           (4.709,0.677,-10)
#           (4.81,0.685,-10)
#           (5.01,0.705,-10)
#           (5.11,0.716,-10)
#           (5.209,0.728,-10)
#           (5.309,0.74,-10)
#           (5.408,0.754,-10)
#           (5.606,0.784,-10)
#           (5.705,0.8,-10)
#           (5.804,0.817,-10)
#           (5.902,0.835,-10)
#           (6.001,0.854,-10)
#           (6.099,0.873,-10)
#           (6.198,0.893,-10)
#           (6.296,0.913,-10)
#           (6.394,0.934,-10)
#           (6.492,0.956,-10)
#           (6.59,0.979,-10)
#           (6.687,1.002,-10)
#           (6.785,1.025,-10)
#           (6.883,1.05,-10)
#           (6.98,1.074,-10)
#           (7.078,1.099,-10)
#           (7.272,1.151,-10)
#           (7.37,1.177,-10)
#           (7.467,1.204,-10)
#           (7.564,1.232,-10)
#           (7.662,1.259,-10)
#           (7.856,1.315,-10)
#           (7.953,1.344,-10)
#           (8.051,1.373,-10)
#           (8.342,1.46,-10)
#           (8.44,1.49,-10)
#           (8.537,1.519,-10)
#           (8.634,1.549,-10)
#           (8.732,1.579,-10)
#           (8.926,1.639,-10)
#           (9.122,1.699,-10)
#           (9.219,1.729,-10)
#           (9.415,1.789,-10)
#           (9.513,1.818,-10)
#           (9.611,1.848,-10)
#           (9.709,1.877,-10)
#           (9.807,1.907,-10)
#           (9.905,1.936,-10)
#           (10.004,1.965,-10)
#           (10.102,1.993,-10)
#           (10.201,2.022,-10)
#           (10.3,2.05,-10)
#           (10.399,2.077,-10)
#           (10.498,2.105,-10)
#           (10.597,2.132,-10)
#           (10.697,2.158,-10)
#           (10.796,2.185,-10)
#           (11.096,2.26,-10)
#           (11.197,2.285,-10)
#           (11.297,2.308,-10)
#           (11.499,2.354,-10)
#           (11.6,2.376,-10)
#           (11.701,2.397,-10)
#           (11.803,2.418,-10)
#           (11.905,2.438,-10)
#           (12.007,2.457,-10)
#           (12.109,2.475,-10)
#           (12.212,2.493,-10)
#           (12.315,2.51,-10)
#           (12.418,2.526,-10)
#           (12.521,2.541,-10)
#           (12.729,2.569,-10)
#           (12.833,2.581,-10)
#           (12.938,2.593,-10)
#           (13.148,2.613,-10)
#           (13.253,2.621,-10)
#           (13.359,2.629,-10)
#           (13.465,2.635,-10)
#           (13.571,2.64,-10)
#           (13.678,2.645,-10)
#           (13.785,2.648,-10)
#           (13.892,2.649,-10)
#           (14,2.65,-10)
#           (17.2,2.65,-10)
#           (17.2,2.15,-10)
#           (14,2.15,-10)
#           (13.796,2.148,-10)
#           (13.695,2.145,-10)
#           (13.593,2.141,-10)
#           (13.492,2.136,-10)
#           (13.392,2.13,-10)
#           (13.291,2.123,-10)
#           (13.19,2.115,-10)
#           (12.99,2.095,-10)
#           (12.89,2.084,-10)
#           (12.791,2.072,-10)
#           (12.691,2.06,-10)
#           (12.592,2.046,-10)
#           (12.394,2.016,-10)
#           (12.295,2,-10)
#           (12.196,1.983,-10)
#           (12.098,1.965,-10)
#           (11.999,1.946,-10)
#           (11.901,1.927,-10)
#           (11.802,1.907,-10)
#           (11.704,1.887,-10)
#           (11.606,1.866,-10)
#           (11.508,1.844,-10)
#           (11.41,1.821,-10)
#           (11.313,1.798,-10)
#           (11.215,1.775,-10)
#           (11.117,1.75,-10)
#           (11.02,1.726,-10)
#           (10.922,1.701,-10)
#           (10.728,1.649,-10)
#           (10.63,1.623,-10)
#           (10.533,1.596,-10)
#           (10.436,1.568,-10)
#           (10.338,1.541,-10)
#           (10.144,1.485,-10)
#           (10.047,1.456,-10)
#           (9.949,1.427,-10)
#           (9.658,1.34,-10)
#           (9.56,1.31,-10)
#           (9.463,1.281,-10)
#           (9.366,1.251,-10)
#           (9.268,1.221,-10)
#           (9.074,1.161,-10)
#           (8.878,1.101,-10)
#           (8.781,1.071,-10)
#           (8.585,1.011,-10)
#           (8.487,0.982,-10)
#           (8.389,0.952,-10)
#           (8.291,0.923,-10)
#           (8.193,0.893,-10)
#           (8.095,0.864,-10)
#           (7.996,0.835,-10)
#           (7.898,0.807,-10)
#           (7.799,0.778,-10)
#           (7.7,0.75,-10)
#           (7.601,0.723,-10)
#           (7.502,0.695,-10)
#           (7.403,0.668,-10)
#           (7.303,0.642,-10)
#           (7.204,0.615,-10)
#           (6.904,0.54,-10)
#           (6.803,0.515,-10)
#           (6.703,0.492,-10)
#           (6.501,0.446,-10)
#           (6.4,0.424,-10)
#           (6.299,0.403,-10)
#           (6.197,0.382,-10)
#           (6.095,0.362,-10)
#           (5.993,0.343,-10)
#           (5.891,0.325,-10)
#           (5.788,0.307,-10)
#           (5.685,0.29,-10)
#           (5.582,0.274,-10)
#           (5.479,0.259,-10)
#           (5.271,0.231,-10)
#           (5.167,0.219,-10)
#           (5.062,0.207,-10)
#           (4.852,0.187,-10)
#           (4.747,0.179,-10)
#           (4.641,0.171,-10)
#           (4.535,0.165,-10)
#           (4.429,0.16,-10)
#           (4.322,0.155,-10)
#           (4.215,0.152,-10)
#           (4.108,0.151,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,0.4,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,0.15,-10)
#           (-4,0.65,-10)
#           (4,0.65,-10)
#           (4,0.15,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (-9.09425,-1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-17.2,-2.65,-10)
#           (-17.2,-2.15,-10)
#           (-14,-2.15,-10)
#           (-13.796,-2.148,-10)
#           (-13.695,-2.145,-10)
#           (-13.593,-2.141,-10)
#           (-13.492,-2.136,-10)
#           (-13.392,-2.13,-10)
#           (-13.291,-2.123,-10)
#           (-13.19,-2.115,-10)
#           (-12.99,-2.095,-10)
#           (-12.89,-2.084,-10)
#           (-12.791,-2.072,-10)
#           (-12.691,-2.06,-10)
#           (-12.592,-2.046,-10)
#           (-12.394,-2.016,-10)
#           (-12.295,-2,-10)
#           (-12.196,-1.983,-10)
#           (-12.098,-1.965,-10)
#           (-11.999,-1.946,-10)
#           (-11.901,-1.927,-10)
#           (-11.802,-1.907,-10)
#           (-11.704,-1.887,-10)
#           (-11.606,-1.866,-10)
#           (-11.508,-1.844,-10)
#           (-11.41,-1.821,-10)
#           (-11.313,-1.798,-10)
#           (-11.215,-1.775,-10)
#           (-11.117,-1.75,-10)
#           (-11.02,-1.726,-10)
#           (-10.922,-1.701,-10)
#           (-10.728,-1.649,-10)
#           (-10.63,-1.623,-10)
#           (-10.533,-1.596,-10)
#           (-10.436,-1.568,-10)
#           (-10.338,-1.541,-10)
#           (-10.144,-1.485,-10)
#           (-10.047,-1.456,-10)
#           (-9.949,-1.427,-10)
#           (-9.658,-1.34,-10)
#           (-9.56,-1.31,-10)
#           (-9.463,-1.281,-10)
#           (-9.366,-1.251,-10)
#           (-9.268,-1.221,-10)
#           (-9.074,-1.161,-10)
#           (-8.878,-1.101,-10)
#           (-8.781,-1.071,-10)
#           (-8.585,-1.011,-10)
#           (-8.487,-0.982,-10)
#           (-8.389,-0.952,-10)
#           (-8.291,-0.923,-10)
#           (-8.193,-0.893,-10)
#           (-8.095,-0.864,-10)
#           (-7.996,-0.835,-10)
#           (-7.898,-0.807,-10)
#           (-7.799,-0.778,-10)
#           (-7.7,-0.75,-10)
#           (-7.601,-0.723,-10)
#           (-7.502,-0.695,-10)
#           (-7.403,-0.668,-10)
#           (-7.303,-0.642,-10)
#           (-7.204,-0.615,-10)
#           (-6.904,-0.54,-10)
#           (-6.803,-0.515,-10)
#           (-6.703,-0.492,-10)
#           (-6.501,-0.446,-10)
#           (-6.4,-0.424,-10)
#           (-6.299,-0.403,-10)
#           (-6.197,-0.382,-10)
#           (-6.095,-0.362,-10)
#           (-5.993,-0.343,-10)
#           (-5.891,-0.325,-10)
#           (-5.788,-0.307,-10)
#           (-5.685,-0.29,-10)
#           (-5.582,-0.274,-10)
#           (-5.479,-0.259,-10)
#           (-5.271,-0.231,-10)
#           (-5.167,-0.219,-10)
#           (-5.062,-0.207,-10)
#           (-4.852,-0.187,-10)
#           (-4.747,-0.179,-10)
#           (-4.641,-0.171,-10)
#           (-4.535,-0.165,-10)
#           (-4.429,-0.16,-10)
#           (-4.322,-0.155,-10)
#           (-4.215,-0.152,-10)
#           (-4.108,-0.151,-10)
#           (-4,-0.15,-10)
#           (-4,-0.65,-10)
#           (-4.204,-0.652,-10)
#           (-4.305,-0.655,-10)
#           (-4.407,-0.659,-10)
#           (-4.508,-0.664,-10)
#           (-4.608,-0.67,-10)
#           (-4.709,-0.677,-10)
#           (-4.81,-0.685,-10)
#           (-5.01,-0.705,-10)
#           (-5.11,-0.716,-10)
#           (-5.209,-0.728,-10)
#           (-5.309,-0.74,-10)
#           (-5.408,-0.754,-10)
#           (-5.606,-0.784,-10)
#           (-5.705,-0.8,-10)
#           (-5.804,-0.817,-10)
#           (-5.902,-0.835,-10)
#           (-6.001,-0.854,-10)
#           (-6.099,-0.873,-10)
#           (-6.198,-0.893,-10)
#           (-6.296,-0.913,-10)
#           (-6.394,-0.934,-10)
#           (-6.492,-0.956,-10)
#           (-6.59,-0.979,-10)
#           (-6.687,-1.002,-10)
#           (-6.785,-1.025,-10)
#           (-6.883,-1.05,-10)
#           (-6.98,-1.074,-10)
#           (-7.078,-1.099,-10)
#           (-7.272,-1.151,-10)
#           (-7.37,-1.177,-10)
#           (-7.467,-1.204,-10)
#           (-7.564,-1.232,-10)
#           (-7.662,-1.259,-10)
#           (-7.856,-1.315,-10)
#           (-7.953,-1.344,-10)
#           (-8.051,-1.373,-10)
#           (-8.342,-1.46,-10)
#           (-8.44,-1.49,-10)
#           (-8.537,-1.519,-10)
#           (-8.634,-1.549,-10)
#           (-8.732,-1.579,-10)
#           (-8.926,-1.639,-10)
#           (-9.122,-1.699,-10)
#           (-9.219,-1.729,-10)
#           (-9.415,-1.789,-10)
#           (-9.513,-1.818,-10)
#           (-9.611,-1.848,-10)
#           (-9.709,-1.877,-10)
#           (-9.807,-1.907,-10)
#           (-9.905,-1.936,-10)
#           (-10.004,-1.965,-10)
#           (-10.102,-1.993,-10)
#           (-10.201,-2.022,-10)
#           (-10.3,-2.05,-10)
#           (-10.399,-2.077,-10)
#           (-10.498,-2.105,-10)
#           (-10.597,-2.132,-10)
#           (-10.697,-2.158,-10)
#           (-10.796,-2.185,-10)
#           (-11.096,-2.26,-10)
#           (-11.197,-2.285,-10)
#           (-11.297,-2.308,-10)
#           (-11.499,-2.354,-10)
#           (-11.6,-2.376,-10)
#           (-11.701,-2.397,-10)
#           (-11.803,-2.418,-10)
#           (-11.905,-2.438,-10)
#           (-12.007,-2.457,-10)
#           (-12.109,-2.475,-10)
#           (-12.212,-2.493,-10)
#           (-12.315,-2.51,-10)
#           (-12.418,-2.526,-10)
#           (-12.521,-2.541,-10)
#           (-12.729,-2.569,-10)
#           (-12.833,-2.581,-10)
#           (-12.938,-2.593,-10)
#           (-13.148,-2.613,-10)
#           (-13.253,-2.621,-10)
#           (-13.359,-2.629,-10)
#           (-13.465,-2.635,-10)
#           (-13.571,-2.64,-10)
#           (-13.678,-2.645,-10)
#           (-13.785,-2.648,-10)
#           (-13.892,-2.649,-10)
#           (-14,-2.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,-1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (14,-2.65,-10)
#           (13.892,-2.649,-10)
#           (13.785,-2.648,-10)
#           (13.678,-2.645,-10)
#           (13.571,-2.64,-10)
#           (13.465,-2.635,-10)
#           (13.359,-2.629,-10)
#           (13.253,-2.621,-10)
#           (13.148,-2.613,-10)
#           (12.938,-2.593,-10)
#           (12.833,-2.581,-10)
#           (12.729,-2.569,-10)
#           (12.521,-2.541,-10)
#           (12.418,-2.526,-10)
#           (12.315,-2.51,-10)
#           (12.212,-2.493,-10)
#           (12.109,-2.475,-10)
#           (12.007,-2.457,-10)
#           (11.905,-2.438,-10)
#           (11.803,-2.418,-10)
#           (11.701,-2.397,-10)
#           (11.6,-2.376,-10)
#           (11.499,-2.354,-10)
#           (11.297,-2.308,-10)
#           (11.197,-2.285,-10)
#           (11.096,-2.26,-10)
#           (10.796,-2.185,-10)
#           (10.697,-2.158,-10)
#           (10.597,-2.132,-10)
#           (10.498,-2.105,-10)
#           (10.399,-2.077,-10)
#           (10.3,-2.05,-10)
#           (10.201,-2.022,-10)
#           (10.102,-1.993,-10)
#           (10.004,-1.965,-10)
#           (9.905,-1.936,-10)
#           (9.807,-1.907,-10)
#           (9.709,-1.877,-10)
#           (9.611,-1.848,-10)
#           (9.513,-1.818,-10)
#           (9.415,-1.789,-10)
#           (9.219,-1.729,-10)
#           (9.122,-1.699,-10)
#           (8.926,-1.639,-10)
#           (8.732,-1.579,-10)
#           (8.634,-1.549,-10)
#           (8.537,-1.519,-10)
#           (8.44,-1.49,-10)
#           (8.342,-1.46,-10)
#           (8.051,-1.373,-10)
#           (7.953,-1.344,-10)
#           (7.856,-1.315,-10)
#           (7.662,-1.259,-10)
#           (7.564,-1.232,-10)
#           (7.467,-1.204,-10)
#           (7.37,-1.177,-10)
#           (7.272,-1.151,-10)
#           (7.078,-1.099,-10)
#           (6.98,-1.074,-10)
#           (6.883,-1.05,-10)
#           (6.785,-1.025,-10)
#           (6.687,-1.002,-10)
#           (6.59,-0.979,-10)
#           (6.492,-0.956,-10)
#           (6.394,-0.934,-10)
#           (6.296,-0.913,-10)
#           (6.198,-0.893,-10)
#           (6.099,-0.873,-10)
#           (6.001,-0.854,-10)
#           (5.902,-0.835,-10)
#           (5.804,-0.817,-10)
#           (5.705,-0.8,-10)
#           (5.606,-0.784,-10)
#           (5.408,-0.754,-10)
#           (5.309,-0.74,-10)
#           (5.209,-0.728,-10)
#           (5.11,-0.716,-10)
#           (5.01,-0.705,-10)
#           (4.81,-0.685,-10)
#           (4.709,-0.677,-10)
#           (4.608,-0.67,-10)
#           (4.508,-0.664,-10)
#           (4.407,-0.659,-10)
#           (4.305,-0.655,-10)
#           (4.204,-0.652,-10)
#           (4,-0.65,-10)
#           (4,-0.15,-10)
#           (4.108,-0.151,-10)
#           (4.215,-0.152,-10)
#           (4.322,-0.155,-10)
#           (4.429,-0.16,-10)
#           (4.535,-0.165,-10)
#           (4.641,-0.171,-10)
#           (4.747,-0.179,-10)
#           (4.852,-0.187,-10)
#           (5.062,-0.207,-10)
#           (5.167,-0.219,-10)
#           (5.271,-0.231,-10)
#           (5.479,-0.259,-10)
#           (5.582,-0.274,-10)
#           (5.685,-0.29,-10)
#           (5.788,-0.307,-10)
#           (5.891,-0.325,-10)
#           (5.993,-0.343,-10)
#           (6.095,-0.362,-10)
#           (6.197,-0.382,-10)
#           (6.299,-0.403,-10)
#           (6.4,-0.424,-10)
#           (6.501,-0.446,-10)
#           (6.703,-0.492,-10)
#           (6.803,-0.515,-10)
#           (6.904,-0.54,-10)
#           (7.204,-0.615,-10)
#           (7.303,-0.642,-10)
#           (7.403,-0.668,-10)
#           (7.502,-0.695,-10)
#           (7.601,-0.723,-10)
#           (7.7,-0.75,-10)
#           (7.799,-0.778,-10)
#           (7.898,-0.807,-10)
#           (7.996,-0.835,-10)
#           (8.095,-0.864,-10)
#           (8.193,-0.893,-10)
#           (8.291,-0.923,-10)
#           (8.389,-0.952,-10)
#           (8.487,-0.982,-10)
#           (8.585,-1.011,-10)
#           (8.781,-1.071,-10)
#           (8.878,-1.101,-10)
#           (9.074,-1.161,-10)
#           (9.268,-1.221,-10)
#           (9.366,-1.251,-10)
#           (9.463,-1.281,-10)
#           (9.56,-1.31,-10)
#           (9.658,-1.34,-10)
#           (9.949,-1.427,-10)
#           (10.047,-1.456,-10)
#           (10.144,-1.485,-10)
#           (10.338,-1.541,-10)
#           (10.436,-1.568,-10)
#           (10.533,-1.596,-10)
#           (10.63,-1.623,-10)
#           (10.728,-1.649,-10)
#           (10.922,-1.701,-10)
#           (11.02,-1.726,-10)
#           (11.117,-1.75,-10)
#           (11.215,-1.775,-10)
#           (11.313,-1.798,-10)
#           (11.41,-1.821,-10)
#           (11.508,-1.844,-10)
#           (11.606,-1.866,-10)
#           (11.704,-1.887,-10)
#           (11.802,-1.907,-10)
#           (11.901,-1.927,-10)
#           (11.999,-1.946,-10)
#           (12.098,-1.965,-10)
#           (12.196,-1.983,-10)
#           (12.295,-2,-10)
#           (12.394,-2.016,-10)
#           (12.592,-2.046,-10)
#           (12.691,-2.06,-10)
#           (12.791,-2.072,-10)
#           (12.89,-2.084,-10)
#           (12.99,-2.095,-10)
#           (13.19,-2.115,-10)
#           (13.291,-2.123,-10)
#           (13.392,-2.13,-10)
#           (13.492,-2.136,-10)
#           (13.593,-2.141,-10)
#           (13.695,-2.145,-10)
#           (13.796,-2.148,-10)
#           (14,-2.15,-10)
#           (17.2,-2.15,-10)
#           (17.2,-2.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,-0.4,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,-0.65,-10)
#           (-4,-0.15,-10)
#           (4,-0.15,-10)
#           (4,-0.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 11.6135% done, 33.1923 s remaining
# subpixel-averaging is 19.9094% done, 17.4105 s remaining
# subpixel-averaging is 28.2053% done, 11.2096 s remaining
# subpixel-averaging is 36.5013% done, 7.57302 s remaining
# subpixel-averaging is 69.685% done, 1.92258 s remaining
# subpixel-averaging is 77.9809% done, 1.22061 s remaining
# subpixel-averaging is 86.2769% done, 0.689749 s remaining
# subpixel-averaging is 95.4024% done, 0.201467 s remaining
# subpixel-averaging is 10.7839% done, 33.2438 s remaining
# subpixel-averaging is 19.0798% done, 18.4037 s remaining
# subpixel-averaging is 27.3757% done, 11.3459 s remaining
# subpixel-averaging is 35.6717% done, 7.85655 s remaining
# subpixel-averaging is 68.0258% done, 1.88948 s remaining
# subpixel-averaging is 76.3217% done, 1.35977 s remaining
# subpixel-averaging is 84.6177% done, 0.788523 s remaining
# subpixel-averaging is 92.9136% done, 0.328073 s remaining
# subpixel-averaging is 11.6135% done, 33.6177 s remaining
# subpixel-averaging is 19.9094% done, 17.2394 s remaining
# subpixel-averaging is 28.2053% done, 10.8095 s remaining
# subpixel-averaging is 36.5013% done, 7.50609 s remaining
# subpixel-averaging is 69.685% done, 1.92356 s remaining
# subpixel-averaging is 77.9809% done, 1.20691 s remaining
# subpixel-averaging is 86.2769% done, 0.685257 s remaining
# subpixel-averaging is 94.5728% done, 0.237411 s remaining
# time for set_epsilon = 114.166 s
# -----------
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Meep progress: 86.46000000000001/177.5 = 48.7% done in 4.0s, 4.2s to go
# on time step 4323 (time=86.46), 0.00092556 s/step
# Meep progress: 174.70000000000002/177.5 = 98.4% done in 8.0s, 0.1s to go
# on time step 8736 (time=174.72), 0.000906496 s/step
# run 0 finished at t = 177.5 (8875 timesteps)

# %%
# S parameters
p1_coeff = sim.get_eigenmode_coefficients(
    mode1, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]
p2_coeff = sim.get_eigenmode_coefficients(
    mode2, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 1]
p3_coeff = sim.get_eigenmode_coefficients(
    mode3, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]
p4_coeff = sim.get_eigenmode_coefficients(
    mode4, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]

# transmittance
p2_trans = abs(p2_coeff) ** 2 / abs(p1_coeff) ** 2
p3_trans = abs(p3_coeff) ** 2 / abs(p1_coeff) ** 2
p4_trans = abs(p4_coeff) ** 2 / abs(p1_coeff) ** 2

print("trans:, {:.2f}, {:.6f}, {:.6f}, {:.6f}".format(d, p2_trans, p3_trans, p4_trans))
# Out:
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# trans:, 0.30, 0.000000, 0.987077, 0.008438

# %%
sim.reset_meep()

sources = [
    mp.EigenModeSource(
        src=mp.ContinuousSource(fcen, fwidth=df),
        size=src_vol.size,
        center=src_vol.center,
        eig_band=1,
        eig_parity=mp.EVEN_Y + mp.ODD_Z,
        eig_match_freq=True,
    )
]

sim = mp.Simulation(
    resolution=res,
    cell_size=cell.size,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
    geometry=geometry,
)

sim.run(
    until=400
)  # arbitrary long run time to ensure that fields have reached steady state

eps_data = sim.get_epsilon()
ez_data = numpy.real(sim.get_efield_z())

plt.figure(dpi=200)
plt.imshow(numpy.transpose(eps_data), interpolation="spline36", cmap="binary")
plt.imshow(
    numpy.flipud(numpy.transpose(ez_data)),
    interpolation="spline36",
    cmap="RdBu",
    alpha=0.9,
)
plt.axis("off")
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0346711 s
# Working in 2D dimensions.
# Computational cell is 34.4 x 8 x 0 with resolution 25
#      prism, center = (-9.09425,1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-4,0.15,-10)
#           (-4.108,0.151,-10)
#           (-4.215,0.152,-10)
#           (-4.322,0.155,-10)
#           (-4.429,0.16,-10)
#           (-4.535,0.165,-10)
#           (-4.641,0.171,-10)
#           (-4.747,0.179,-10)
#           (-4.852,0.187,-10)
#           (-5.062,0.207,-10)
#           (-5.167,0.219,-10)
#           (-5.271,0.231,-10)
#           (-5.479,0.259,-10)
#           (-5.582,0.274,-10)
#           (-5.685,0.29,-10)
#           (-5.788,0.307,-10)
#           (-5.891,0.325,-10)
#           (-5.993,0.343,-10)
#           (-6.095,0.362,-10)
#           (-6.197,0.382,-10)
#           (-6.299,0.403,-10)
#           (-6.4,0.424,-10)
#           (-6.501,0.446,-10)
#           (-6.703,0.492,-10)
#           (-6.803,0.515,-10)
#           (-6.904,0.54,-10)
#           (-7.204,0.615,-10)
#           (-7.303,0.642,-10)
#           (-7.403,0.668,-10)
#           (-7.502,0.695,-10)
#           (-7.601,0.723,-10)
#           (-7.7,0.75,-10)
#           (-7.799,0.778,-10)
#           (-7.898,0.807,-10)
#           (-7.996,0.835,-10)
#           (-8.095,0.864,-10)
#           (-8.193,0.893,-10)
#           (-8.291,0.923,-10)
#           (-8.389,0.952,-10)
#           (-8.487,0.982,-10)
#           (-8.585,1.011,-10)
#           (-8.781,1.071,-10)
#           (-8.878,1.101,-10)
#           (-9.074,1.161,-10)
#           (-9.268,1.221,-10)
#           (-9.366,1.251,-10)
#           (-9.463,1.281,-10)
#           (-9.56,1.31,-10)
#           (-9.658,1.34,-10)
#           (-9.949,1.427,-10)
#           (-10.047,1.456,-10)
#           (-10.144,1.485,-10)
#           (-10.338,1.541,-10)
#           (-10.436,1.568,-10)
#           (-10.533,1.596,-10)
#           (-10.63,1.623,-10)
#           (-10.728,1.649,-10)
#           (-10.922,1.701,-10)
#           (-11.02,1.726,-10)
#           (-11.117,1.75,-10)
#           (-11.215,1.775,-10)
#           (-11.313,1.798,-10)
#           (-11.41,1.821,-10)
#           (-11.508,1.844,-10)
#           (-11.606,1.866,-10)
#           (-11.704,1.887,-10)
#           (-11.802,1.907,-10)
#           (-11.901,1.927,-10)
#           (-11.999,1.946,-10)
#           (-12.098,1.965,-10)
#           (-12.196,1.983,-10)
#           (-12.295,2,-10)
#           (-12.394,2.016,-10)
#           (-12.592,2.046,-10)
#           (-12.691,2.06,-10)
#           (-12.791,2.072,-10)
#           (-12.89,2.084,-10)
#           (-12.99,2.095,-10)
#           (-13.19,2.115,-10)
#           (-13.291,2.123,-10)
#           (-13.392,2.13,-10)
#           (-13.492,2.136,-10)
#           (-13.593,2.141,-10)
#           (-13.695,2.145,-10)
#           (-13.796,2.148,-10)
#           (-14,2.15,-10)
#           (-17.2,2.15,-10)
#           (-17.2,2.65,-10)
#           (-14,2.65,-10)
#           (-13.892,2.649,-10)
#           (-13.785,2.648,-10)
#           (-13.678,2.645,-10)
#           (-13.571,2.64,-10)
#           (-13.465,2.635,-10)
#           (-13.359,2.629,-10)
#           (-13.253,2.621,-10)
#           (-13.148,2.613,-10)
#           (-12.938,2.593,-10)
#           (-12.833,2.581,-10)
#           (-12.729,2.569,-10)
#           (-12.521,2.541,-10)
#           (-12.418,2.526,-10)
#           (-12.315,2.51,-10)
#           (-12.212,2.493,-10)
#           (-12.109,2.475,-10)
#           (-12.007,2.457,-10)
#           (-11.905,2.438,-10)
#           (-11.803,2.418,-10)
#           (-11.701,2.397,-10)
#           (-11.6,2.376,-10)
#           (-11.499,2.354,-10)
#           (-11.297,2.308,-10)
#           (-11.197,2.285,-10)
#           (-11.096,2.26,-10)
#           (-10.796,2.185,-10)
#           (-10.697,2.158,-10)
#           (-10.597,2.132,-10)
#           (-10.498,2.105,-10)
#           (-10.399,2.077,-10)
#           (-10.3,2.05,-10)
#           (-10.201,2.022,-10)
#           (-10.102,1.993,-10)
#           (-10.004,1.965,-10)
#           (-9.905,1.936,-10)
#           (-9.807,1.907,-10)
#           (-9.709,1.877,-10)
#           (-9.611,1.848,-10)
#           (-9.513,1.818,-10)
#           (-9.415,1.789,-10)
#           (-9.219,1.729,-10)
#           (-9.122,1.699,-10)
#           (-8.926,1.639,-10)
#           (-8.732,1.579,-10)
#           (-8.634,1.549,-10)
#           (-8.537,1.519,-10)
#           (-8.44,1.49,-10)
#           (-8.342,1.46,-10)
#           (-8.051,1.373,-10)
#           (-7.953,1.344,-10)
#           (-7.856,1.315,-10)
#           (-7.662,1.259,-10)
#           (-7.564,1.232,-10)
#           (-7.467,1.204,-10)
#           (-7.37,1.177,-10)
#           (-7.272,1.151,-10)
#           (-7.078,1.099,-10)
#           (-6.98,1.074,-10)
#           (-6.883,1.05,-10)
#           (-6.785,1.025,-10)
#           (-6.687,1.002,-10)
#           (-6.59,0.979,-10)
#           (-6.492,0.956,-10)
#           (-6.394,0.934,-10)
#           (-6.296,0.913,-10)
#           (-6.198,0.893,-10)
#           (-6.099,0.873,-10)
#           (-6.001,0.854,-10)
#           (-5.902,0.835,-10)
#           (-5.804,0.817,-10)
#           (-5.705,0.8,-10)
#           (-5.606,0.784,-10)
#           (-5.408,0.754,-10)
#           (-5.309,0.74,-10)
#           (-5.209,0.728,-10)
#           (-5.11,0.716,-10)
#           (-5.01,0.705,-10)
#           (-4.81,0.685,-10)
#           (-4.709,0.677,-10)
#           (-4.608,0.67,-10)
#           (-4.508,0.664,-10)
#           (-4.407,0.659,-10)
#           (-4.305,0.655,-10)
#           (-4.204,0.652,-10)
#           (-4,0.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (4,0.15,-10)
#           (4,0.65,-10)
#           (4.204,0.652,-10)
#           (4.305,0.655,-10)
#           (4.407,0.659,-10)
#           (4.508,0.664,-10)
#           (4.608,0.67,-10)
#           (4.709,0.677,-10)
#           (4.81,0.685,-10)
#           (5.01,0.705,-10)
#           (5.11,0.716,-10)
#           (5.209,0.728,-10)
#           (5.309,0.74,-10)
#           (5.408,0.754,-10)
#           (5.606,0.784,-10)
#           (5.705,0.8,-10)
#           (5.804,0.817,-10)
#           (5.902,0.835,-10)
#           (6.001,0.854,-10)
#           (6.099,0.873,-10)
#           (6.198,0.893,-10)
#           (6.296,0.913,-10)
#           (6.394,0.934,-10)
#           (6.492,0.956,-10)
#           (6.59,0.979,-10)
#           (6.687,1.002,-10)
#           (6.785,1.025,-10)
#           (6.883,1.05,-10)
#           (6.98,1.074,-10)
#           (7.078,1.099,-10)
#           (7.272,1.151,-10)
#           (7.37,1.177,-10)
#           (7.467,1.204,-10)
#           (7.564,1.232,-10)
#           (7.662,1.259,-10)
#           (7.856,1.315,-10)
#           (7.953,1.344,-10)
#           (8.051,1.373,-10)
#           (8.342,1.46,-10)
#           (8.44,1.49,-10)
#           (8.537,1.519,-10)
#           (8.634,1.549,-10)
#           (8.732,1.579,-10)
#           (8.926,1.639,-10)
#           (9.122,1.699,-10)
#           (9.219,1.729,-10)
#           (9.415,1.789,-10)
#           (9.513,1.818,-10)
#           (9.611,1.848,-10)
#           (9.709,1.877,-10)
#           (9.807,1.907,-10)
#           (9.905,1.936,-10)
#           (10.004,1.965,-10)
#           (10.102,1.993,-10)
#           (10.201,2.022,-10)
#           (10.3,2.05,-10)
#           (10.399,2.077,-10)
#           (10.498,2.105,-10)
#           (10.597,2.132,-10)
#           (10.697,2.158,-10)
#           (10.796,2.185,-10)
#           (11.096,2.26,-10)
#           (11.197,2.285,-10)
#           (11.297,2.308,-10)
#           (11.499,2.354,-10)
#           (11.6,2.376,-10)
#           (11.701,2.397,-10)
#           (11.803,2.418,-10)
#           (11.905,2.438,-10)
#           (12.007,2.457,-10)
#           (12.109,2.475,-10)
#           (12.212,2.493,-10)
#           (12.315,2.51,-10)
#           (12.418,2.526,-10)
#           (12.521,2.541,-10)
#           (12.729,2.569,-10)
#           (12.833,2.581,-10)
#           (12.938,2.593,-10)
#           (13.148,2.613,-10)
#           (13.253,2.621,-10)
#           (13.359,2.629,-10)
#           (13.465,2.635,-10)
#           (13.571,2.64,-10)
#           (13.678,2.645,-10)
#           (13.785,2.648,-10)
#           (13.892,2.649,-10)
#           (14,2.65,-10)
#           (17.2,2.65,-10)
#           (17.2,2.15,-10)
#           (14,2.15,-10)
#           (13.796,2.148,-10)
#           (13.695,2.145,-10)
#           (13.593,2.141,-10)
#           (13.492,2.136,-10)
#           (13.392,2.13,-10)
#           (13.291,2.123,-10)
#           (13.19,2.115,-10)
#           (12.99,2.095,-10)
#           (12.89,2.084,-10)
#           (12.791,2.072,-10)
#           (12.691,2.06,-10)
#           (12.592,2.046,-10)
#           (12.394,2.016,-10)
#           (12.295,2,-10)
#           (12.196,1.983,-10)
#           (12.098,1.965,-10)
#           (11.999,1.946,-10)
#           (11.901,1.927,-10)
#           (11.802,1.907,-10)
#           (11.704,1.887,-10)
#           (11.606,1.866,-10)
#           (11.508,1.844,-10)
#           (11.41,1.821,-10)
#           (11.313,1.798,-10)
#           (11.215,1.775,-10)
#           (11.117,1.75,-10)
#           (11.02,1.726,-10)
#           (10.922,1.701,-10)
#           (10.728,1.649,-10)
#           (10.63,1.623,-10)
#           (10.533,1.596,-10)
#           (10.436,1.568,-10)
#           (10.338,1.541,-10)
#           (10.144,1.485,-10)
#           (10.047,1.456,-10)
#           (9.949,1.427,-10)
#           (9.658,1.34,-10)
#           (9.56,1.31,-10)
#           (9.463,1.281,-10)
#           (9.366,1.251,-10)
#           (9.268,1.221,-10)
#           (9.074,1.161,-10)
#           (8.878,1.101,-10)
#           (8.781,1.071,-10)
#           (8.585,1.011,-10)
#           (8.487,0.982,-10)
#           (8.389,0.952,-10)
#           (8.291,0.923,-10)
#           (8.193,0.893,-10)
#           (8.095,0.864,-10)
#           (7.996,0.835,-10)
#           (7.898,0.807,-10)
#           (7.799,0.778,-10)
#           (7.7,0.75,-10)
#           (7.601,0.723,-10)
#           (7.502,0.695,-10)
#           (7.403,0.668,-10)
#           (7.303,0.642,-10)
#           (7.204,0.615,-10)
#           (6.904,0.54,-10)
#           (6.803,0.515,-10)
#           (6.703,0.492,-10)
#           (6.501,0.446,-10)
#           (6.4,0.424,-10)
#           (6.299,0.403,-10)
#           (6.197,0.382,-10)
#           (6.095,0.362,-10)
#           (5.993,0.343,-10)
#           (5.891,0.325,-10)
#           (5.788,0.307,-10)
#           (5.685,0.29,-10)
#           (5.582,0.274,-10)
#           (5.479,0.259,-10)
#           (5.271,0.231,-10)
#           (5.167,0.219,-10)
#           (5.062,0.207,-10)
#           (4.852,0.187,-10)
#           (4.747,0.179,-10)
#           (4.641,0.171,-10)
#           (4.535,0.165,-10)
#           (4.429,0.16,-10)
#           (4.322,0.155,-10)
#           (4.215,0.152,-10)
#           (4.108,0.151,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,0.4,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,0.15,-10)
#           (-4,0.65,-10)
#           (4,0.65,-10)
#           (4,0.15,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (-9.09425,-1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-17.2,-2.65,-10)
#           (-17.2,-2.15,-10)
#           (-14,-2.15,-10)
#           (-13.796,-2.148,-10)
#           (-13.695,-2.145,-10)
#           (-13.593,-2.141,-10)
#           (-13.492,-2.136,-10)
#           (-13.392,-2.13,-10)
#           (-13.291,-2.123,-10)
#           (-13.19,-2.115,-10)
#           (-12.99,-2.095,-10)
#           (-12.89,-2.084,-10)
#           (-12.791,-2.072,-10)
#           (-12.691,-2.06,-10)
#           (-12.592,-2.046,-10)
#           (-12.394,-2.016,-10)
#           (-12.295,-2,-10)
#           (-12.196,-1.983,-10)
#           (-12.098,-1.965,-10)
#           (-11.999,-1.946,-10)
#           (-11.901,-1.927,-10)
#           (-11.802,-1.907,-10)
#           (-11.704,-1.887,-10)
#           (-11.606,-1.866,-10)
#           (-11.508,-1.844,-10)
#           (-11.41,-1.821,-10)
#           (-11.313,-1.798,-10)
#           (-11.215,-1.775,-10)
#           (-11.117,-1.75,-10)
#           (-11.02,-1.726,-10)
#           (-10.922,-1.701,-10)
#           (-10.728,-1.649,-10)
#           (-10.63,-1.623,-10)
#           (-10.533,-1.596,-10)
#           (-10.436,-1.568,-10)
#           (-10.338,-1.541,-10)
#           (-10.144,-1.485,-10)
#           (-10.047,-1.456,-10)
#           (-9.949,-1.427,-10)
#           (-9.658,-1.34,-10)
#           (-9.56,-1.31,-10)
#           (-9.463,-1.281,-10)
#           (-9.366,-1.251,-10)
#           (-9.268,-1.221,-10)
#           (-9.074,-1.161,-10)
#           (-8.878,-1.101,-10)
#           (-8.781,-1.071,-10)
#           (-8.585,-1.011,-10)
#           (-8.487,-0.982,-10)
#           (-8.389,-0.952,-10)
#           (-8.291,-0.923,-10)
#           (-8.193,-0.893,-10)
#           (-8.095,-0.864,-10)
#           (-7.996,-0.835,-10)
#           (-7.898,-0.807,-10)
#           (-7.799,-0.778,-10)
#           (-7.7,-0.75,-10)
#           (-7.601,-0.723,-10)
#           (-7.502,-0.695,-10)
#           (-7.403,-0.668,-10)
#           (-7.303,-0.642,-10)
#           (-7.204,-0.615,-10)
#           (-6.904,-0.54,-10)
#           (-6.803,-0.515,-10)
#           (-6.703,-0.492,-10)
#           (-6.501,-0.446,-10)
#           (-6.4,-0.424,-10)
#           (-6.299,-0.403,-10)
#           (-6.197,-0.382,-10)
#           (-6.095,-0.362,-10)
#           (-5.993,-0.343,-10)
#           (-5.891,-0.325,-10)
#           (-5.788,-0.307,-10)
#           (-5.685,-0.29,-10)
#           (-5.582,-0.274,-10)
#           (-5.479,-0.259,-10)
#           (-5.271,-0.231,-10)
#           (-5.167,-0.219,-10)
#           (-5.062,-0.207,-10)
#           (-4.852,-0.187,-10)
#           (-4.747,-0.179,-10)
#           (-4.641,-0.171,-10)
#           (-4.535,-0.165,-10)
#           (-4.429,-0.16,-10)
#           (-4.322,-0.155,-10)
#           (-4.215,-0.152,-10)
#           (-4.108,-0.151,-10)
#           (-4,-0.15,-10)
#           (-4,-0.65,-10)
#           (-4.204,-0.652,-10)
#           (-4.305,-0.655,-10)
#           (-4.407,-0.659,-10)
#           (-4.508,-0.664,-10)
#           (-4.608,-0.67,-10)
#           (-4.709,-0.677,-10)
#           (-4.81,-0.685,-10)
#           (-5.01,-0.705,-10)
#           (-5.11,-0.716,-10)
#           (-5.209,-0.728,-10)
#           (-5.309,-0.74,-10)
#           (-5.408,-0.754,-10)
#           (-5.606,-0.784,-10)
#           (-5.705,-0.8,-10)
#           (-5.804,-0.817,-10)
#           (-5.902,-0.835,-10)
#           (-6.001,-0.854,-10)
#           (-6.099,-0.873,-10)
#           (-6.198,-0.893,-10)
#           (-6.296,-0.913,-10)
#           (-6.394,-0.934,-10)
#           (-6.492,-0.956,-10)
#           (-6.59,-0.979,-10)
#           (-6.687,-1.002,-10)
#           (-6.785,-1.025,-10)
#           (-6.883,-1.05,-10)
#           (-6.98,-1.074,-10)
#           (-7.078,-1.099,-10)
#           (-7.272,-1.151,-10)
#           (-7.37,-1.177,-10)
#           (-7.467,-1.204,-10)
#           (-7.564,-1.232,-10)
#           (-7.662,-1.259,-10)
#           (-7.856,-1.315,-10)
#           (-7.953,-1.344,-10)
#           (-8.051,-1.373,-10)
#           (-8.342,-1.46,-10)
#           (-8.44,-1.49,-10)
#           (-8.537,-1.519,-10)
#           (-8.634,-1.549,-10)
#           (-8.732,-1.579,-10)
#           (-8.926,-1.639,-10)
#           (-9.122,-1.699,-10)
#           (-9.219,-1.729,-10)
#           (-9.415,-1.789,-10)
#           (-9.513,-1.818,-10)
#           (-9.611,-1.848,-10)
#           (-9.709,-1.877,-10)
#           (-9.807,-1.907,-10)
#           (-9.905,-1.936,-10)
#           (-10.004,-1.965,-10)
#           (-10.102,-1.993,-10)
#           (-10.201,-2.022,-10)
#           (-10.3,-2.05,-10)
#           (-10.399,-2.077,-10)
#           (-10.498,-2.105,-10)
#           (-10.597,-2.132,-10)
#           (-10.697,-2.158,-10)
#           (-10.796,-2.185,-10)
#           (-11.096,-2.26,-10)
#           (-11.197,-2.285,-10)
#           (-11.297,-2.308,-10)
#           (-11.499,-2.354,-10)
#           (-11.6,-2.376,-10)
#           (-11.701,-2.397,-10)
#           (-11.803,-2.418,-10)
#           (-11.905,-2.438,-10)
#           (-12.007,-2.457,-10)
#           (-12.109,-2.475,-10)
#           (-12.212,-2.493,-10)
#           (-12.315,-2.51,-10)
#           (-12.418,-2.526,-10)
#           (-12.521,-2.541,-10)
#           (-12.729,-2.569,-10)
#           (-12.833,-2.581,-10)
#           (-12.938,-2.593,-10)
#           (-13.148,-2.613,-10)
#           (-13.253,-2.621,-10)
#           (-13.359,-2.629,-10)
#           (-13.465,-2.635,-10)
#           (-13.571,-2.64,-10)
#           (-13.678,-2.645,-10)
#           (-13.785,-2.648,-10)
#           (-13.892,-2.649,-10)
#           (-14,-2.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,-1.41149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (14,-2.65,-10)
#           (13.892,-2.649,-10)
#           (13.785,-2.648,-10)
#           (13.678,-2.645,-10)
#           (13.571,-2.64,-10)
#           (13.465,-2.635,-10)
#           (13.359,-2.629,-10)
#           (13.253,-2.621,-10)
#           (13.148,-2.613,-10)
#           (12.938,-2.593,-10)
#           (12.833,-2.581,-10)
#           (12.729,-2.569,-10)
#           (12.521,-2.541,-10)
#           (12.418,-2.526,-10)
#           (12.315,-2.51,-10)
#           (12.212,-2.493,-10)
#           (12.109,-2.475,-10)
#           (12.007,-2.457,-10)
#           (11.905,-2.438,-10)
#           (11.803,-2.418,-10)
#           (11.701,-2.397,-10)
#           (11.6,-2.376,-10)
#           (11.499,-2.354,-10)
#           (11.297,-2.308,-10)
#           (11.197,-2.285,-10)
#           (11.096,-2.26,-10)
#           (10.796,-2.185,-10)
#           (10.697,-2.158,-10)
#           (10.597,-2.132,-10)
#           (10.498,-2.105,-10)
#           (10.399,-2.077,-10)
#           (10.3,-2.05,-10)
#           (10.201,-2.022,-10)
#           (10.102,-1.993,-10)
#           (10.004,-1.965,-10)
#           (9.905,-1.936,-10)
#           (9.807,-1.907,-10)
#           (9.709,-1.877,-10)
#           (9.611,-1.848,-10)
#           (9.513,-1.818,-10)
#           (9.415,-1.789,-10)
#           (9.219,-1.729,-10)
#           (9.122,-1.699,-10)
#           (8.926,-1.639,-10)
#           (8.732,-1.579,-10)
#           (8.634,-1.549,-10)
#           (8.537,-1.519,-10)
#           (8.44,-1.49,-10)
#           (8.342,-1.46,-10)
#           (8.051,-1.373,-10)
#           (7.953,-1.344,-10)
#           (7.856,-1.315,-10)
#           (7.662,-1.259,-10)
#           (7.564,-1.232,-10)
#           (7.467,-1.204,-10)
#           (7.37,-1.177,-10)
#           (7.272,-1.151,-10)
#           (7.078,-1.099,-10)
#           (6.98,-1.074,-10)
#           (6.883,-1.05,-10)
#           (6.785,-1.025,-10)
#           (6.687,-1.002,-10)
#           (6.59,-0.979,-10)
#           (6.492,-0.956,-10)
#           (6.394,-0.934,-10)
#           (6.296,-0.913,-10)
#           (6.198,-0.893,-10)
#           (6.099,-0.873,-10)
#           (6.001,-0.854,-10)
#           (5.902,-0.835,-10)
#           (5.804,-0.817,-10)
#           (5.705,-0.8,-10)
#           (5.606,-0.784,-10)
#           (5.408,-0.754,-10)
#           (5.309,-0.74,-10)
#           (5.209,-0.728,-10)
#           (5.11,-0.716,-10)
#           (5.01,-0.705,-10)
#           (4.81,-0.685,-10)
#           (4.709,-0.677,-10)
#           (4.608,-0.67,-10)
#           (4.508,-0.664,-10)
#           (4.407,-0.659,-10)
#           (4.305,-0.655,-10)
#           (4.204,-0.652,-10)
#           (4,-0.65,-10)
#           (4,-0.15,-10)
#           (4.108,-0.151,-10)
#           (4.215,-0.152,-10)
#           (4.322,-0.155,-10)
#           (4.429,-0.16,-10)
#           (4.535,-0.165,-10)
#           (4.641,-0.171,-10)
#           (4.747,-0.179,-10)
#           (4.852,-0.187,-10)
#           (5.062,-0.207,-10)
#           (5.167,-0.219,-10)
#           (5.271,-0.231,-10)
#           (5.479,-0.259,-10)
#           (5.582,-0.274,-10)
#           (5.685,-0.29,-10)
#           (5.788,-0.307,-10)
#           (5.891,-0.325,-10)
#           (5.993,-0.343,-10)
#           (6.095,-0.362,-10)
#           (6.197,-0.382,-10)
#           (6.299,-0.403,-10)
#           (6.4,-0.424,-10)
#           (6.501,-0.446,-10)
#           (6.703,-0.492,-10)
#           (6.803,-0.515,-10)
#           (6.904,-0.54,-10)
#           (7.204,-0.615,-10)
#           (7.303,-0.642,-10)
#           (7.403,-0.668,-10)
#           (7.502,-0.695,-10)
#           (7.601,-0.723,-10)
#           (7.7,-0.75,-10)
#           (7.799,-0.778,-10)
#           (7.898,-0.807,-10)
#           (7.996,-0.835,-10)
#           (8.095,-0.864,-10)
#           (8.193,-0.893,-10)
#           (8.291,-0.923,-10)
#           (8.389,-0.952,-10)
#           (8.487,-0.982,-10)
#           (8.585,-1.011,-10)
#           (8.781,-1.071,-10)
#           (8.878,-1.101,-10)
#           (9.074,-1.161,-10)
#           (9.268,-1.221,-10)
#           (9.366,-1.251,-10)
#           (9.463,-1.281,-10)
#           (9.56,-1.31,-10)
#           (9.658,-1.34,-10)
#           (9.949,-1.427,-10)
#           (10.047,-1.456,-10)
#           (10.144,-1.485,-10)
#           (10.338,-1.541,-10)
#           (10.436,-1.568,-10)
#           (10.533,-1.596,-10)
#           (10.63,-1.623,-10)
#           (10.728,-1.649,-10)
#           (10.922,-1.701,-10)
#           (11.02,-1.726,-10)
#           (11.117,-1.75,-10)
#           (11.215,-1.775,-10)
#           (11.313,-1.798,-10)
#           (11.41,-1.821,-10)
#           (11.508,-1.844,-10)
#           (11.606,-1.866,-10)
#           (11.704,-1.887,-10)
#           (11.802,-1.907,-10)
#           (11.901,-1.927,-10)
#           (11.999,-1.946,-10)
#           (12.098,-1.965,-10)
#           (12.196,-1.983,-10)
#           (12.295,-2,-10)
#           (12.394,-2.016,-10)
#           (12.592,-2.046,-10)
#           (12.691,-2.06,-10)
#           (12.791,-2.072,-10)
#           (12.89,-2.084,-10)
#           (12.99,-2.095,-10)
#           (13.19,-2.115,-10)
#           (13.291,-2.123,-10)
#           (13.392,-2.13,-10)
#           (13.492,-2.136,-10)
#           (13.593,-2.141,-10)
#           (13.695,-2.145,-10)
#           (13.796,-2.148,-10)
#           (14,-2.15,-10)
#           (17.2,-2.15,-10)
#           (17.2,-2.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,-0.4,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,-0.65,-10)
#           (-4,-0.15,-10)
#           (4,-0.15,-10)
#           (4,-0.65,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 11.6135% done, 33.2634 s remaining
# subpixel-averaging is 19.9094% done, 17.5598 s remaining
# subpixel-averaging is 28.2053% done, 10.903 s remaining
# subpixel-averaging is 36.5013% done, 7.43606 s remaining
# subpixel-averaging is 69.685% done, 1.91008 s remaining
# subpixel-averaging is 77.9809% done, 1.21149 s remaining
# subpixel-averaging is 86.2769% done, 0.682829 s remaining
# subpixel-averaging is 95.4024% done, 0.200569 s remaining
# subpixel-averaging is 10.7839% done, 33.1477 s remaining
# subpixel-averaging is 19.0798% done, 18.3168 s remaining
# subpixel-averaging is 27.3757% done, 11.3228 s remaining
# subpixel-averaging is 35.6717% done, 7.84347 s remaining
# subpixel-averaging is 68.8554% done, 1.99848 s remaining
# subpixel-averaging is 77.1513% done, 1.2879 s remaining
# subpixel-averaging is 85.4473% done, 0.728437 s remaining
# subpixel-averaging is 93.7432% done, 0.274224 s remaining
# subpixel-averaging is 11.6135% done, 33.0272 s remaining
# subpixel-averaging is 19.9094% done, 17.6146 s remaining
# subpixel-averaging is 28.2053% done, 10.8069 s remaining
# subpixel-averaging is 36.5013% done, 7.35161 s remaining
# subpixel-averaging is 69.685% done, 1.89173 s remaining
# subpixel-averaging is 77.9809% done, 1.19539 s remaining
# subpixel-averaging is 86.2769% done, 0.678407 s remaining
# subpixel-averaging is 95.4024% done, 0.200113 s remaining
# time for set_epsilon = 113.153 s
# -----------
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Meep progress: 86.06/400.0 = 21.5% done in 4.0s, 14.6s to go
# on time step 4303 (time=86.06), 0.000929672 s/step
# Meep progress: 175.12/400.0 = 43.8% done in 8.0s, 10.3s to go
# on time step 8756 (time=175.12), 0.000898316 s/step
# Meep progress: 264.22/400.0 = 66.1% done in 12.0s, 6.2s to go
# on time step 13211 (time=264.22), 0.000897877 s/step
# Meep progress: 353.5/400.0 = 88.4% done in 16.0s, 2.1s to go
# on time step 17675 (time=353.5), 0.000896067 s/step
# run 0 finished at t = 400.0 (20000 timesteps)
# /home/311514090/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/311514090/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
