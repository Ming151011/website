# %%
import meep as mp
import numpy
import matplotlib.pyplot as plt

res = 25  # pixels/μm
three_d = False  # 3d calculation?
d = 0.06  # branch separation

gdsII_file = "coupler.gds"
CELL_LAYER = 0
PORT1_LAYER = 1
PORT2_LAYER = 2
PORT3_LAYER = 3
PORT4_LAYER = 4
SOURCE_LAYER = 5
UPPER_BRANCH_LAYER = 31
LOWER_BRANCH_LAYER = 32
default_d = 0.3

t_oxide = 1.0
t_Si = 0.22
t_air = 0.78

dpml = 1
cell_thickness = dpml + t_oxide + t_Si + t_air + dpml

oxide = mp.Medium(epsilon=2.25)
silicon = mp.Medium(epsilon=12)

lcen = 1.55
fcen = 1 / lcen
df = 0.2 * fcen

cell_zmax = 0.5 * cell_thickness if three_d else 0
cell_zmin = -0.5 * cell_thickness if three_d else 0
si_zmax = 0.5 * t_Si if three_d else 10
si_zmin = -0.5 * t_Si if three_d else -10

# read cell size, volumes for source region and flux monitors,
# and coupler geometry from GDSII file
upper_branch = mp.get_GDSII_prisms(
    silicon, gdsII_file, UPPER_BRANCH_LAYER, si_zmin, si_zmax
)
lower_branch = mp.get_GDSII_prisms(
    silicon, gdsII_file, LOWER_BRANCH_LAYER, si_zmin, si_zmax
)

cell = mp.GDSII_vol(gdsII_file, CELL_LAYER, cell_zmin, cell_zmax)
p1 = mp.GDSII_vol(gdsII_file, PORT1_LAYER, si_zmin, si_zmax)
p2 = mp.GDSII_vol(gdsII_file, PORT2_LAYER, si_zmin, si_zmax)
p3 = mp.GDSII_vol(gdsII_file, PORT3_LAYER, si_zmin, si_zmax)
p4 = mp.GDSII_vol(gdsII_file, PORT4_LAYER, si_zmin, si_zmax)
src_vol = mp.GDSII_vol(gdsII_file, SOURCE_LAYER, si_zmin, si_zmax)

# displace upper and lower branches of coupler (as well as source and flux regions)
if d != default_d:
    delta_y = 0.5 * (d - default_d)
    delta = mp.Vector3(y=delta_y)
    p1.center += delta
    p2.center -= delta
    p3.center += delta
    p4.center -= delta
    src_vol.center += delta
    cell.size += 2 * delta
    for np in range(len(lower_branch)):
        lower_branch[np].center -= delta
        for nv in range(len(lower_branch[np].vertices)):
            lower_branch[np].vertices[nv] -= delta
    for np in range(len(upper_branch)):
        upper_branch[np].center += delta
        for nv in range(len(upper_branch[np].vertices)):
            upper_branch[np].vertices[nv] += delta

geometry = upper_branch + lower_branch

if three_d:
    oxide_center = mp.Vector3(z=-0.5 * t_oxide)
    oxide_size = mp.Vector3(cell.size.x, cell.size.y, t_oxide)
    oxide_layer = [mp.Block(material=oxide, center=oxide_center, size=oxide_size)]
    geometry = geometry + oxide_layer

sources = [
    mp.EigenModeSource(
        src=mp.GaussianSource(fcen, fwidth=df),
        size=src_vol.size,
        center=src_vol.center,
        eig_band=1,
        eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z,
        eig_match_freq=True,
    )
]

sim = mp.Simulation(
    resolution=res,
    cell_size=cell.size,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
    geometry=geometry,
)

mode1 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p1))
mode2 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p2))
mode3 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p3))
mode4 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p4))

sim.run(until_after_sources=100)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0192311 s
# Working in 2D dimensions.
# Computational cell is 34.4 x 7.76 x 0 with resolution 25
#      prism, center = (-9.09425,1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-4,0.03,-10)
#           (-4.108,0.031,-10)
#           (-4.215,0.032,-10)
#           (-4.322,0.035,-10)
#           (-4.429,0.04,-10)
#           (-4.535,0.045,-10)
#           (-4.641,0.051,-10)
#           (-4.747,0.059,-10)
#           (-4.852,0.067,-10)
#           (-5.062,0.087,-10)
#           (-5.167,0.099,-10)
#           (-5.271,0.111,-10)
#           (-5.479,0.139,-10)
#           (-5.582,0.154,-10)
#           (-5.685,0.17,-10)
#           (-5.788,0.187,-10)
#           (-5.891,0.205,-10)
#           (-5.993,0.223,-10)
#           (-6.095,0.242,-10)
#           (-6.197,0.262,-10)
#           (-6.299,0.283,-10)
#           (-6.4,0.304,-10)
#           (-6.501,0.326,-10)
#           (-6.703,0.372,-10)
#           (-6.803,0.395,-10)
#           (-6.904,0.42,-10)
#           (-7.204,0.495,-10)
#           (-7.303,0.522,-10)
#           (-7.403,0.548,-10)
#           (-7.502,0.575,-10)
#           (-7.601,0.603,-10)
#           (-7.7,0.63,-10)
#           (-7.799,0.658,-10)
#           (-7.898,0.687,-10)
#           (-7.996,0.715,-10)
#           (-8.095,0.744,-10)
#           (-8.193,0.773,-10)
#           (-8.291,0.803,-10)
#           (-8.389,0.832,-10)
#           (-8.487,0.862,-10)
#           (-8.585,0.891,-10)
#           (-8.781,0.951,-10)
#           (-8.878,0.981,-10)
#           (-9.074,1.041,-10)
#           (-9.268,1.101,-10)
#           (-9.366,1.131,-10)
#           (-9.463,1.161,-10)
#           (-9.56,1.19,-10)
#           (-9.658,1.22,-10)
#           (-9.949,1.307,-10)
#           (-10.047,1.336,-10)
#           (-10.144,1.365,-10)
#           (-10.338,1.421,-10)
#           (-10.436,1.448,-10)
#           (-10.533,1.476,-10)
#           (-10.63,1.503,-10)
#           (-10.728,1.529,-10)
#           (-10.922,1.581,-10)
#           (-11.02,1.606,-10)
#           (-11.117,1.63,-10)
#           (-11.215,1.655,-10)
#           (-11.313,1.678,-10)
#           (-11.41,1.701,-10)
#           (-11.508,1.724,-10)
#           (-11.606,1.746,-10)
#           (-11.704,1.767,-10)
#           (-11.802,1.787,-10)
#           (-11.901,1.807,-10)
#           (-11.999,1.826,-10)
#           (-12.098,1.845,-10)
#           (-12.196,1.863,-10)
#           (-12.295,1.88,-10)
#           (-12.394,1.896,-10)
#           (-12.592,1.926,-10)
#           (-12.691,1.94,-10)
#           (-12.791,1.952,-10)
#           (-12.89,1.964,-10)
#           (-12.99,1.975,-10)
#           (-13.19,1.995,-10)
#           (-13.291,2.003,-10)
#           (-13.392,2.01,-10)
#           (-13.492,2.016,-10)
#           (-13.593,2.021,-10)
#           (-13.695,2.025,-10)
#           (-13.796,2.028,-10)
#           (-14,2.03,-10)
#           (-17.2,2.03,-10)
#           (-17.2,2.53,-10)
#           (-14,2.53,-10)
#           (-13.892,2.529,-10)
#           (-13.785,2.528,-10)
#           (-13.678,2.525,-10)
#           (-13.571,2.52,-10)
#           (-13.465,2.515,-10)
#           (-13.359,2.509,-10)
#           (-13.253,2.501,-10)
#           (-13.148,2.493,-10)
#           (-12.938,2.473,-10)
#           (-12.833,2.461,-10)
#           (-12.729,2.449,-10)
#           (-12.521,2.421,-10)
#           (-12.418,2.406,-10)
#           (-12.315,2.39,-10)
#           (-12.212,2.373,-10)
#           (-12.109,2.355,-10)
#           (-12.007,2.337,-10)
#           (-11.905,2.318,-10)
#           (-11.803,2.298,-10)
#           (-11.701,2.277,-10)
#           (-11.6,2.256,-10)
#           (-11.499,2.234,-10)
#           (-11.297,2.188,-10)
#           (-11.197,2.165,-10)
#           (-11.096,2.14,-10)
#           (-10.796,2.065,-10)
#           (-10.697,2.038,-10)
#           (-10.597,2.012,-10)
#           (-10.498,1.985,-10)
#           (-10.399,1.957,-10)
#           (-10.3,1.93,-10)
#           (-10.201,1.902,-10)
#           (-10.102,1.873,-10)
#           (-10.004,1.845,-10)
#           (-9.905,1.816,-10)
#           (-9.807,1.787,-10)
#           (-9.709,1.757,-10)
#           (-9.611,1.728,-10)
#           (-9.513,1.698,-10)
#           (-9.415,1.669,-10)
#           (-9.219,1.609,-10)
#           (-9.122,1.579,-10)
#           (-8.926,1.519,-10)
#           (-8.732,1.459,-10)
#           (-8.634,1.429,-10)
#           (-8.537,1.399,-10)
#           (-8.44,1.37,-10)
#           (-8.342,1.34,-10)
#           (-8.051,1.253,-10)
#           (-7.953,1.224,-10)
#           (-7.856,1.195,-10)
#           (-7.662,1.139,-10)
#           (-7.564,1.112,-10)
#           (-7.467,1.084,-10)
#           (-7.37,1.057,-10)
#           (-7.272,1.031,-10)
#           (-7.078,0.979,-10)
#           (-6.98,0.954,-10)
#           (-6.883,0.93,-10)
#           (-6.785,0.905,-10)
#           (-6.687,0.882,-10)
#           (-6.59,0.859,-10)
#           (-6.492,0.836,-10)
#           (-6.394,0.814,-10)
#           (-6.296,0.793,-10)
#           (-6.198,0.773,-10)
#           (-6.099,0.753,-10)
#           (-6.001,0.734,-10)
#           (-5.902,0.715,-10)
#           (-5.804,0.697,-10)
#           (-5.705,0.68,-10)
#           (-5.606,0.664,-10)
#           (-5.408,0.634,-10)
#           (-5.309,0.62,-10)
#           (-5.209,0.608,-10)
#           (-5.11,0.596,-10)
#           (-5.01,0.585,-10)
#           (-4.81,0.565,-10)
#           (-4.709,0.557,-10)
#           (-4.608,0.55,-10)
#           (-4.508,0.544,-10)
#           (-4.407,0.539,-10)
#           (-4.305,0.535,-10)
#           (-4.204,0.532,-10)
#           (-4,0.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (4,0.03,-10)
#           (4,0.53,-10)
#           (4.204,0.532,-10)
#           (4.305,0.535,-10)
#           (4.407,0.539,-10)
#           (4.508,0.544,-10)
#           (4.608,0.55,-10)
#           (4.709,0.557,-10)
#           (4.81,0.565,-10)
#           (5.01,0.585,-10)
#           (5.11,0.596,-10)
#           (5.209,0.608,-10)
#           (5.309,0.62,-10)
#           (5.408,0.634,-10)
#           (5.606,0.664,-10)
#           (5.705,0.68,-10)
#           (5.804,0.697,-10)
#           (5.902,0.715,-10)
#           (6.001,0.734,-10)
#           (6.099,0.753,-10)
#           (6.198,0.773,-10)
#           (6.296,0.793,-10)
#           (6.394,0.814,-10)
#           (6.492,0.836,-10)
#           (6.59,0.859,-10)
#           (6.687,0.882,-10)
#           (6.785,0.905,-10)
#           (6.883,0.93,-10)
#           (6.98,0.954,-10)
#           (7.078,0.979,-10)
#           (7.272,1.031,-10)
#           (7.37,1.057,-10)
#           (7.467,1.084,-10)
#           (7.564,1.112,-10)
#           (7.662,1.139,-10)
#           (7.856,1.195,-10)
#           (7.953,1.224,-10)
#           (8.051,1.253,-10)
#           (8.342,1.34,-10)
#           (8.44,1.37,-10)
#           (8.537,1.399,-10)
#           (8.634,1.429,-10)
#           (8.732,1.459,-10)
#           (8.926,1.519,-10)
#           (9.122,1.579,-10)
#           (9.219,1.609,-10)
#           (9.415,1.669,-10)
#           (9.513,1.698,-10)
#           (9.611,1.728,-10)
#           (9.709,1.757,-10)
#           (9.807,1.787,-10)
#           (9.905,1.816,-10)
#           (10.004,1.845,-10)
#           (10.102,1.873,-10)
#           (10.201,1.902,-10)
#           (10.3,1.93,-10)
#           (10.399,1.957,-10)
#           (10.498,1.985,-10)
#           (10.597,2.012,-10)
#           (10.697,2.038,-10)
#           (10.796,2.065,-10)
#           (11.096,2.14,-10)
#           (11.197,2.165,-10)
#           (11.297,2.188,-10)
#           (11.499,2.234,-10)
#           (11.6,2.256,-10)
#           (11.701,2.277,-10)
#           (11.803,2.298,-10)
#           (11.905,2.318,-10)
#           (12.007,2.337,-10)
#           (12.109,2.355,-10)
#           (12.212,2.373,-10)
#           (12.315,2.39,-10)
#           (12.418,2.406,-10)
#           (12.521,2.421,-10)
#           (12.729,2.449,-10)
#           (12.833,2.461,-10)
#           (12.938,2.473,-10)
#           (13.148,2.493,-10)
#           (13.253,2.501,-10)
#           (13.359,2.509,-10)
#           (13.465,2.515,-10)
#           (13.571,2.52,-10)
#           (13.678,2.525,-10)
#           (13.785,2.528,-10)
#           (13.892,2.529,-10)
#           (14,2.53,-10)
#           (17.2,2.53,-10)
#           (17.2,2.03,-10)
#           (14,2.03,-10)
#           (13.796,2.028,-10)
#           (13.695,2.025,-10)
#           (13.593,2.021,-10)
#           (13.492,2.016,-10)
#           (13.392,2.01,-10)
#           (13.291,2.003,-10)
#           (13.19,1.995,-10)
#           (12.99,1.975,-10)
#           (12.89,1.964,-10)
#           (12.791,1.952,-10)
#           (12.691,1.94,-10)
#           (12.592,1.926,-10)
#           (12.394,1.896,-10)
#           (12.295,1.88,-10)
#           (12.196,1.863,-10)
#           (12.098,1.845,-10)
#           (11.999,1.826,-10)
#           (11.901,1.807,-10)
#           (11.802,1.787,-10)
#           (11.704,1.767,-10)
#           (11.606,1.746,-10)
#           (11.508,1.724,-10)
#           (11.41,1.701,-10)
#           (11.313,1.678,-10)
#           (11.215,1.655,-10)
#           (11.117,1.63,-10)
#           (11.02,1.606,-10)
#           (10.922,1.581,-10)
#           (10.728,1.529,-10)
#           (10.63,1.503,-10)
#           (10.533,1.476,-10)
#           (10.436,1.448,-10)
#           (10.338,1.421,-10)
#           (10.144,1.365,-10)
#           (10.047,1.336,-10)
#           (9.949,1.307,-10)
#           (9.658,1.22,-10)
#           (9.56,1.19,-10)
#           (9.463,1.161,-10)
#           (9.366,1.131,-10)
#           (9.268,1.101,-10)
#           (9.074,1.041,-10)
#           (8.878,0.981,-10)
#           (8.781,0.951,-10)
#           (8.585,0.891,-10)
#           (8.487,0.862,-10)
#           (8.389,0.832,-10)
#           (8.291,0.803,-10)
#           (8.193,0.773,-10)
#           (8.095,0.744,-10)
#           (7.996,0.715,-10)
#           (7.898,0.687,-10)
#           (7.799,0.658,-10)
#           (7.7,0.63,-10)
#           (7.601,0.603,-10)
#           (7.502,0.575,-10)
#           (7.403,0.548,-10)
#           (7.303,0.522,-10)
#           (7.204,0.495,-10)
#           (6.904,0.42,-10)
#           (6.803,0.395,-10)
#           (6.703,0.372,-10)
#           (6.501,0.326,-10)
#           (6.4,0.304,-10)
#           (6.299,0.283,-10)
#           (6.197,0.262,-10)
#           (6.095,0.242,-10)
#           (5.993,0.223,-10)
#           (5.891,0.205,-10)
#           (5.788,0.187,-10)
#           (5.685,0.17,-10)
#           (5.582,0.154,-10)
#           (5.479,0.139,-10)
#           (5.271,0.111,-10)
#           (5.167,0.099,-10)
#           (5.062,0.087,-10)
#           (4.852,0.067,-10)
#           (4.747,0.059,-10)
#           (4.641,0.051,-10)
#           (4.535,0.045,-10)
#           (4.429,0.04,-10)
#           (4.322,0.035,-10)
#           (4.215,0.032,-10)
#           (4.108,0.031,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,0.28,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,0.03,-10)
#           (-4,0.53,-10)
#           (4,0.53,-10)
#           (4,0.03,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (-9.09425,-1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-17.2,-2.53,-10)
#           (-17.2,-2.03,-10)
#           (-14,-2.03,-10)
#           (-13.796,-2.028,-10)
#           (-13.695,-2.025,-10)
#           (-13.593,-2.021,-10)
#           (-13.492,-2.016,-10)
#           (-13.392,-2.01,-10)
#           (-13.291,-2.003,-10)
#           (-13.19,-1.995,-10)
#           (-12.99,-1.975,-10)
#           (-12.89,-1.964,-10)
#           (-12.791,-1.952,-10)
#           (-12.691,-1.94,-10)
#           (-12.592,-1.926,-10)
#           (-12.394,-1.896,-10)
#           (-12.295,-1.88,-10)
#           (-12.196,-1.863,-10)
#           (-12.098,-1.845,-10)
#           (-11.999,-1.826,-10)
#           (-11.901,-1.807,-10)
#           (-11.802,-1.787,-10)
#           (-11.704,-1.767,-10)
#           (-11.606,-1.746,-10)
#           (-11.508,-1.724,-10)
#           (-11.41,-1.701,-10)
#           (-11.313,-1.678,-10)
#           (-11.215,-1.655,-10)
#           (-11.117,-1.63,-10)
#           (-11.02,-1.606,-10)
#           (-10.922,-1.581,-10)
#           (-10.728,-1.529,-10)
#           (-10.63,-1.503,-10)
#           (-10.533,-1.476,-10)
#           (-10.436,-1.448,-10)
#           (-10.338,-1.421,-10)
#           (-10.144,-1.365,-10)
#           (-10.047,-1.336,-10)
#           (-9.949,-1.307,-10)
#           (-9.658,-1.22,-10)
#           (-9.56,-1.19,-10)
#           (-9.463,-1.161,-10)
#           (-9.366,-1.131,-10)
#           (-9.268,-1.101,-10)
#           (-9.074,-1.041,-10)
#           (-8.878,-0.981,-10)
#           (-8.781,-0.951,-10)
#           (-8.585,-0.891,-10)
#           (-8.487,-0.862,-10)
#           (-8.389,-0.832,-10)
#           (-8.291,-0.803,-10)
#           (-8.193,-0.773,-10)
#           (-8.095,-0.744,-10)
#           (-7.996,-0.715,-10)
#           (-7.898,-0.687,-10)
#           (-7.799,-0.658,-10)
#           (-7.7,-0.63,-10)
#           (-7.601,-0.603,-10)
#           (-7.502,-0.575,-10)
#           (-7.403,-0.548,-10)
#           (-7.303,-0.522,-10)
#           (-7.204,-0.495,-10)
#           (-6.904,-0.42,-10)
#           (-6.803,-0.395,-10)
#           (-6.703,-0.372,-10)
#           (-6.501,-0.326,-10)
#           (-6.4,-0.304,-10)
#           (-6.299,-0.283,-10)
#           (-6.197,-0.262,-10)
#           (-6.095,-0.242,-10)
#           (-5.993,-0.223,-10)
#           (-5.891,-0.205,-10)
#           (-5.788,-0.187,-10)
#           (-5.685,-0.17,-10)
#           (-5.582,-0.154,-10)
#           (-5.479,-0.139,-10)
#           (-5.271,-0.111,-10)
#           (-5.167,-0.099,-10)
#           (-5.062,-0.087,-10)
#           (-4.852,-0.067,-10)
#           (-4.747,-0.059,-10)
#           (-4.641,-0.051,-10)
#           (-4.535,-0.045,-10)
#           (-4.429,-0.04,-10)
#           (-4.322,-0.035,-10)
#           (-4.215,-0.032,-10)
#           (-4.108,-0.031,-10)
#           (-4,-0.03,-10)
#           (-4,-0.53,-10)
#           (-4.204,-0.532,-10)
#           (-4.305,-0.535,-10)
#           (-4.407,-0.539,-10)
#           (-4.508,-0.544,-10)
#           (-4.608,-0.55,-10)
#           (-4.709,-0.557,-10)
#           (-4.81,-0.565,-10)
#           (-5.01,-0.585,-10)
#           (-5.11,-0.596,-10)
#           (-5.209,-0.608,-10)
#           (-5.309,-0.62,-10)
#           (-5.408,-0.634,-10)
#           (-5.606,-0.664,-10)
#           (-5.705,-0.68,-10)
#           (-5.804,-0.697,-10)
#           (-5.902,-0.715,-10)
#           (-6.001,-0.734,-10)
#           (-6.099,-0.753,-10)
#           (-6.198,-0.773,-10)
#           (-6.296,-0.793,-10)
#           (-6.394,-0.814,-10)
#           (-6.492,-0.836,-10)
#           (-6.59,-0.859,-10)
#           (-6.687,-0.882,-10)
#           (-6.785,-0.905,-10)
#           (-6.883,-0.93,-10)
#           (-6.98,-0.954,-10)
#           (-7.078,-0.979,-10)
#           (-7.272,-1.031,-10)
#           (-7.37,-1.057,-10)
#           (-7.467,-1.084,-10)
#           (-7.564,-1.112,-10)
#           (-7.662,-1.139,-10)
#           (-7.856,-1.195,-10)
#           (-7.953,-1.224,-10)
#           (-8.051,-1.253,-10)
#           (-8.342,-1.34,-10)
#           (-8.44,-1.37,-10)
#           (-8.537,-1.399,-10)
#           (-8.634,-1.429,-10)
#           (-8.732,-1.459,-10)
#           (-8.926,-1.519,-10)
#           (-9.122,-1.579,-10)
#           (-9.219,-1.609,-10)
#           (-9.415,-1.669,-10)
#           (-9.513,-1.698,-10)
#           (-9.611,-1.728,-10)
#           (-9.709,-1.757,-10)
#           (-9.807,-1.787,-10)
#           (-9.905,-1.816,-10)
#           (-10.004,-1.845,-10)
#           (-10.102,-1.873,-10)
#           (-10.201,-1.902,-10)
#           (-10.3,-1.93,-10)
#           (-10.399,-1.957,-10)
#           (-10.498,-1.985,-10)
#           (-10.597,-2.012,-10)
#           (-10.697,-2.038,-10)
#           (-10.796,-2.065,-10)
#           (-11.096,-2.14,-10)
#           (-11.197,-2.165,-10)
#           (-11.297,-2.188,-10)
#           (-11.499,-2.234,-10)
#           (-11.6,-2.256,-10)
#           (-11.701,-2.277,-10)
#           (-11.803,-2.298,-10)
#           (-11.905,-2.318,-10)
#           (-12.007,-2.337,-10)
#           (-12.109,-2.355,-10)
#           (-12.212,-2.373,-10)
#           (-12.315,-2.39,-10)
#           (-12.418,-2.406,-10)
#           (-12.521,-2.421,-10)
#           (-12.729,-2.449,-10)
#           (-12.833,-2.461,-10)
#           (-12.938,-2.473,-10)
#           (-13.148,-2.493,-10)
#           (-13.253,-2.501,-10)
#           (-13.359,-2.509,-10)
#           (-13.465,-2.515,-10)
#           (-13.571,-2.52,-10)
#           (-13.678,-2.525,-10)
#           (-13.785,-2.528,-10)
#           (-13.892,-2.529,-10)
#           (-14,-2.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,-1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (14,-2.53,-10)
#           (13.892,-2.529,-10)
#           (13.785,-2.528,-10)
#           (13.678,-2.525,-10)
#           (13.571,-2.52,-10)
#           (13.465,-2.515,-10)
#           (13.359,-2.509,-10)
#           (13.253,-2.501,-10)
#           (13.148,-2.493,-10)
#           (12.938,-2.473,-10)
#           (12.833,-2.461,-10)
#           (12.729,-2.449,-10)
#           (12.521,-2.421,-10)
#           (12.418,-2.406,-10)
#           (12.315,-2.39,-10)
#           (12.212,-2.373,-10)
#           (12.109,-2.355,-10)
#           (12.007,-2.337,-10)
#           (11.905,-2.318,-10)
#           (11.803,-2.298,-10)
#           (11.701,-2.277,-10)
#           (11.6,-2.256,-10)
#           (11.499,-2.234,-10)
#           (11.297,-2.188,-10)
#           (11.197,-2.165,-10)
#           (11.096,-2.14,-10)
#           (10.796,-2.065,-10)
#           (10.697,-2.038,-10)
#           (10.597,-2.012,-10)
#           (10.498,-1.985,-10)
#           (10.399,-1.957,-10)
#           (10.3,-1.93,-10)
#           (10.201,-1.902,-10)
#           (10.102,-1.873,-10)
#           (10.004,-1.845,-10)
#           (9.905,-1.816,-10)
#           (9.807,-1.787,-10)
#           (9.709,-1.757,-10)
#           (9.611,-1.728,-10)
#           (9.513,-1.698,-10)
#           (9.415,-1.669,-10)
#           (9.219,-1.609,-10)
#           (9.122,-1.579,-10)
#           (8.926,-1.519,-10)
#           (8.732,-1.459,-10)
#           (8.634,-1.429,-10)
#           (8.537,-1.399,-10)
#           (8.44,-1.37,-10)
#           (8.342,-1.34,-10)
#           (8.051,-1.253,-10)
#           (7.953,-1.224,-10)
#           (7.856,-1.195,-10)
#           (7.662,-1.139,-10)
#           (7.564,-1.112,-10)
#           (7.467,-1.084,-10)
#           (7.37,-1.057,-10)
#           (7.272,-1.031,-10)
#           (7.078,-0.979,-10)
#           (6.98,-0.954,-10)
#           (6.883,-0.93,-10)
#           (6.785,-0.905,-10)
#           (6.687,-0.882,-10)
#           (6.59,-0.859,-10)
#           (6.492,-0.836,-10)
#           (6.394,-0.814,-10)
#           (6.296,-0.793,-10)
#           (6.198,-0.773,-10)
#           (6.099,-0.753,-10)
#           (6.001,-0.734,-10)
#           (5.902,-0.715,-10)
#           (5.804,-0.697,-10)
#           (5.705,-0.68,-10)
#           (5.606,-0.664,-10)
#           (5.408,-0.634,-10)
#           (5.309,-0.62,-10)
#           (5.209,-0.608,-10)
#           (5.11,-0.596,-10)
#           (5.01,-0.585,-10)
#           (4.81,-0.565,-10)
#           (4.709,-0.557,-10)
#           (4.608,-0.55,-10)
#           (4.508,-0.544,-10)
#           (4.407,-0.539,-10)
#           (4.305,-0.535,-10)
#           (4.204,-0.532,-10)
#           (4,-0.53,-10)
#           (4,-0.03,-10)
#           (4.108,-0.031,-10)
#           (4.215,-0.032,-10)
#           (4.322,-0.035,-10)
#           (4.429,-0.04,-10)
#           (4.535,-0.045,-10)
#           (4.641,-0.051,-10)
#           (4.747,-0.059,-10)
#           (4.852,-0.067,-10)
#           (5.062,-0.087,-10)
#           (5.167,-0.099,-10)
#           (5.271,-0.111,-10)
#           (5.479,-0.139,-10)
#           (5.582,-0.154,-10)
#           (5.685,-0.17,-10)
#           (5.788,-0.187,-10)
#           (5.891,-0.205,-10)
#           (5.993,-0.223,-10)
#           (6.095,-0.242,-10)
#           (6.197,-0.262,-10)
#           (6.299,-0.283,-10)
#           (6.4,-0.304,-10)
#           (6.501,-0.326,-10)
#           (6.703,-0.372,-10)
#           (6.803,-0.395,-10)
#           (6.904,-0.42,-10)
#           (7.204,-0.495,-10)
#           (7.303,-0.522,-10)
#           (7.403,-0.548,-10)
#           (7.502,-0.575,-10)
#           (7.601,-0.603,-10)
#           (7.7,-0.63,-10)
#           (7.799,-0.658,-10)
#           (7.898,-0.687,-10)
#           (7.996,-0.715,-10)
#           (8.095,-0.744,-10)
#           (8.193,-0.773,-10)
#           (8.291,-0.803,-10)
#           (8.389,-0.832,-10)
#           (8.487,-0.862,-10)
#           (8.585,-0.891,-10)
#           (8.781,-0.951,-10)
#           (8.878,-0.981,-10)
#           (9.074,-1.041,-10)
#           (9.268,-1.101,-10)
#           (9.366,-1.131,-10)
#           (9.463,-1.161,-10)
#           (9.56,-1.19,-10)
#           (9.658,-1.22,-10)
#           (9.949,-1.307,-10)
#           (10.047,-1.336,-10)
#           (10.144,-1.365,-10)
#           (10.338,-1.421,-10)
#           (10.436,-1.448,-10)
#           (10.533,-1.476,-10)
#           (10.63,-1.503,-10)
#           (10.728,-1.529,-10)
#           (10.922,-1.581,-10)
#           (11.02,-1.606,-10)
#           (11.117,-1.63,-10)
#           (11.215,-1.655,-10)
#           (11.313,-1.678,-10)
#           (11.41,-1.701,-10)
#           (11.508,-1.724,-10)
#           (11.606,-1.746,-10)
#           (11.704,-1.767,-10)
#           (11.802,-1.787,-10)
#           (11.901,-1.807,-10)
#           (11.999,-1.826,-10)
#           (12.098,-1.845,-10)
#           (12.196,-1.863,-10)
#           (12.295,-1.88,-10)
#           (12.394,-1.896,-10)
#           (12.592,-1.926,-10)
#           (12.691,-1.94,-10)
#           (12.791,-1.952,-10)
#           (12.89,-1.964,-10)
#           (12.99,-1.975,-10)
#           (13.19,-1.995,-10)
#           (13.291,-2.003,-10)
#           (13.392,-2.01,-10)
#           (13.492,-2.016,-10)
#           (13.593,-2.021,-10)
#           (13.695,-2.025,-10)
#           (13.796,-2.028,-10)
#           (14,-2.03,-10)
#           (17.2,-2.03,-10)
#           (17.2,-2.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,-0.28,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,-0.53,-10)
#           (-4,-0.03,-10)
#           (4,-0.03,-10)
#           (4,-0.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 11.2364% done, 33.0633 s remaining
# subpixel-averaging is 19.016% done, 17.2409 s remaining
# subpixel-averaging is 26.7956% done, 10.9707 s remaining
# subpixel-averaging is 34.5752% done, 7.59455 s remaining
# subpixel-averaging is 67.4224% done, 2.02778 s remaining
# subpixel-averaging is 75.2021% done, 1.32857 s remaining
# subpixel-averaging is 83.8461% done, 0.85698 s remaining
# subpixel-averaging is 91.6257% done, 0.366062 s remaining
# subpixel-averaging is 11.2364% done, 33.2493 s remaining
# subpixel-averaging is 19.016% done, 17.1255 s remaining
# subpixel-averaging is 27.66% done, 11.5883 s remaining
# subpixel-averaging is 35.4396% done, 7.35209 s remaining
# subpixel-averaging is 68.2868% done, 1.96087 s remaining
# subpixel-averaging is 76.0665% done, 1.27602 s remaining
# subpixel-averaging is 83.8461% done, 0.773213 s remaining
# subpixel-averaging is 91.6257% done, 0.369297 s remaining
# subpixel-averaging is 10.372% done, 34.7408 s remaining
# subpixel-averaging is 18.1516% done, 18.4491 s remaining
# subpixel-averaging is 25.9312% done, 11.5329 s remaining
# subpixel-averaging is 33.7108% done, 7.9356 s remaining
# subpixel-averaging is 66.558% done, 2.16233 s remaining
# subpixel-averaging is 74.3377% done, 1.39379 s remaining
# subpixel-averaging is 82.9817% done, 0.908464 s remaining
# subpixel-averaging is 90.7613% done, 0.410795 s remaining
# time for set_epsilon = 113.66 s
# -----------
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Meep progress: 86.24/177.5 = 48.6% done in 4.0s, 4.2s to go
# on time step 4312 (time=86.24), 0.000927703 s/step
# Meep progress: 175.22/177.5 = 98.7% done in 8.0s, 0.1s to go
# on time step 8762 (time=175.24), 0.000899012 s/step
# run 0 finished at t = 177.5 (8875 timesteps)

# %%
# S parameters
p1_coeff = sim.get_eigenmode_coefficients(
    mode1, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]
p2_coeff = sim.get_eigenmode_coefficients(
    mode2, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 1]
p3_coeff = sim.get_eigenmode_coefficients(
    mode3, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]
p4_coeff = sim.get_eigenmode_coefficients(
    mode4, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]

# transmittance
p2_trans = abs(p2_coeff) ** 2 / abs(p1_coeff) ** 2
p3_trans = abs(p3_coeff) ** 2 / abs(p1_coeff) ** 2
p4_trans = abs(p4_coeff) ** 2 / abs(p1_coeff) ** 2

print("trans:, {:.2f}, {:.6f}, {:.6f}, {:.6f}".format(d, p2_trans, p3_trans, p4_trans))
# Out:
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.091129,-0.000000,0.000000)
# trans:, 0.06, 0.000001, 0.069793, 0.913117

# %%
sim.reset_meep()

sources = [
    mp.EigenModeSource(
        src=mp.ContinuousSource(fcen, fwidth=df),
        size=src_vol.size,
        center=src_vol.center,
        eig_band=1,
        eig_parity=mp.EVEN_Y + mp.ODD_Z,
        eig_match_freq=True,
    )
]

sim = mp.Simulation(
    resolution=res,
    cell_size=cell.size,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
    geometry=geometry,
)

sim.run(
    until=400
)  # arbitrary long run time to ensure that fields have reached steady state

eps_data = sim.get_epsilon()
ez_data = numpy.real(sim.get_efield_z())

plt.figure(dpi=200)
plt.imshow(numpy.transpose(eps_data), interpolation="spline36", cmap="binary")
plt.imshow(
    numpy.flipud(numpy.transpose(ez_data)),
    interpolation="spline36",
    cmap="RdBu",
    alpha=0.9,
)
plt.axis("off")
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0191531 s
# Working in 2D dimensions.
# Computational cell is 34.4 x 7.76 x 0 with resolution 25
#      prism, center = (-9.09425,1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-4,0.03,-10)
#           (-4.108,0.031,-10)
#           (-4.215,0.032,-10)
#           (-4.322,0.035,-10)
#           (-4.429,0.04,-10)
#           (-4.535,0.045,-10)
#           (-4.641,0.051,-10)
#           (-4.747,0.059,-10)
#           (-4.852,0.067,-10)
#           (-5.062,0.087,-10)
#           (-5.167,0.099,-10)
#           (-5.271,0.111,-10)
#           (-5.479,0.139,-10)
#           (-5.582,0.154,-10)
#           (-5.685,0.17,-10)
#           (-5.788,0.187,-10)
#           (-5.891,0.205,-10)
#           (-5.993,0.223,-10)
#           (-6.095,0.242,-10)
#           (-6.197,0.262,-10)
#           (-6.299,0.283,-10)
#           (-6.4,0.304,-10)
#           (-6.501,0.326,-10)
#           (-6.703,0.372,-10)
#           (-6.803,0.395,-10)
#           (-6.904,0.42,-10)
#           (-7.204,0.495,-10)
#           (-7.303,0.522,-10)
#           (-7.403,0.548,-10)
#           (-7.502,0.575,-10)
#           (-7.601,0.603,-10)
#           (-7.7,0.63,-10)
#           (-7.799,0.658,-10)
#           (-7.898,0.687,-10)
#           (-7.996,0.715,-10)
#           (-8.095,0.744,-10)
#           (-8.193,0.773,-10)
#           (-8.291,0.803,-10)
#           (-8.389,0.832,-10)
#           (-8.487,0.862,-10)
#           (-8.585,0.891,-10)
#           (-8.781,0.951,-10)
#           (-8.878,0.981,-10)
#           (-9.074,1.041,-10)
#           (-9.268,1.101,-10)
#           (-9.366,1.131,-10)
#           (-9.463,1.161,-10)
#           (-9.56,1.19,-10)
#           (-9.658,1.22,-10)
#           (-9.949,1.307,-10)
#           (-10.047,1.336,-10)
#           (-10.144,1.365,-10)
#           (-10.338,1.421,-10)
#           (-10.436,1.448,-10)
#           (-10.533,1.476,-10)
#           (-10.63,1.503,-10)
#           (-10.728,1.529,-10)
#           (-10.922,1.581,-10)
#           (-11.02,1.606,-10)
#           (-11.117,1.63,-10)
#           (-11.215,1.655,-10)
#           (-11.313,1.678,-10)
#           (-11.41,1.701,-10)
#           (-11.508,1.724,-10)
#           (-11.606,1.746,-10)
#           (-11.704,1.767,-10)
#           (-11.802,1.787,-10)
#           (-11.901,1.807,-10)
#           (-11.999,1.826,-10)
#           (-12.098,1.845,-10)
#           (-12.196,1.863,-10)
#           (-12.295,1.88,-10)
#           (-12.394,1.896,-10)
#           (-12.592,1.926,-10)
#           (-12.691,1.94,-10)
#           (-12.791,1.952,-10)
#           (-12.89,1.964,-10)
#           (-12.99,1.975,-10)
#           (-13.19,1.995,-10)
#           (-13.291,2.003,-10)
#           (-13.392,2.01,-10)
#           (-13.492,2.016,-10)
#           (-13.593,2.021,-10)
#           (-13.695,2.025,-10)
#           (-13.796,2.028,-10)
#           (-14,2.03,-10)
#           (-17.2,2.03,-10)
#           (-17.2,2.53,-10)
#           (-14,2.53,-10)
#           (-13.892,2.529,-10)
#           (-13.785,2.528,-10)
#           (-13.678,2.525,-10)
#           (-13.571,2.52,-10)
#           (-13.465,2.515,-10)
#           (-13.359,2.509,-10)
#           (-13.253,2.501,-10)
#           (-13.148,2.493,-10)
#           (-12.938,2.473,-10)
#           (-12.833,2.461,-10)
#           (-12.729,2.449,-10)
#           (-12.521,2.421,-10)
#           (-12.418,2.406,-10)
#           (-12.315,2.39,-10)
#           (-12.212,2.373,-10)
#           (-12.109,2.355,-10)
#           (-12.007,2.337,-10)
#           (-11.905,2.318,-10)
#           (-11.803,2.298,-10)
#           (-11.701,2.277,-10)
#           (-11.6,2.256,-10)
#           (-11.499,2.234,-10)
#           (-11.297,2.188,-10)
#           (-11.197,2.165,-10)
#           (-11.096,2.14,-10)
#           (-10.796,2.065,-10)
#           (-10.697,2.038,-10)
#           (-10.597,2.012,-10)
#           (-10.498,1.985,-10)
#           (-10.399,1.957,-10)
#           (-10.3,1.93,-10)
#           (-10.201,1.902,-10)
#           (-10.102,1.873,-10)
#           (-10.004,1.845,-10)
#           (-9.905,1.816,-10)
#           (-9.807,1.787,-10)
#           (-9.709,1.757,-10)
#           (-9.611,1.728,-10)
#           (-9.513,1.698,-10)
#           (-9.415,1.669,-10)
#           (-9.219,1.609,-10)
#           (-9.122,1.579,-10)
#           (-8.926,1.519,-10)
#           (-8.732,1.459,-10)
#           (-8.634,1.429,-10)
#           (-8.537,1.399,-10)
#           (-8.44,1.37,-10)
#           (-8.342,1.34,-10)
#           (-8.051,1.253,-10)
#           (-7.953,1.224,-10)
#           (-7.856,1.195,-10)
#           (-7.662,1.139,-10)
#           (-7.564,1.112,-10)
#           (-7.467,1.084,-10)
#           (-7.37,1.057,-10)
#           (-7.272,1.031,-10)
#           (-7.078,0.979,-10)
#           (-6.98,0.954,-10)
#           (-6.883,0.93,-10)
#           (-6.785,0.905,-10)
#           (-6.687,0.882,-10)
#           (-6.59,0.859,-10)
#           (-6.492,0.836,-10)
#           (-6.394,0.814,-10)
#           (-6.296,0.793,-10)
#           (-6.198,0.773,-10)
#           (-6.099,0.753,-10)
#           (-6.001,0.734,-10)
#           (-5.902,0.715,-10)
#           (-5.804,0.697,-10)
#           (-5.705,0.68,-10)
#           (-5.606,0.664,-10)
#           (-5.408,0.634,-10)
#           (-5.309,0.62,-10)
#           (-5.209,0.608,-10)
#           (-5.11,0.596,-10)
#           (-5.01,0.585,-10)
#           (-4.81,0.565,-10)
#           (-4.709,0.557,-10)
#           (-4.608,0.55,-10)
#           (-4.508,0.544,-10)
#           (-4.407,0.539,-10)
#           (-4.305,0.535,-10)
#           (-4.204,0.532,-10)
#           (-4,0.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (4,0.03,-10)
#           (4,0.53,-10)
#           (4.204,0.532,-10)
#           (4.305,0.535,-10)
#           (4.407,0.539,-10)
#           (4.508,0.544,-10)
#           (4.608,0.55,-10)
#           (4.709,0.557,-10)
#           (4.81,0.565,-10)
#           (5.01,0.585,-10)
#           (5.11,0.596,-10)
#           (5.209,0.608,-10)
#           (5.309,0.62,-10)
#           (5.408,0.634,-10)
#           (5.606,0.664,-10)
#           (5.705,0.68,-10)
#           (5.804,0.697,-10)
#           (5.902,0.715,-10)
#           (6.001,0.734,-10)
#           (6.099,0.753,-10)
#           (6.198,0.773,-10)
#           (6.296,0.793,-10)
#           (6.394,0.814,-10)
#           (6.492,0.836,-10)
#           (6.59,0.859,-10)
#           (6.687,0.882,-10)
#           (6.785,0.905,-10)
#           (6.883,0.93,-10)
#           (6.98,0.954,-10)
#           (7.078,0.979,-10)
#           (7.272,1.031,-10)
#           (7.37,1.057,-10)
#           (7.467,1.084,-10)
#           (7.564,1.112,-10)
#           (7.662,1.139,-10)
#           (7.856,1.195,-10)
#           (7.953,1.224,-10)
#           (8.051,1.253,-10)
#           (8.342,1.34,-10)
#           (8.44,1.37,-10)
#           (8.537,1.399,-10)
#           (8.634,1.429,-10)
#           (8.732,1.459,-10)
#           (8.926,1.519,-10)
#           (9.122,1.579,-10)
#           (9.219,1.609,-10)
#           (9.415,1.669,-10)
#           (9.513,1.698,-10)
#           (9.611,1.728,-10)
#           (9.709,1.757,-10)
#           (9.807,1.787,-10)
#           (9.905,1.816,-10)
#           (10.004,1.845,-10)
#           (10.102,1.873,-10)
#           (10.201,1.902,-10)
#           (10.3,1.93,-10)
#           (10.399,1.957,-10)
#           (10.498,1.985,-10)
#           (10.597,2.012,-10)
#           (10.697,2.038,-10)
#           (10.796,2.065,-10)
#           (11.096,2.14,-10)
#           (11.197,2.165,-10)
#           (11.297,2.188,-10)
#           (11.499,2.234,-10)
#           (11.6,2.256,-10)
#           (11.701,2.277,-10)
#           (11.803,2.298,-10)
#           (11.905,2.318,-10)
#           (12.007,2.337,-10)
#           (12.109,2.355,-10)
#           (12.212,2.373,-10)
#           (12.315,2.39,-10)
#           (12.418,2.406,-10)
#           (12.521,2.421,-10)
#           (12.729,2.449,-10)
#           (12.833,2.461,-10)
#           (12.938,2.473,-10)
#           (13.148,2.493,-10)
#           (13.253,2.501,-10)
#           (13.359,2.509,-10)
#           (13.465,2.515,-10)
#           (13.571,2.52,-10)
#           (13.678,2.525,-10)
#           (13.785,2.528,-10)
#           (13.892,2.529,-10)
#           (14,2.53,-10)
#           (17.2,2.53,-10)
#           (17.2,2.03,-10)
#           (14,2.03,-10)
#           (13.796,2.028,-10)
#           (13.695,2.025,-10)
#           (13.593,2.021,-10)
#           (13.492,2.016,-10)
#           (13.392,2.01,-10)
#           (13.291,2.003,-10)
#           (13.19,1.995,-10)
#           (12.99,1.975,-10)
#           (12.89,1.964,-10)
#           (12.791,1.952,-10)
#           (12.691,1.94,-10)
#           (12.592,1.926,-10)
#           (12.394,1.896,-10)
#           (12.295,1.88,-10)
#           (12.196,1.863,-10)
#           (12.098,1.845,-10)
#           (11.999,1.826,-10)
#           (11.901,1.807,-10)
#           (11.802,1.787,-10)
#           (11.704,1.767,-10)
#           (11.606,1.746,-10)
#           (11.508,1.724,-10)
#           (11.41,1.701,-10)
#           (11.313,1.678,-10)
#           (11.215,1.655,-10)
#           (11.117,1.63,-10)
#           (11.02,1.606,-10)
#           (10.922,1.581,-10)
#           (10.728,1.529,-10)
#           (10.63,1.503,-10)
#           (10.533,1.476,-10)
#           (10.436,1.448,-10)
#           (10.338,1.421,-10)
#           (10.144,1.365,-10)
#           (10.047,1.336,-10)
#           (9.949,1.307,-10)
#           (9.658,1.22,-10)
#           (9.56,1.19,-10)
#           (9.463,1.161,-10)
#           (9.366,1.131,-10)
#           (9.268,1.101,-10)
#           (9.074,1.041,-10)
#           (8.878,0.981,-10)
#           (8.781,0.951,-10)
#           (8.585,0.891,-10)
#           (8.487,0.862,-10)
#           (8.389,0.832,-10)
#           (8.291,0.803,-10)
#           (8.193,0.773,-10)
#           (8.095,0.744,-10)
#           (7.996,0.715,-10)
#           (7.898,0.687,-10)
#           (7.799,0.658,-10)
#           (7.7,0.63,-10)
#           (7.601,0.603,-10)
#           (7.502,0.575,-10)
#           (7.403,0.548,-10)
#           (7.303,0.522,-10)
#           (7.204,0.495,-10)
#           (6.904,0.42,-10)
#           (6.803,0.395,-10)
#           (6.703,0.372,-10)
#           (6.501,0.326,-10)
#           (6.4,0.304,-10)
#           (6.299,0.283,-10)
#           (6.197,0.262,-10)
#           (6.095,0.242,-10)
#           (5.993,0.223,-10)
#           (5.891,0.205,-10)
#           (5.788,0.187,-10)
#           (5.685,0.17,-10)
#           (5.582,0.154,-10)
#           (5.479,0.139,-10)
#           (5.271,0.111,-10)
#           (5.167,0.099,-10)
#           (5.062,0.087,-10)
#           (4.852,0.067,-10)
#           (4.747,0.059,-10)
#           (4.641,0.051,-10)
#           (4.535,0.045,-10)
#           (4.429,0.04,-10)
#           (4.322,0.035,-10)
#           (4.215,0.032,-10)
#           (4.108,0.031,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,0.28,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,0.03,-10)
#           (-4,0.53,-10)
#           (4,0.53,-10)
#           (4,0.03,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (-9.09425,-1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-17.2,-2.53,-10)
#           (-17.2,-2.03,-10)
#           (-14,-2.03,-10)
#           (-13.796,-2.028,-10)
#           (-13.695,-2.025,-10)
#           (-13.593,-2.021,-10)
#           (-13.492,-2.016,-10)
#           (-13.392,-2.01,-10)
#           (-13.291,-2.003,-10)
#           (-13.19,-1.995,-10)
#           (-12.99,-1.975,-10)
#           (-12.89,-1.964,-10)
#           (-12.791,-1.952,-10)
#           (-12.691,-1.94,-10)
#           (-12.592,-1.926,-10)
#           (-12.394,-1.896,-10)
#           (-12.295,-1.88,-10)
#           (-12.196,-1.863,-10)
#           (-12.098,-1.845,-10)
#           (-11.999,-1.826,-10)
#           (-11.901,-1.807,-10)
#           (-11.802,-1.787,-10)
#           (-11.704,-1.767,-10)
#           (-11.606,-1.746,-10)
#           (-11.508,-1.724,-10)
#           (-11.41,-1.701,-10)
#           (-11.313,-1.678,-10)
#           (-11.215,-1.655,-10)
#           (-11.117,-1.63,-10)
#           (-11.02,-1.606,-10)
#           (-10.922,-1.581,-10)
#           (-10.728,-1.529,-10)
#           (-10.63,-1.503,-10)
#           (-10.533,-1.476,-10)
#           (-10.436,-1.448,-10)
#           (-10.338,-1.421,-10)
#           (-10.144,-1.365,-10)
#           (-10.047,-1.336,-10)
#           (-9.949,-1.307,-10)
#           (-9.658,-1.22,-10)
#           (-9.56,-1.19,-10)
#           (-9.463,-1.161,-10)
#           (-9.366,-1.131,-10)
#           (-9.268,-1.101,-10)
#           (-9.074,-1.041,-10)
#           (-8.878,-0.981,-10)
#           (-8.781,-0.951,-10)
#           (-8.585,-0.891,-10)
#           (-8.487,-0.862,-10)
#           (-8.389,-0.832,-10)
#           (-8.291,-0.803,-10)
#           (-8.193,-0.773,-10)
#           (-8.095,-0.744,-10)
#           (-7.996,-0.715,-10)
#           (-7.898,-0.687,-10)
#           (-7.799,-0.658,-10)
#           (-7.7,-0.63,-10)
#           (-7.601,-0.603,-10)
#           (-7.502,-0.575,-10)
#           (-7.403,-0.548,-10)
#           (-7.303,-0.522,-10)
#           (-7.204,-0.495,-10)
#           (-6.904,-0.42,-10)
#           (-6.803,-0.395,-10)
#           (-6.703,-0.372,-10)
#           (-6.501,-0.326,-10)
#           (-6.4,-0.304,-10)
#           (-6.299,-0.283,-10)
#           (-6.197,-0.262,-10)
#           (-6.095,-0.242,-10)
#           (-5.993,-0.223,-10)
#           (-5.891,-0.205,-10)
#           (-5.788,-0.187,-10)
#           (-5.685,-0.17,-10)
#           (-5.582,-0.154,-10)
#           (-5.479,-0.139,-10)
#           (-5.271,-0.111,-10)
#           (-5.167,-0.099,-10)
#           (-5.062,-0.087,-10)
#           (-4.852,-0.067,-10)
#           (-4.747,-0.059,-10)
#           (-4.641,-0.051,-10)
#           (-4.535,-0.045,-10)
#           (-4.429,-0.04,-10)
#           (-4.322,-0.035,-10)
#           (-4.215,-0.032,-10)
#           (-4.108,-0.031,-10)
#           (-4,-0.03,-10)
#           (-4,-0.53,-10)
#           (-4.204,-0.532,-10)
#           (-4.305,-0.535,-10)
#           (-4.407,-0.539,-10)
#           (-4.508,-0.544,-10)
#           (-4.608,-0.55,-10)
#           (-4.709,-0.557,-10)
#           (-4.81,-0.565,-10)
#           (-5.01,-0.585,-10)
#           (-5.11,-0.596,-10)
#           (-5.209,-0.608,-10)
#           (-5.309,-0.62,-10)
#           (-5.408,-0.634,-10)
#           (-5.606,-0.664,-10)
#           (-5.705,-0.68,-10)
#           (-5.804,-0.697,-10)
#           (-5.902,-0.715,-10)
#           (-6.001,-0.734,-10)
#           (-6.099,-0.753,-10)
#           (-6.198,-0.773,-10)
#           (-6.296,-0.793,-10)
#           (-6.394,-0.814,-10)
#           (-6.492,-0.836,-10)
#           (-6.59,-0.859,-10)
#           (-6.687,-0.882,-10)
#           (-6.785,-0.905,-10)
#           (-6.883,-0.93,-10)
#           (-6.98,-0.954,-10)
#           (-7.078,-0.979,-10)
#           (-7.272,-1.031,-10)
#           (-7.37,-1.057,-10)
#           (-7.467,-1.084,-10)
#           (-7.564,-1.112,-10)
#           (-7.662,-1.139,-10)
#           (-7.856,-1.195,-10)
#           (-7.953,-1.224,-10)
#           (-8.051,-1.253,-10)
#           (-8.342,-1.34,-10)
#           (-8.44,-1.37,-10)
#           (-8.537,-1.399,-10)
#           (-8.634,-1.429,-10)
#           (-8.732,-1.459,-10)
#           (-8.926,-1.519,-10)
#           (-9.122,-1.579,-10)
#           (-9.219,-1.609,-10)
#           (-9.415,-1.669,-10)
#           (-9.513,-1.698,-10)
#           (-9.611,-1.728,-10)
#           (-9.709,-1.757,-10)
#           (-9.807,-1.787,-10)
#           (-9.905,-1.816,-10)
#           (-10.004,-1.845,-10)
#           (-10.102,-1.873,-10)
#           (-10.201,-1.902,-10)
#           (-10.3,-1.93,-10)
#           (-10.399,-1.957,-10)
#           (-10.498,-1.985,-10)
#           (-10.597,-2.012,-10)
#           (-10.697,-2.038,-10)
#           (-10.796,-2.065,-10)
#           (-11.096,-2.14,-10)
#           (-11.197,-2.165,-10)
#           (-11.297,-2.188,-10)
#           (-11.499,-2.234,-10)
#           (-11.6,-2.256,-10)
#           (-11.701,-2.277,-10)
#           (-11.803,-2.298,-10)
#           (-11.905,-2.318,-10)
#           (-12.007,-2.337,-10)
#           (-12.109,-2.355,-10)
#           (-12.212,-2.373,-10)
#           (-12.315,-2.39,-10)
#           (-12.418,-2.406,-10)
#           (-12.521,-2.421,-10)
#           (-12.729,-2.449,-10)
#           (-12.833,-2.461,-10)
#           (-12.938,-2.473,-10)
#           (-13.148,-2.493,-10)
#           (-13.253,-2.501,-10)
#           (-13.359,-2.509,-10)
#           (-13.465,-2.515,-10)
#           (-13.571,-2.52,-10)
#           (-13.678,-2.525,-10)
#           (-13.785,-2.528,-10)
#           (-13.892,-2.529,-10)
#           (-14,-2.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,-1.29149,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (14,-2.53,-10)
#           (13.892,-2.529,-10)
#           (13.785,-2.528,-10)
#           (13.678,-2.525,-10)
#           (13.571,-2.52,-10)
#           (13.465,-2.515,-10)
#           (13.359,-2.509,-10)
#           (13.253,-2.501,-10)
#           (13.148,-2.493,-10)
#           (12.938,-2.473,-10)
#           (12.833,-2.461,-10)
#           (12.729,-2.449,-10)
#           (12.521,-2.421,-10)
#           (12.418,-2.406,-10)
#           (12.315,-2.39,-10)
#           (12.212,-2.373,-10)
#           (12.109,-2.355,-10)
#           (12.007,-2.337,-10)
#           (11.905,-2.318,-10)
#           (11.803,-2.298,-10)
#           (11.701,-2.277,-10)
#           (11.6,-2.256,-10)
#           (11.499,-2.234,-10)
#           (11.297,-2.188,-10)
#           (11.197,-2.165,-10)
#           (11.096,-2.14,-10)
#           (10.796,-2.065,-10)
#           (10.697,-2.038,-10)
#           (10.597,-2.012,-10)
#           (10.498,-1.985,-10)
#           (10.399,-1.957,-10)
#           (10.3,-1.93,-10)
#           (10.201,-1.902,-10)
#           (10.102,-1.873,-10)
#           (10.004,-1.845,-10)
#           (9.905,-1.816,-10)
#           (9.807,-1.787,-10)
#           (9.709,-1.757,-10)
#           (9.611,-1.728,-10)
#           (9.513,-1.698,-10)
#           (9.415,-1.669,-10)
#           (9.219,-1.609,-10)
#           (9.122,-1.579,-10)
#           (8.926,-1.519,-10)
#           (8.732,-1.459,-10)
#           (8.634,-1.429,-10)
#           (8.537,-1.399,-10)
#           (8.44,-1.37,-10)
#           (8.342,-1.34,-10)
#           (8.051,-1.253,-10)
#           (7.953,-1.224,-10)
#           (7.856,-1.195,-10)
#           (7.662,-1.139,-10)
#           (7.564,-1.112,-10)
#           (7.467,-1.084,-10)
#           (7.37,-1.057,-10)
#           (7.272,-1.031,-10)
#           (7.078,-0.979,-10)
#           (6.98,-0.954,-10)
#           (6.883,-0.93,-10)
#           (6.785,-0.905,-10)
#           (6.687,-0.882,-10)
#           (6.59,-0.859,-10)
#           (6.492,-0.836,-10)
#           (6.394,-0.814,-10)
#           (6.296,-0.793,-10)
#           (6.198,-0.773,-10)
#           (6.099,-0.753,-10)
#           (6.001,-0.734,-10)
#           (5.902,-0.715,-10)
#           (5.804,-0.697,-10)
#           (5.705,-0.68,-10)
#           (5.606,-0.664,-10)
#           (5.408,-0.634,-10)
#           (5.309,-0.62,-10)
#           (5.209,-0.608,-10)
#           (5.11,-0.596,-10)
#           (5.01,-0.585,-10)
#           (4.81,-0.565,-10)
#           (4.709,-0.557,-10)
#           (4.608,-0.55,-10)
#           (4.508,-0.544,-10)
#           (4.407,-0.539,-10)
#           (4.305,-0.535,-10)
#           (4.204,-0.532,-10)
#           (4,-0.53,-10)
#           (4,-0.03,-10)
#           (4.108,-0.031,-10)
#           (4.215,-0.032,-10)
#           (4.322,-0.035,-10)
#           (4.429,-0.04,-10)
#           (4.535,-0.045,-10)
#           (4.641,-0.051,-10)
#           (4.747,-0.059,-10)
#           (4.852,-0.067,-10)
#           (5.062,-0.087,-10)
#           (5.167,-0.099,-10)
#           (5.271,-0.111,-10)
#           (5.479,-0.139,-10)
#           (5.582,-0.154,-10)
#           (5.685,-0.17,-10)
#           (5.788,-0.187,-10)
#           (5.891,-0.205,-10)
#           (5.993,-0.223,-10)
#           (6.095,-0.242,-10)
#           (6.197,-0.262,-10)
#           (6.299,-0.283,-10)
#           (6.4,-0.304,-10)
#           (6.501,-0.326,-10)
#           (6.703,-0.372,-10)
#           (6.803,-0.395,-10)
#           (6.904,-0.42,-10)
#           (7.204,-0.495,-10)
#           (7.303,-0.522,-10)
#           (7.403,-0.548,-10)
#           (7.502,-0.575,-10)
#           (7.601,-0.603,-10)
#           (7.7,-0.63,-10)
#           (7.799,-0.658,-10)
#           (7.898,-0.687,-10)
#           (7.996,-0.715,-10)
#           (8.095,-0.744,-10)
#           (8.193,-0.773,-10)
#           (8.291,-0.803,-10)
#           (8.389,-0.832,-10)
#           (8.487,-0.862,-10)
#           (8.585,-0.891,-10)
#           (8.781,-0.951,-10)
#           (8.878,-0.981,-10)
#           (9.074,-1.041,-10)
#           (9.268,-1.101,-10)
#           (9.366,-1.131,-10)
#           (9.463,-1.161,-10)
#           (9.56,-1.19,-10)
#           (9.658,-1.22,-10)
#           (9.949,-1.307,-10)
#           (10.047,-1.336,-10)
#           (10.144,-1.365,-10)
#           (10.338,-1.421,-10)
#           (10.436,-1.448,-10)
#           (10.533,-1.476,-10)
#           (10.63,-1.503,-10)
#           (10.728,-1.529,-10)
#           (10.922,-1.581,-10)
#           (11.02,-1.606,-10)
#           (11.117,-1.63,-10)
#           (11.215,-1.655,-10)
#           (11.313,-1.678,-10)
#           (11.41,-1.701,-10)
#           (11.508,-1.724,-10)
#           (11.606,-1.746,-10)
#           (11.704,-1.767,-10)
#           (11.802,-1.787,-10)
#           (11.901,-1.807,-10)
#           (11.999,-1.826,-10)
#           (12.098,-1.845,-10)
#           (12.196,-1.863,-10)
#           (12.295,-1.88,-10)
#           (12.394,-1.896,-10)
#           (12.592,-1.926,-10)
#           (12.691,-1.94,-10)
#           (12.791,-1.952,-10)
#           (12.89,-1.964,-10)
#           (12.99,-1.975,-10)
#           (13.19,-1.995,-10)
#           (13.291,-2.003,-10)
#           (13.392,-2.01,-10)
#           (13.492,-2.016,-10)
#           (13.593,-2.021,-10)
#           (13.695,-2.025,-10)
#           (13.796,-2.028,-10)
#           (14,-2.03,-10)
#           (17.2,-2.03,-10)
#           (17.2,-2.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,-0.28,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,-0.53,-10)
#           (-4,-0.03,-10)
#           (4,-0.03,-10)
#           (4,-0.53,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 11.2364% done, 33.0348 s remaining
# subpixel-averaging is 19.016% done, 17.2818 s remaining
# subpixel-averaging is 26.7956% done, 11.183 s remaining
# subpixel-averaging is 34.5752% done, 7.66379 s remaining
# subpixel-averaging is 67.4224% done, 2.04168 s remaining
# subpixel-averaging is 75.2021% done, 1.33681 s remaining
# subpixel-averaging is 82.9817% done, 0.822483 s remaining
# subpixel-averaging is 91.6257% done, 0.406867 s remaining
# subpixel-averaging is 11.2364% done, 33.2299 s remaining
# subpixel-averaging is 19.016% done, 17.2994 s remaining
# subpixel-averaging is 27.66% done, 11.6344 s remaining
# subpixel-averaging is 35.4396% done, 7.68575 s remaining
# subpixel-averaging is 68.2868% done, 1.97703 s remaining
# subpixel-averaging is 76.0665% done, 1.28192 s remaining
# subpixel-averaging is 83.8461% done, 0.772229 s remaining
# subpixel-averaging is 91.6257% done, 0.370922 s remaining
# subpixel-averaging is 11.2364% done, 33.2096 s remaining
# subpixel-averaging is 19.016% done, 17.0845 s remaining
# subpixel-averaging is 27.66% done, 11.5438 s remaining
# subpixel-averaging is 35.4396% done, 7.30007 s remaining
# subpixel-averaging is 68.2868% done, 1.95681 s remaining
# subpixel-averaging is 76.0665% done, 1.27915 s remaining
# subpixel-averaging is 84.7105% done, 0.804328 s remaining
# subpixel-averaging is 92.4901% done, 0.32505 s remaining
# time for set_epsilon = 113.664 s
# -----------
# MPB solved for frequency_1(2.2349,0,0) = 0.68533 after 11 iters
# MPB solved for frequency_1(2.09126,0,0) = 0.645199 after 7 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 4 iters
# MPB solved for frequency_1(2.09113,0,0) = 0.645161 after 1 iters
# Meep progress: 86.82000000000001/400.0 = 21.7% done in 4.0s, 14.4s to go
# on time step 4341 (time=86.82), 0.000921605 s/step
# Meep progress: 176.52/400.0 = 44.1% done in 8.0s, 10.1s to go
# on time step 8827 (time=176.54), 0.000891767 s/step
# Meep progress: 266.74/400.0 = 66.7% done in 12.0s, 6.0s to go
# on time step 13339 (time=266.78), 0.000886623 s/step
# Meep progress: 357.48/400.0 = 89.4% done in 16.0s, 1.9s to go
# on time step 17877 (time=357.54), 0.000881624 s/step
# run 0 finished at t = 400.0 (20000 timesteps)
# /home/311514090/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/311514090/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
