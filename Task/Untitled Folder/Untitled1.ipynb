# %%
import meep as mp
import numpy
import matplotlib.pyplot as plt

res = 25  # pixels/μm
three_d = False  # 3d calculation?
d = 0.13  # branch separation

gdsII_file = "coupler.gds"
CELL_LAYER = 0
PORT1_LAYER = 1
PORT2_LAYER = 2
PORT3_LAYER = 3
PORT4_LAYER = 4
SOURCE_LAYER = 5
UPPER_BRANCH_LAYER = 31
LOWER_BRANCH_LAYER = 32
default_d = 0.3

t_oxide = 1.0
t_Si = 0.22
t_air = 0.78

dpml = 1
cell_thickness = dpml + t_oxide + t_Si + t_air + dpml

oxide = mp.Medium(epsilon=2.25)
silicon = mp.Medium(epsilon=12)

lcen = 1.55
fcen = 1 / lcen
df = 0.2 * fcen

cell_zmax = 0.5 * cell_thickness if three_d else 0
cell_zmin = -0.5 * cell_thickness if three_d else 0
si_zmax = 0.5 * t_Si if three_d else 10
si_zmin = -0.5 * t_Si if three_d else -10

# read cell size, volumes for source region and flux monitors,
# and coupler geometry from GDSII file
upper_branch = mp.get_GDSII_prisms(
    silicon, gdsII_file, UPPER_BRANCH_LAYER, si_zmin, si_zmax
)
lower_branch = mp.get_GDSII_prisms(
    silicon, gdsII_file, LOWER_BRANCH_LAYER, si_zmin, si_zmax
)

cell = mp.GDSII_vol(gdsII_file, CELL_LAYER, cell_zmin, cell_zmax)
p1 = mp.GDSII_vol(gdsII_file, PORT1_LAYER, si_zmin, si_zmax)
p2 = mp.GDSII_vol(gdsII_file, PORT2_LAYER, si_zmin, si_zmax)
p3 = mp.GDSII_vol(gdsII_file, PORT3_LAYER, si_zmin, si_zmax)
p4 = mp.GDSII_vol(gdsII_file, PORT4_LAYER, si_zmin, si_zmax)
src_vol = mp.GDSII_vol(gdsII_file, SOURCE_LAYER, si_zmin, si_zmax)

# displace upper and lower branches of coupler (as well as source and flux regions)
if d != default_d:
    delta_y = 0.5 * (d - default_d)
    delta = mp.Vector3(y=delta_y)
    p1.center += delta
    p2.center -= delta
    p3.center += delta
    p4.center -= delta
    src_vol.center += delta
    cell.size += 2 * delta
    for np in range(len(lower_branch)):
        lower_branch[np].center -= delta
        for nv in range(len(lower_branch[np].vertices)):
            lower_branch[np].vertices[nv] -= delta
    for np in range(len(upper_branch)):
        upper_branch[np].center += delta
        for nv in range(len(upper_branch[np].vertices)):
            upper_branch[np].vertices[nv] += delta

geometry = upper_branch + lower_branch

if three_d:
    oxide_center = mp.Vector3(z=-0.5 * t_oxide)
    oxide_size = mp.Vector3(cell.size.x, cell.size.y, t_oxide)
    oxide_layer = [mp.Block(material=oxide, center=oxide_center, size=oxide_size)]
    geometry = geometry + oxide_layer

sources = [
    mp.EigenModeSource(
        src=mp.GaussianSource(fcen, fwidth=df),
        size=src_vol.size,
        center=src_vol.center,
        eig_band=1,
        eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z,
        eig_match_freq=True,
    )
]

sim = mp.Simulation(
    resolution=res,
    cell_size=cell.size,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
    geometry=geometry,
)

mode1 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p1))
mode2 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p2))
mode3 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p3))
mode4 = sim.add_mode_monitor(fcen, 0, 1, mp.ModeRegion(volume=p4))

sim.run(until_after_sources=100)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0188029 s
# Working in 2D dimensions.
# Computational cell is 34.4 x 7.84 x 0 with resolution 25
#      prism, center = (-9.09425,1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-4,0.065,-10)
#           (-4.108,0.066,-10)
#           (-4.215,0.067,-10)
#           (-4.322,0.07,-10)
#           (-4.429,0.075,-10)
#           (-4.535,0.08,-10)
#           (-4.641,0.086,-10)
#           (-4.747,0.094,-10)
#           (-4.852,0.102,-10)
#           (-5.062,0.122,-10)
#           (-5.167,0.134,-10)
#           (-5.271,0.146,-10)
#           (-5.479,0.174,-10)
#           (-5.582,0.189,-10)
#           (-5.685,0.205,-10)
#           (-5.788,0.222,-10)
#           (-5.891,0.24,-10)
#           (-5.993,0.258,-10)
#           (-6.095,0.277,-10)
#           (-6.197,0.297,-10)
#           (-6.299,0.318,-10)
#           (-6.4,0.339,-10)
#           (-6.501,0.361,-10)
#           (-6.703,0.407,-10)
#           (-6.803,0.43,-10)
#           (-6.904,0.455,-10)
#           (-7.204,0.53,-10)
#           (-7.303,0.557,-10)
#           (-7.403,0.583,-10)
#           (-7.502,0.61,-10)
#           (-7.601,0.638,-10)
#           (-7.7,0.665,-10)
#           (-7.799,0.693,-10)
#           (-7.898,0.722,-10)
#           (-7.996,0.75,-10)
#           (-8.095,0.779,-10)
#           (-8.193,0.808,-10)
#           (-8.291,0.838,-10)
#           (-8.389,0.867,-10)
#           (-8.487,0.897,-10)
#           (-8.585,0.926,-10)
#           (-8.781,0.986,-10)
#           (-8.878,1.016,-10)
#           (-9.074,1.076,-10)
#           (-9.268,1.136,-10)
#           (-9.366,1.166,-10)
#           (-9.463,1.196,-10)
#           (-9.56,1.225,-10)
#           (-9.658,1.255,-10)
#           (-9.949,1.342,-10)
#           (-10.047,1.371,-10)
#           (-10.144,1.4,-10)
#           (-10.338,1.456,-10)
#           (-10.436,1.483,-10)
#           (-10.533,1.511,-10)
#           (-10.63,1.538,-10)
#           (-10.728,1.564,-10)
#           (-10.922,1.616,-10)
#           (-11.02,1.641,-10)
#           (-11.117,1.665,-10)
#           (-11.215,1.69,-10)
#           (-11.313,1.713,-10)
#           (-11.41,1.736,-10)
#           (-11.508,1.759,-10)
#           (-11.606,1.781,-10)
#           (-11.704,1.802,-10)
#           (-11.802,1.822,-10)
#           (-11.901,1.842,-10)
#           (-11.999,1.861,-10)
#           (-12.098,1.88,-10)
#           (-12.196,1.898,-10)
#           (-12.295,1.915,-10)
#           (-12.394,1.931,-10)
#           (-12.592,1.961,-10)
#           (-12.691,1.975,-10)
#           (-12.791,1.987,-10)
#           (-12.89,1.999,-10)
#           (-12.99,2.01,-10)
#           (-13.19,2.03,-10)
#           (-13.291,2.038,-10)
#           (-13.392,2.045,-10)
#           (-13.492,2.051,-10)
#           (-13.593,2.056,-10)
#           (-13.695,2.06,-10)
#           (-13.796,2.063,-10)
#           (-14,2.065,-10)
#           (-17.2,2.065,-10)
#           (-17.2,2.565,-10)
#           (-14,2.565,-10)
#           (-13.892,2.564,-10)
#           (-13.785,2.563,-10)
#           (-13.678,2.56,-10)
#           (-13.571,2.555,-10)
#           (-13.465,2.55,-10)
#           (-13.359,2.544,-10)
#           (-13.253,2.536,-10)
#           (-13.148,2.528,-10)
#           (-12.938,2.508,-10)
#           (-12.833,2.496,-10)
#           (-12.729,2.484,-10)
#           (-12.521,2.456,-10)
#           (-12.418,2.441,-10)
#           (-12.315,2.425,-10)
#           (-12.212,2.408,-10)
#           (-12.109,2.39,-10)
#           (-12.007,2.372,-10)
#           (-11.905,2.353,-10)
#           (-11.803,2.333,-10)
#           (-11.701,2.312,-10)
#           (-11.6,2.291,-10)
#           (-11.499,2.269,-10)
#           (-11.297,2.223,-10)
#           (-11.197,2.2,-10)
#           (-11.096,2.175,-10)
#           (-10.796,2.1,-10)
#           (-10.697,2.073,-10)
#           (-10.597,2.047,-10)
#           (-10.498,2.02,-10)
#           (-10.399,1.992,-10)
#           (-10.3,1.965,-10)
#           (-10.201,1.937,-10)
#           (-10.102,1.908,-10)
#           (-10.004,1.88,-10)
#           (-9.905,1.851,-10)
#           (-9.807,1.822,-10)
#           (-9.709,1.792,-10)
#           (-9.611,1.763,-10)
#           (-9.513,1.733,-10)
#           (-9.415,1.704,-10)
#           (-9.219,1.644,-10)
#           (-9.122,1.614,-10)
#           (-8.926,1.554,-10)
#           (-8.732,1.494,-10)
#           (-8.634,1.464,-10)
#           (-8.537,1.434,-10)
#           (-8.44,1.405,-10)
#           (-8.342,1.375,-10)
#           (-8.051,1.288,-10)
#           (-7.953,1.259,-10)
#           (-7.856,1.23,-10)
#           (-7.662,1.174,-10)
#           (-7.564,1.147,-10)
#           (-7.467,1.119,-10)
#           (-7.37,1.092,-10)
#           (-7.272,1.066,-10)
#           (-7.078,1.014,-10)
#           (-6.98,0.989,-10)
#           (-6.883,0.965,-10)
#           (-6.785,0.94,-10)
#           (-6.687,0.917,-10)
#           (-6.59,0.894,-10)
#           (-6.492,0.871,-10)
#           (-6.394,0.849,-10)
#           (-6.296,0.828,-10)
#           (-6.198,0.808,-10)
#           (-6.099,0.788,-10)
#           (-6.001,0.769,-10)
#           (-5.902,0.75,-10)
#           (-5.804,0.732,-10)
#           (-5.705,0.715,-10)
#           (-5.606,0.699,-10)
#           (-5.408,0.669,-10)
#           (-5.309,0.655,-10)
#           (-5.209,0.643,-10)
#           (-5.11,0.631,-10)
#           (-5.01,0.62,-10)
#           (-4.81,0.6,-10)
#           (-4.709,0.592,-10)
#           (-4.608,0.585,-10)
#           (-4.508,0.579,-10)
#           (-4.407,0.574,-10)
#           (-4.305,0.57,-10)
#           (-4.204,0.567,-10)
#           (-4,0.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (4,0.065,-10)
#           (4,0.565,-10)
#           (4.204,0.567,-10)
#           (4.305,0.57,-10)
#           (4.407,0.574,-10)
#           (4.508,0.579,-10)
#           (4.608,0.585,-10)
#           (4.709,0.592,-10)
#           (4.81,0.6,-10)
#           (5.01,0.62,-10)
#           (5.11,0.631,-10)
#           (5.209,0.643,-10)
#           (5.309,0.655,-10)
#           (5.408,0.669,-10)
#           (5.606,0.699,-10)
#           (5.705,0.715,-10)
#           (5.804,0.732,-10)
#           (5.902,0.75,-10)
#           (6.001,0.769,-10)
#           (6.099,0.788,-10)
#           (6.198,0.808,-10)
#           (6.296,0.828,-10)
#           (6.394,0.849,-10)
#           (6.492,0.871,-10)
#           (6.59,0.894,-10)
#           (6.687,0.917,-10)
#           (6.785,0.94,-10)
#           (6.883,0.965,-10)
#           (6.98,0.989,-10)
#           (7.078,1.014,-10)
#           (7.272,1.066,-10)
#           (7.37,1.092,-10)
#           (7.467,1.119,-10)
#           (7.564,1.147,-10)
#           (7.662,1.174,-10)
#           (7.856,1.23,-10)
#           (7.953,1.259,-10)
#           (8.051,1.288,-10)
#           (8.342,1.375,-10)
#           (8.44,1.405,-10)
#           (8.537,1.434,-10)
#           (8.634,1.464,-10)
#           (8.732,1.494,-10)
#           (8.926,1.554,-10)
#           (9.122,1.614,-10)
#           (9.219,1.644,-10)
#           (9.415,1.704,-10)
#           (9.513,1.733,-10)
#           (9.611,1.763,-10)
#           (9.709,1.792,-10)
#           (9.807,1.822,-10)
#           (9.905,1.851,-10)
#           (10.004,1.88,-10)
#           (10.102,1.908,-10)
#           (10.201,1.937,-10)
#           (10.3,1.965,-10)
#           (10.399,1.992,-10)
#           (10.498,2.02,-10)
#           (10.597,2.047,-10)
#           (10.697,2.073,-10)
#           (10.796,2.1,-10)
#           (11.096,2.175,-10)
#           (11.197,2.2,-10)
#           (11.297,2.223,-10)
#           (11.499,2.269,-10)
#           (11.6,2.291,-10)
#           (11.701,2.312,-10)
#           (11.803,2.333,-10)
#           (11.905,2.353,-10)
#           (12.007,2.372,-10)
#           (12.109,2.39,-10)
#           (12.212,2.408,-10)
#           (12.315,2.425,-10)
#           (12.418,2.441,-10)
#           (12.521,2.456,-10)
#           (12.729,2.484,-10)
#           (12.833,2.496,-10)
#           (12.938,2.508,-10)
#           (13.148,2.528,-10)
#           (13.253,2.536,-10)
#           (13.359,2.544,-10)
#           (13.465,2.55,-10)
#           (13.571,2.555,-10)
#           (13.678,2.56,-10)
#           (13.785,2.563,-10)
#           (13.892,2.564,-10)
#           (14,2.565,-10)
#           (17.2,2.565,-10)
#           (17.2,2.065,-10)
#           (14,2.065,-10)
#           (13.796,2.063,-10)
#           (13.695,2.06,-10)
#           (13.593,2.056,-10)
#           (13.492,2.051,-10)
#           (13.392,2.045,-10)
#           (13.291,2.038,-10)
#           (13.19,2.03,-10)
#           (12.99,2.01,-10)
#           (12.89,1.999,-10)
#           (12.791,1.987,-10)
#           (12.691,1.975,-10)
#           (12.592,1.961,-10)
#           (12.394,1.931,-10)
#           (12.295,1.915,-10)
#           (12.196,1.898,-10)
#           (12.098,1.88,-10)
#           (11.999,1.861,-10)
#           (11.901,1.842,-10)
#           (11.802,1.822,-10)
#           (11.704,1.802,-10)
#           (11.606,1.781,-10)
#           (11.508,1.759,-10)
#           (11.41,1.736,-10)
#           (11.313,1.713,-10)
#           (11.215,1.69,-10)
#           (11.117,1.665,-10)
#           (11.02,1.641,-10)
#           (10.922,1.616,-10)
#           (10.728,1.564,-10)
#           (10.63,1.538,-10)
#           (10.533,1.511,-10)
#           (10.436,1.483,-10)
#           (10.338,1.456,-10)
#           (10.144,1.4,-10)
#           (10.047,1.371,-10)
#           (9.949,1.342,-10)
#           (9.658,1.255,-10)
#           (9.56,1.225,-10)
#           (9.463,1.196,-10)
#           (9.366,1.166,-10)
#           (9.268,1.136,-10)
#           (9.074,1.076,-10)
#           (8.878,1.016,-10)
#           (8.781,0.986,-10)
#           (8.585,0.926,-10)
#           (8.487,0.897,-10)
#           (8.389,0.867,-10)
#           (8.291,0.838,-10)
#           (8.193,0.808,-10)
#           (8.095,0.779,-10)
#           (7.996,0.75,-10)
#           (7.898,0.722,-10)
#           (7.799,0.693,-10)
#           (7.7,0.665,-10)
#           (7.601,0.638,-10)
#           (7.502,0.61,-10)
#           (7.403,0.583,-10)
#           (7.303,0.557,-10)
#           (7.204,0.53,-10)
#           (6.904,0.455,-10)
#           (6.803,0.43,-10)
#           (6.703,0.407,-10)
#           (6.501,0.361,-10)
#           (6.4,0.339,-10)
#           (6.299,0.318,-10)
#           (6.197,0.297,-10)
#           (6.095,0.277,-10)
#           (5.993,0.258,-10)
#           (5.891,0.24,-10)
#           (5.788,0.222,-10)
#           (5.685,0.205,-10)
#           (5.582,0.189,-10)
#           (5.479,0.174,-10)
#           (5.271,0.146,-10)
#           (5.167,0.134,-10)
#           (5.062,0.122,-10)
#           (4.852,0.102,-10)
#           (4.747,0.094,-10)
#           (4.641,0.086,-10)
#           (4.535,0.08,-10)
#           (4.429,0.075,-10)
#           (4.322,0.07,-10)
#           (4.215,0.067,-10)
#           (4.108,0.066,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,0.315,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,0.065,-10)
#           (-4,0.565,-10)
#           (4,0.565,-10)
#           (4,0.065,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (-9.09425,-1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-17.2,-2.565,-10)
#           (-17.2,-2.065,-10)
#           (-14,-2.065,-10)
#           (-13.796,-2.063,-10)
#           (-13.695,-2.06,-10)
#           (-13.593,-2.056,-10)
#           (-13.492,-2.051,-10)
#           (-13.392,-2.045,-10)
#           (-13.291,-2.038,-10)
#           (-13.19,-2.03,-10)
#           (-12.99,-2.01,-10)
#           (-12.89,-1.999,-10)
#           (-12.791,-1.987,-10)
#           (-12.691,-1.975,-10)
#           (-12.592,-1.961,-10)
#           (-12.394,-1.931,-10)
#           (-12.295,-1.915,-10)
#           (-12.196,-1.898,-10)
#           (-12.098,-1.88,-10)
#           (-11.999,-1.861,-10)
#           (-11.901,-1.842,-10)
#           (-11.802,-1.822,-10)
#           (-11.704,-1.802,-10)
#           (-11.606,-1.781,-10)
#           (-11.508,-1.759,-10)
#           (-11.41,-1.736,-10)
#           (-11.313,-1.713,-10)
#           (-11.215,-1.69,-10)
#           (-11.117,-1.665,-10)
#           (-11.02,-1.641,-10)
#           (-10.922,-1.616,-10)
#           (-10.728,-1.564,-10)
#           (-10.63,-1.538,-10)
#           (-10.533,-1.511,-10)
#           (-10.436,-1.483,-10)
#           (-10.338,-1.456,-10)
#           (-10.144,-1.4,-10)
#           (-10.047,-1.371,-10)
#           (-9.949,-1.342,-10)
#           (-9.658,-1.255,-10)
#           (-9.56,-1.225,-10)
#           (-9.463,-1.196,-10)
#           (-9.366,-1.166,-10)
#           (-9.268,-1.136,-10)
#           (-9.074,-1.076,-10)
#           (-8.878,-1.016,-10)
#           (-8.781,-0.986,-10)
#           (-8.585,-0.926,-10)
#           (-8.487,-0.897,-10)
#           (-8.389,-0.867,-10)
#           (-8.291,-0.838,-10)
#           (-8.193,-0.808,-10)
#           (-8.095,-0.779,-10)
#           (-7.996,-0.75,-10)
#           (-7.898,-0.722,-10)
#           (-7.799,-0.693,-10)
#           (-7.7,-0.665,-10)
#           (-7.601,-0.638,-10)
#           (-7.502,-0.61,-10)
#           (-7.403,-0.583,-10)
#           (-7.303,-0.557,-10)
#           (-7.204,-0.53,-10)
#           (-6.904,-0.455,-10)
#           (-6.803,-0.43,-10)
#           (-6.703,-0.407,-10)
#           (-6.501,-0.361,-10)
#           (-6.4,-0.339,-10)
#           (-6.299,-0.318,-10)
#           (-6.197,-0.297,-10)
#           (-6.095,-0.277,-10)
#           (-5.993,-0.258,-10)
#           (-5.891,-0.24,-10)
#           (-5.788,-0.222,-10)
#           (-5.685,-0.205,-10)
#           (-5.582,-0.189,-10)
#           (-5.479,-0.174,-10)
#           (-5.271,-0.146,-10)
#           (-5.167,-0.134,-10)
#           (-5.062,-0.122,-10)
#           (-4.852,-0.102,-10)
#           (-4.747,-0.094,-10)
#           (-4.641,-0.086,-10)
#           (-4.535,-0.08,-10)
#           (-4.429,-0.075,-10)
#           (-4.322,-0.07,-10)
#           (-4.215,-0.067,-10)
#           (-4.108,-0.066,-10)
#           (-4,-0.065,-10)
#           (-4,-0.565,-10)
#           (-4.204,-0.567,-10)
#           (-4.305,-0.57,-10)
#           (-4.407,-0.574,-10)
#           (-4.508,-0.579,-10)
#           (-4.608,-0.585,-10)
#           (-4.709,-0.592,-10)
#           (-4.81,-0.6,-10)
#           (-5.01,-0.62,-10)
#           (-5.11,-0.631,-10)
#           (-5.209,-0.643,-10)
#           (-5.309,-0.655,-10)
#           (-5.408,-0.669,-10)
#           (-5.606,-0.699,-10)
#           (-5.705,-0.715,-10)
#           (-5.804,-0.732,-10)
#           (-5.902,-0.75,-10)
#           (-6.001,-0.769,-10)
#           (-6.099,-0.788,-10)
#           (-6.198,-0.808,-10)
#           (-6.296,-0.828,-10)
#           (-6.394,-0.849,-10)
#           (-6.492,-0.871,-10)
#           (-6.59,-0.894,-10)
#           (-6.687,-0.917,-10)
#           (-6.785,-0.94,-10)
#           (-6.883,-0.965,-10)
#           (-6.98,-0.989,-10)
#           (-7.078,-1.014,-10)
#           (-7.272,-1.066,-10)
#           (-7.37,-1.092,-10)
#           (-7.467,-1.119,-10)
#           (-7.564,-1.147,-10)
#           (-7.662,-1.174,-10)
#           (-7.856,-1.23,-10)
#           (-7.953,-1.259,-10)
#           (-8.051,-1.288,-10)
#           (-8.342,-1.375,-10)
#           (-8.44,-1.405,-10)
#           (-8.537,-1.434,-10)
#           (-8.634,-1.464,-10)
#           (-8.732,-1.494,-10)
#           (-8.926,-1.554,-10)
#           (-9.122,-1.614,-10)
#           (-9.219,-1.644,-10)
#           (-9.415,-1.704,-10)
#           (-9.513,-1.733,-10)
#           (-9.611,-1.763,-10)
#           (-9.709,-1.792,-10)
#           (-9.807,-1.822,-10)
#           (-9.905,-1.851,-10)
#           (-10.004,-1.88,-10)
#           (-10.102,-1.908,-10)
#           (-10.201,-1.937,-10)
#           (-10.3,-1.965,-10)
#           (-10.399,-1.992,-10)
#           (-10.498,-2.02,-10)
#           (-10.597,-2.047,-10)
#           (-10.697,-2.073,-10)
#           (-10.796,-2.1,-10)
#           (-11.096,-2.175,-10)
#           (-11.197,-2.2,-10)
#           (-11.297,-2.223,-10)
#           (-11.499,-2.269,-10)
#           (-11.6,-2.291,-10)
#           (-11.701,-2.312,-10)
#           (-11.803,-2.333,-10)
#           (-11.905,-2.353,-10)
#           (-12.007,-2.372,-10)
#           (-12.109,-2.39,-10)
#           (-12.212,-2.408,-10)
#           (-12.315,-2.425,-10)
#           (-12.418,-2.441,-10)
#           (-12.521,-2.456,-10)
#           (-12.729,-2.484,-10)
#           (-12.833,-2.496,-10)
#           (-12.938,-2.508,-10)
#           (-13.148,-2.528,-10)
#           (-13.253,-2.536,-10)
#           (-13.359,-2.544,-10)
#           (-13.465,-2.55,-10)
#           (-13.571,-2.555,-10)
#           (-13.678,-2.56,-10)
#           (-13.785,-2.563,-10)
#           (-13.892,-2.564,-10)
#           (-14,-2.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,-1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (14,-2.565,-10)
#           (13.892,-2.564,-10)
#           (13.785,-2.563,-10)
#           (13.678,-2.56,-10)
#           (13.571,-2.555,-10)
#           (13.465,-2.55,-10)
#           (13.359,-2.544,-10)
#           (13.253,-2.536,-10)
#           (13.148,-2.528,-10)
#           (12.938,-2.508,-10)
#           (12.833,-2.496,-10)
#           (12.729,-2.484,-10)
#           (12.521,-2.456,-10)
#           (12.418,-2.441,-10)
#           (12.315,-2.425,-10)
#           (12.212,-2.408,-10)
#           (12.109,-2.39,-10)
#           (12.007,-2.372,-10)
#           (11.905,-2.353,-10)
#           (11.803,-2.333,-10)
#           (11.701,-2.312,-10)
#           (11.6,-2.291,-10)
#           (11.499,-2.269,-10)
#           (11.297,-2.223,-10)
#           (11.197,-2.2,-10)
#           (11.096,-2.175,-10)
#           (10.796,-2.1,-10)
#           (10.697,-2.073,-10)
#           (10.597,-2.047,-10)
#           (10.498,-2.02,-10)
#           (10.399,-1.992,-10)
#           (10.3,-1.965,-10)
#           (10.201,-1.937,-10)
#           (10.102,-1.908,-10)
#           (10.004,-1.88,-10)
#           (9.905,-1.851,-10)
#           (9.807,-1.822,-10)
#           (9.709,-1.792,-10)
#           (9.611,-1.763,-10)
#           (9.513,-1.733,-10)
#           (9.415,-1.704,-10)
#           (9.219,-1.644,-10)
#           (9.122,-1.614,-10)
#           (8.926,-1.554,-10)
#           (8.732,-1.494,-10)
#           (8.634,-1.464,-10)
#           (8.537,-1.434,-10)
#           (8.44,-1.405,-10)
#           (8.342,-1.375,-10)
#           (8.051,-1.288,-10)
#           (7.953,-1.259,-10)
#           (7.856,-1.23,-10)
#           (7.662,-1.174,-10)
#           (7.564,-1.147,-10)
#           (7.467,-1.119,-10)
#           (7.37,-1.092,-10)
#           (7.272,-1.066,-10)
#           (7.078,-1.014,-10)
#           (6.98,-0.989,-10)
#           (6.883,-0.965,-10)
#           (6.785,-0.94,-10)
#           (6.687,-0.917,-10)
#           (6.59,-0.894,-10)
#           (6.492,-0.871,-10)
#           (6.394,-0.849,-10)
#           (6.296,-0.828,-10)
#           (6.198,-0.808,-10)
#           (6.099,-0.788,-10)
#           (6.001,-0.769,-10)
#           (5.902,-0.75,-10)
#           (5.804,-0.732,-10)
#           (5.705,-0.715,-10)
#           (5.606,-0.699,-10)
#           (5.408,-0.669,-10)
#           (5.309,-0.655,-10)
#           (5.209,-0.643,-10)
#           (5.11,-0.631,-10)
#           (5.01,-0.62,-10)
#           (4.81,-0.6,-10)
#           (4.709,-0.592,-10)
#           (4.608,-0.585,-10)
#           (4.508,-0.579,-10)
#           (4.407,-0.574,-10)
#           (4.305,-0.57,-10)
#           (4.204,-0.567,-10)
#           (4,-0.565,-10)
#           (4,-0.065,-10)
#           (4.108,-0.066,-10)
#           (4.215,-0.067,-10)
#           (4.322,-0.07,-10)
#           (4.429,-0.075,-10)
#           (4.535,-0.08,-10)
#           (4.641,-0.086,-10)
#           (4.747,-0.094,-10)
#           (4.852,-0.102,-10)
#           (5.062,-0.122,-10)
#           (5.167,-0.134,-10)
#           (5.271,-0.146,-10)
#           (5.479,-0.174,-10)
#           (5.582,-0.189,-10)
#           (5.685,-0.205,-10)
#           (5.788,-0.222,-10)
#           (5.891,-0.24,-10)
#           (5.993,-0.258,-10)
#           (6.095,-0.277,-10)
#           (6.197,-0.297,-10)
#           (6.299,-0.318,-10)
#           (6.4,-0.339,-10)
#           (6.501,-0.361,-10)
#           (6.703,-0.407,-10)
#           (6.803,-0.43,-10)
#           (6.904,-0.455,-10)
#           (7.204,-0.53,-10)
#           (7.303,-0.557,-10)
#           (7.403,-0.583,-10)
#           (7.502,-0.61,-10)
#           (7.601,-0.638,-10)
#           (7.7,-0.665,-10)
#           (7.799,-0.693,-10)
#           (7.898,-0.722,-10)
#           (7.996,-0.75,-10)
#           (8.095,-0.779,-10)
#           (8.193,-0.808,-10)
#           (8.291,-0.838,-10)
#           (8.389,-0.867,-10)
#           (8.487,-0.897,-10)
#           (8.585,-0.926,-10)
#           (8.781,-0.986,-10)
#           (8.878,-1.016,-10)
#           (9.074,-1.076,-10)
#           (9.268,-1.136,-10)
#           (9.366,-1.166,-10)
#           (9.463,-1.196,-10)
#           (9.56,-1.225,-10)
#           (9.658,-1.255,-10)
#           (9.949,-1.342,-10)
#           (10.047,-1.371,-10)
#           (10.144,-1.4,-10)
#           (10.338,-1.456,-10)
#           (10.436,-1.483,-10)
#           (10.533,-1.511,-10)
#           (10.63,-1.538,-10)
#           (10.728,-1.564,-10)
#           (10.922,-1.616,-10)
#           (11.02,-1.641,-10)
#           (11.117,-1.665,-10)
#           (11.215,-1.69,-10)
#           (11.313,-1.713,-10)
#           (11.41,-1.736,-10)
#           (11.508,-1.759,-10)
#           (11.606,-1.781,-10)
#           (11.704,-1.802,-10)
#           (11.802,-1.822,-10)
#           (11.901,-1.842,-10)
#           (11.999,-1.861,-10)
#           (12.098,-1.88,-10)
#           (12.196,-1.898,-10)
#           (12.295,-1.915,-10)
#           (12.394,-1.931,-10)
#           (12.592,-1.961,-10)
#           (12.691,-1.975,-10)
#           (12.791,-1.987,-10)
#           (12.89,-1.999,-10)
#           (12.99,-2.01,-10)
#           (13.19,-2.03,-10)
#           (13.291,-2.038,-10)
#           (13.392,-2.045,-10)
#           (13.492,-2.051,-10)
#           (13.593,-2.056,-10)
#           (13.695,-2.06,-10)
#           (13.796,-2.063,-10)
#           (14,-2.065,-10)
#           (17.2,-2.065,-10)
#           (17.2,-2.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,-0.315,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,-0.565,-10)
#           (-4,-0.065,-10)
#           (4,-0.065,-10)
#           (4,-0.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 11.0814% done, 32.5614 s remaining
# subpixel-averaging is 19.6062% done, 17.803 s remaining
# subpixel-averaging is 28.1309% done, 11.1901 s remaining
# subpixel-averaging is 36.6557% done, 7.40183 s remaining
# subpixel-averaging is 69.9024% done, 1.84478 s remaining
# subpixel-averaging is 78.4272% done, 1.19654 s remaining
# subpixel-averaging is 86.952% done, 0.661437 s remaining
# subpixel-averaging is 96.3292% done, 0.154591 s remaining
# subpixel-averaging is 11.0814% done, 32.9977 s remaining
# subpixel-averaging is 19.6062% done, 17.9098 s remaining
# subpixel-averaging is 28.1309% done, 11.222 s remaining
# subpixel-averaging is 36.6557% done, 7.54071 s remaining
# subpixel-averaging is 69.9024% done, 1.86947 s remaining
# subpixel-averaging is 78.4272% done, 1.19871 s remaining
# subpixel-averaging is 86.952% done, 0.660998 s remaining
# subpixel-averaging is 96.3292% done, 0.156086 s remaining
# subpixel-averaging is 11.0814% done, 32.787 s remaining
# subpixel-averaging is 18.7537% done, 18.2052 s remaining
# subpixel-averaging is 27.2785% done, 11.7576 s remaining
# subpixel-averaging is 35.8032% done, 7.88577 s remaining
# subpixel-averaging is 69.0499% done, 1.9261 s remaining
# subpixel-averaging is 77.5747% done, 1.28195 s remaining
# subpixel-averaging is 85.247% done, 0.693912 s remaining
# subpixel-averaging is 93.7718% done, 0.282791 s remaining
# time for set_epsilon = 112.45 s
# -----------
# MPB solved for frequency_1(2.2349,0,0) = 0.686825 after 15 iters
# MPB solved for frequency_1(2.08585,0,0) = 0.645213 after 6 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 2 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 1 iters
# Meep progress: 87.36/177.5 = 49.2% done in 4.0s, 4.1s to go
# on time step 4368 (time=87.36), 0.000915846 s/step
# Meep progress: 177.26/177.5 = 99.9% done in 8.0s, 0.0s to go
# on time step 8864 (time=177.28), 0.000889738 s/step
# run 0 finished at t = 177.5 (8875 timesteps)

# %%
# S parameters
p1_coeff = sim.get_eigenmode_coefficients(
    mode1, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]
p2_coeff = sim.get_eigenmode_coefficients(
    mode2, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 1]
p3_coeff = sim.get_eigenmode_coefficients(
    mode3, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]
p4_coeff = sim.get_eigenmode_coefficients(
    mode4, [1], eig_parity=mp.NO_PARITY if three_d else mp.EVEN_Y + mp.ODD_Z
).alpha[0, 0, 0]

# transmittance
p2_trans = abs(p2_coeff) ** 2 / abs(p1_coeff) ** 2
p3_trans = abs(p3_coeff) ** 2 / abs(p1_coeff) ** 2
p4_trans = abs(p4_coeff) ** 2 / abs(p1_coeff) ** 2

print("trans:, {:.2f}, {:.6f}, {:.6f}, {:.6f}".format(d, p2_trans, p3_trans, p4_trans))
# Out:
# MPB solved for frequency_1(2.2349,0,0) = 0.686825 after 15 iters
# MPB solved for frequency_1(2.08585,0,0) = 0.645213 after 6 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 2 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.085665,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.686825 after 15 iters
# MPB solved for frequency_1(2.08585,0,0) = 0.645213 after 6 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 2 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.085665,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.686825 after 15 iters
# MPB solved for frequency_1(2.08585,0,0) = 0.645213 after 6 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 2 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.085665,-0.000000,0.000000)
# MPB solved for frequency_1(2.2349,0,0) = 0.686825 after 15 iters
# MPB solved for frequency_1(2.08585,0,0) = 0.645213 after 6 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 2 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 1 iters
# Dominant planewave for band 1: (2.085665,-0.000000,0.000000)
# trans:, 0.13, 0.000002, 0.518700, 0.478369

# %%
sim.reset_meep()

sources = [
    mp.EigenModeSource(
        src=mp.ContinuousSource(fcen, fwidth=df),
        size=src_vol.size,
        center=src_vol.center,
        eig_band=1,
        eig_parity=mp.EVEN_Y + mp.ODD_Z,
        eig_match_freq=True,
    )
]

sim = mp.Simulation(
    resolution=res,
    cell_size=cell.size,
    boundary_layers=[mp.PML(dpml)],
    sources=sources,
    geometry=geometry,
)

sim.run(
    until=400
)  # arbitrary long run time to ensure that fields have reached steady state

eps_data = sim.get_epsilon()
ez_data = numpy.real(sim.get_efield_z())

plt.figure(dpi=200)
plt.imshow(numpy.transpose(eps_data), interpolation="spline36", cmap="binary")
plt.imshow(
    numpy.flipud(numpy.transpose(ez_data)),
    interpolation="spline36",
    cmap="RdBu",
    alpha=0.9,
)
plt.axis("off")
plt.show()
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0281298 s
# Working in 2D dimensions.
# Computational cell is 34.4 x 7.84 x 0 with resolution 25
#      prism, center = (-9.09425,1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-4,0.065,-10)
#           (-4.108,0.066,-10)
#           (-4.215,0.067,-10)
#           (-4.322,0.07,-10)
#           (-4.429,0.075,-10)
#           (-4.535,0.08,-10)
#           (-4.641,0.086,-10)
#           (-4.747,0.094,-10)
#           (-4.852,0.102,-10)
#           (-5.062,0.122,-10)
#           (-5.167,0.134,-10)
#           (-5.271,0.146,-10)
#           (-5.479,0.174,-10)
#           (-5.582,0.189,-10)
#           (-5.685,0.205,-10)
#           (-5.788,0.222,-10)
#           (-5.891,0.24,-10)
#           (-5.993,0.258,-10)
#           (-6.095,0.277,-10)
#           (-6.197,0.297,-10)
#           (-6.299,0.318,-10)
#           (-6.4,0.339,-10)
#           (-6.501,0.361,-10)
#           (-6.703,0.407,-10)
#           (-6.803,0.43,-10)
#           (-6.904,0.455,-10)
#           (-7.204,0.53,-10)
#           (-7.303,0.557,-10)
#           (-7.403,0.583,-10)
#           (-7.502,0.61,-10)
#           (-7.601,0.638,-10)
#           (-7.7,0.665,-10)
#           (-7.799,0.693,-10)
#           (-7.898,0.722,-10)
#           (-7.996,0.75,-10)
#           (-8.095,0.779,-10)
#           (-8.193,0.808,-10)
#           (-8.291,0.838,-10)
#           (-8.389,0.867,-10)
#           (-8.487,0.897,-10)
#           (-8.585,0.926,-10)
#           (-8.781,0.986,-10)
#           (-8.878,1.016,-10)
#           (-9.074,1.076,-10)
#           (-9.268,1.136,-10)
#           (-9.366,1.166,-10)
#           (-9.463,1.196,-10)
#           (-9.56,1.225,-10)
#           (-9.658,1.255,-10)
#           (-9.949,1.342,-10)
#           (-10.047,1.371,-10)
#           (-10.144,1.4,-10)
#           (-10.338,1.456,-10)
#           (-10.436,1.483,-10)
#           (-10.533,1.511,-10)
#           (-10.63,1.538,-10)
#           (-10.728,1.564,-10)
#           (-10.922,1.616,-10)
#           (-11.02,1.641,-10)
#           (-11.117,1.665,-10)
#           (-11.215,1.69,-10)
#           (-11.313,1.713,-10)
#           (-11.41,1.736,-10)
#           (-11.508,1.759,-10)
#           (-11.606,1.781,-10)
#           (-11.704,1.802,-10)
#           (-11.802,1.822,-10)
#           (-11.901,1.842,-10)
#           (-11.999,1.861,-10)
#           (-12.098,1.88,-10)
#           (-12.196,1.898,-10)
#           (-12.295,1.915,-10)
#           (-12.394,1.931,-10)
#           (-12.592,1.961,-10)
#           (-12.691,1.975,-10)
#           (-12.791,1.987,-10)
#           (-12.89,1.999,-10)
#           (-12.99,2.01,-10)
#           (-13.19,2.03,-10)
#           (-13.291,2.038,-10)
#           (-13.392,2.045,-10)
#           (-13.492,2.051,-10)
#           (-13.593,2.056,-10)
#           (-13.695,2.06,-10)
#           (-13.796,2.063,-10)
#           (-14,2.065,-10)
#           (-17.2,2.065,-10)
#           (-17.2,2.565,-10)
#           (-14,2.565,-10)
#           (-13.892,2.564,-10)
#           (-13.785,2.563,-10)
#           (-13.678,2.56,-10)
#           (-13.571,2.555,-10)
#           (-13.465,2.55,-10)
#           (-13.359,2.544,-10)
#           (-13.253,2.536,-10)
#           (-13.148,2.528,-10)
#           (-12.938,2.508,-10)
#           (-12.833,2.496,-10)
#           (-12.729,2.484,-10)
#           (-12.521,2.456,-10)
#           (-12.418,2.441,-10)
#           (-12.315,2.425,-10)
#           (-12.212,2.408,-10)
#           (-12.109,2.39,-10)
#           (-12.007,2.372,-10)
#           (-11.905,2.353,-10)
#           (-11.803,2.333,-10)
#           (-11.701,2.312,-10)
#           (-11.6,2.291,-10)
#           (-11.499,2.269,-10)
#           (-11.297,2.223,-10)
#           (-11.197,2.2,-10)
#           (-11.096,2.175,-10)
#           (-10.796,2.1,-10)
#           (-10.697,2.073,-10)
#           (-10.597,2.047,-10)
#           (-10.498,2.02,-10)
#           (-10.399,1.992,-10)
#           (-10.3,1.965,-10)
#           (-10.201,1.937,-10)
#           (-10.102,1.908,-10)
#           (-10.004,1.88,-10)
#           (-9.905,1.851,-10)
#           (-9.807,1.822,-10)
#           (-9.709,1.792,-10)
#           (-9.611,1.763,-10)
#           (-9.513,1.733,-10)
#           (-9.415,1.704,-10)
#           (-9.219,1.644,-10)
#           (-9.122,1.614,-10)
#           (-8.926,1.554,-10)
#           (-8.732,1.494,-10)
#           (-8.634,1.464,-10)
#           (-8.537,1.434,-10)
#           (-8.44,1.405,-10)
#           (-8.342,1.375,-10)
#           (-8.051,1.288,-10)
#           (-7.953,1.259,-10)
#           (-7.856,1.23,-10)
#           (-7.662,1.174,-10)
#           (-7.564,1.147,-10)
#           (-7.467,1.119,-10)
#           (-7.37,1.092,-10)
#           (-7.272,1.066,-10)
#           (-7.078,1.014,-10)
#           (-6.98,0.989,-10)
#           (-6.883,0.965,-10)
#           (-6.785,0.94,-10)
#           (-6.687,0.917,-10)
#           (-6.59,0.894,-10)
#           (-6.492,0.871,-10)
#           (-6.394,0.849,-10)
#           (-6.296,0.828,-10)
#           (-6.198,0.808,-10)
#           (-6.099,0.788,-10)
#           (-6.001,0.769,-10)
#           (-5.902,0.75,-10)
#           (-5.804,0.732,-10)
#           (-5.705,0.715,-10)
#           (-5.606,0.699,-10)
#           (-5.408,0.669,-10)
#           (-5.309,0.655,-10)
#           (-5.209,0.643,-10)
#           (-5.11,0.631,-10)
#           (-5.01,0.62,-10)
#           (-4.81,0.6,-10)
#           (-4.709,0.592,-10)
#           (-4.608,0.585,-10)
#           (-4.508,0.579,-10)
#           (-4.407,0.574,-10)
#           (-4.305,0.57,-10)
#           (-4.204,0.567,-10)
#           (-4,0.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (4,0.065,-10)
#           (4,0.565,-10)
#           (4.204,0.567,-10)
#           (4.305,0.57,-10)
#           (4.407,0.574,-10)
#           (4.508,0.579,-10)
#           (4.608,0.585,-10)
#           (4.709,0.592,-10)
#           (4.81,0.6,-10)
#           (5.01,0.62,-10)
#           (5.11,0.631,-10)
#           (5.209,0.643,-10)
#           (5.309,0.655,-10)
#           (5.408,0.669,-10)
#           (5.606,0.699,-10)
#           (5.705,0.715,-10)
#           (5.804,0.732,-10)
#           (5.902,0.75,-10)
#           (6.001,0.769,-10)
#           (6.099,0.788,-10)
#           (6.198,0.808,-10)
#           (6.296,0.828,-10)
#           (6.394,0.849,-10)
#           (6.492,0.871,-10)
#           (6.59,0.894,-10)
#           (6.687,0.917,-10)
#           (6.785,0.94,-10)
#           (6.883,0.965,-10)
#           (6.98,0.989,-10)
#           (7.078,1.014,-10)
#           (7.272,1.066,-10)
#           (7.37,1.092,-10)
#           (7.467,1.119,-10)
#           (7.564,1.147,-10)
#           (7.662,1.174,-10)
#           (7.856,1.23,-10)
#           (7.953,1.259,-10)
#           (8.051,1.288,-10)
#           (8.342,1.375,-10)
#           (8.44,1.405,-10)
#           (8.537,1.434,-10)
#           (8.634,1.464,-10)
#           (8.732,1.494,-10)
#           (8.926,1.554,-10)
#           (9.122,1.614,-10)
#           (9.219,1.644,-10)
#           (9.415,1.704,-10)
#           (9.513,1.733,-10)
#           (9.611,1.763,-10)
#           (9.709,1.792,-10)
#           (9.807,1.822,-10)
#           (9.905,1.851,-10)
#           (10.004,1.88,-10)
#           (10.102,1.908,-10)
#           (10.201,1.937,-10)
#           (10.3,1.965,-10)
#           (10.399,1.992,-10)
#           (10.498,2.02,-10)
#           (10.597,2.047,-10)
#           (10.697,2.073,-10)
#           (10.796,2.1,-10)
#           (11.096,2.175,-10)
#           (11.197,2.2,-10)
#           (11.297,2.223,-10)
#           (11.499,2.269,-10)
#           (11.6,2.291,-10)
#           (11.701,2.312,-10)
#           (11.803,2.333,-10)
#           (11.905,2.353,-10)
#           (12.007,2.372,-10)
#           (12.109,2.39,-10)
#           (12.212,2.408,-10)
#           (12.315,2.425,-10)
#           (12.418,2.441,-10)
#           (12.521,2.456,-10)
#           (12.729,2.484,-10)
#           (12.833,2.496,-10)
#           (12.938,2.508,-10)
#           (13.148,2.528,-10)
#           (13.253,2.536,-10)
#           (13.359,2.544,-10)
#           (13.465,2.55,-10)
#           (13.571,2.555,-10)
#           (13.678,2.56,-10)
#           (13.785,2.563,-10)
#           (13.892,2.564,-10)
#           (14,2.565,-10)
#           (17.2,2.565,-10)
#           (17.2,2.065,-10)
#           (14,2.065,-10)
#           (13.796,2.063,-10)
#           (13.695,2.06,-10)
#           (13.593,2.056,-10)
#           (13.492,2.051,-10)
#           (13.392,2.045,-10)
#           (13.291,2.038,-10)
#           (13.19,2.03,-10)
#           (12.99,2.01,-10)
#           (12.89,1.999,-10)
#           (12.791,1.987,-10)
#           (12.691,1.975,-10)
#           (12.592,1.961,-10)
#           (12.394,1.931,-10)
#           (12.295,1.915,-10)
#           (12.196,1.898,-10)
#           (12.098,1.88,-10)
#           (11.999,1.861,-10)
#           (11.901,1.842,-10)
#           (11.802,1.822,-10)
#           (11.704,1.802,-10)
#           (11.606,1.781,-10)
#           (11.508,1.759,-10)
#           (11.41,1.736,-10)
#           (11.313,1.713,-10)
#           (11.215,1.69,-10)
#           (11.117,1.665,-10)
#           (11.02,1.641,-10)
#           (10.922,1.616,-10)
#           (10.728,1.564,-10)
#           (10.63,1.538,-10)
#           (10.533,1.511,-10)
#           (10.436,1.483,-10)
#           (10.338,1.456,-10)
#           (10.144,1.4,-10)
#           (10.047,1.371,-10)
#           (9.949,1.342,-10)
#           (9.658,1.255,-10)
#           (9.56,1.225,-10)
#           (9.463,1.196,-10)
#           (9.366,1.166,-10)
#           (9.268,1.136,-10)
#           (9.074,1.076,-10)
#           (8.878,1.016,-10)
#           (8.781,0.986,-10)
#           (8.585,0.926,-10)
#           (8.487,0.897,-10)
#           (8.389,0.867,-10)
#           (8.291,0.838,-10)
#           (8.193,0.808,-10)
#           (8.095,0.779,-10)
#           (7.996,0.75,-10)
#           (7.898,0.722,-10)
#           (7.799,0.693,-10)
#           (7.7,0.665,-10)
#           (7.601,0.638,-10)
#           (7.502,0.61,-10)
#           (7.403,0.583,-10)
#           (7.303,0.557,-10)
#           (7.204,0.53,-10)
#           (6.904,0.455,-10)
#           (6.803,0.43,-10)
#           (6.703,0.407,-10)
#           (6.501,0.361,-10)
#           (6.4,0.339,-10)
#           (6.299,0.318,-10)
#           (6.197,0.297,-10)
#           (6.095,0.277,-10)
#           (5.993,0.258,-10)
#           (5.891,0.24,-10)
#           (5.788,0.222,-10)
#           (5.685,0.205,-10)
#           (5.582,0.189,-10)
#           (5.479,0.174,-10)
#           (5.271,0.146,-10)
#           (5.167,0.134,-10)
#           (5.062,0.122,-10)
#           (4.852,0.102,-10)
#           (4.747,0.094,-10)
#           (4.641,0.086,-10)
#           (4.535,0.08,-10)
#           (4.429,0.075,-10)
#           (4.322,0.07,-10)
#           (4.215,0.067,-10)
#           (4.108,0.066,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,0.315,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,0.065,-10)
#           (-4,0.565,-10)
#           (4,0.565,-10)
#           (4,0.065,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (-9.09425,-1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (-17.2,-2.565,-10)
#           (-17.2,-2.065,-10)
#           (-14,-2.065,-10)
#           (-13.796,-2.063,-10)
#           (-13.695,-2.06,-10)
#           (-13.593,-2.056,-10)
#           (-13.492,-2.051,-10)
#           (-13.392,-2.045,-10)
#           (-13.291,-2.038,-10)
#           (-13.19,-2.03,-10)
#           (-12.99,-2.01,-10)
#           (-12.89,-1.999,-10)
#           (-12.791,-1.987,-10)
#           (-12.691,-1.975,-10)
#           (-12.592,-1.961,-10)
#           (-12.394,-1.931,-10)
#           (-12.295,-1.915,-10)
#           (-12.196,-1.898,-10)
#           (-12.098,-1.88,-10)
#           (-11.999,-1.861,-10)
#           (-11.901,-1.842,-10)
#           (-11.802,-1.822,-10)
#           (-11.704,-1.802,-10)
#           (-11.606,-1.781,-10)
#           (-11.508,-1.759,-10)
#           (-11.41,-1.736,-10)
#           (-11.313,-1.713,-10)
#           (-11.215,-1.69,-10)
#           (-11.117,-1.665,-10)
#           (-11.02,-1.641,-10)
#           (-10.922,-1.616,-10)
#           (-10.728,-1.564,-10)
#           (-10.63,-1.538,-10)
#           (-10.533,-1.511,-10)
#           (-10.436,-1.483,-10)
#           (-10.338,-1.456,-10)
#           (-10.144,-1.4,-10)
#           (-10.047,-1.371,-10)
#           (-9.949,-1.342,-10)
#           (-9.658,-1.255,-10)
#           (-9.56,-1.225,-10)
#           (-9.463,-1.196,-10)
#           (-9.366,-1.166,-10)
#           (-9.268,-1.136,-10)
#           (-9.074,-1.076,-10)
#           (-8.878,-1.016,-10)
#           (-8.781,-0.986,-10)
#           (-8.585,-0.926,-10)
#           (-8.487,-0.897,-10)
#           (-8.389,-0.867,-10)
#           (-8.291,-0.838,-10)
#           (-8.193,-0.808,-10)
#           (-8.095,-0.779,-10)
#           (-7.996,-0.75,-10)
#           (-7.898,-0.722,-10)
#           (-7.799,-0.693,-10)
#           (-7.7,-0.665,-10)
#           (-7.601,-0.638,-10)
#           (-7.502,-0.61,-10)
#           (-7.403,-0.583,-10)
#           (-7.303,-0.557,-10)
#           (-7.204,-0.53,-10)
#           (-6.904,-0.455,-10)
#           (-6.803,-0.43,-10)
#           (-6.703,-0.407,-10)
#           (-6.501,-0.361,-10)
#           (-6.4,-0.339,-10)
#           (-6.299,-0.318,-10)
#           (-6.197,-0.297,-10)
#           (-6.095,-0.277,-10)
#           (-5.993,-0.258,-10)
#           (-5.891,-0.24,-10)
#           (-5.788,-0.222,-10)
#           (-5.685,-0.205,-10)
#           (-5.582,-0.189,-10)
#           (-5.479,-0.174,-10)
#           (-5.271,-0.146,-10)
#           (-5.167,-0.134,-10)
#           (-5.062,-0.122,-10)
#           (-4.852,-0.102,-10)
#           (-4.747,-0.094,-10)
#           (-4.641,-0.086,-10)
#           (-4.535,-0.08,-10)
#           (-4.429,-0.075,-10)
#           (-4.322,-0.07,-10)
#           (-4.215,-0.067,-10)
#           (-4.108,-0.066,-10)
#           (-4,-0.065,-10)
#           (-4,-0.565,-10)
#           (-4.204,-0.567,-10)
#           (-4.305,-0.57,-10)
#           (-4.407,-0.574,-10)
#           (-4.508,-0.579,-10)
#           (-4.608,-0.585,-10)
#           (-4.709,-0.592,-10)
#           (-4.81,-0.6,-10)
#           (-5.01,-0.62,-10)
#           (-5.11,-0.631,-10)
#           (-5.209,-0.643,-10)
#           (-5.309,-0.655,-10)
#           (-5.408,-0.669,-10)
#           (-5.606,-0.699,-10)
#           (-5.705,-0.715,-10)
#           (-5.804,-0.732,-10)
#           (-5.902,-0.75,-10)
#           (-6.001,-0.769,-10)
#           (-6.099,-0.788,-10)
#           (-6.198,-0.808,-10)
#           (-6.296,-0.828,-10)
#           (-6.394,-0.849,-10)
#           (-6.492,-0.871,-10)
#           (-6.59,-0.894,-10)
#           (-6.687,-0.917,-10)
#           (-6.785,-0.94,-10)
#           (-6.883,-0.965,-10)
#           (-6.98,-0.989,-10)
#           (-7.078,-1.014,-10)
#           (-7.272,-1.066,-10)
#           (-7.37,-1.092,-10)
#           (-7.467,-1.119,-10)
#           (-7.564,-1.147,-10)
#           (-7.662,-1.174,-10)
#           (-7.856,-1.23,-10)
#           (-7.953,-1.259,-10)
#           (-8.051,-1.288,-10)
#           (-8.342,-1.375,-10)
#           (-8.44,-1.405,-10)
#           (-8.537,-1.434,-10)
#           (-8.634,-1.464,-10)
#           (-8.732,-1.494,-10)
#           (-8.926,-1.554,-10)
#           (-9.122,-1.614,-10)
#           (-9.219,-1.644,-10)
#           (-9.415,-1.704,-10)
#           (-9.513,-1.733,-10)
#           (-9.611,-1.763,-10)
#           (-9.709,-1.792,-10)
#           (-9.807,-1.822,-10)
#           (-9.905,-1.851,-10)
#           (-10.004,-1.88,-10)
#           (-10.102,-1.908,-10)
#           (-10.201,-1.937,-10)
#           (-10.3,-1.965,-10)
#           (-10.399,-1.992,-10)
#           (-10.498,-2.02,-10)
#           (-10.597,-2.047,-10)
#           (-10.697,-2.073,-10)
#           (-10.796,-2.1,-10)
#           (-11.096,-2.175,-10)
#           (-11.197,-2.2,-10)
#           (-11.297,-2.223,-10)
#           (-11.499,-2.269,-10)
#           (-11.6,-2.291,-10)
#           (-11.701,-2.312,-10)
#           (-11.803,-2.333,-10)
#           (-11.905,-2.353,-10)
#           (-12.007,-2.372,-10)
#           (-12.109,-2.39,-10)
#           (-12.212,-2.408,-10)
#           (-12.315,-2.425,-10)
#           (-12.418,-2.441,-10)
#           (-12.521,-2.456,-10)
#           (-12.729,-2.484,-10)
#           (-12.833,-2.496,-10)
#           (-12.938,-2.508,-10)
#           (-13.148,-2.528,-10)
#           (-13.253,-2.536,-10)
#           (-13.359,-2.544,-10)
#           (-13.465,-2.55,-10)
#           (-13.571,-2.555,-10)
#           (-13.678,-2.56,-10)
#           (-13.785,-2.563,-10)
#           (-13.892,-2.564,-10)
#           (-14,-2.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (9.09425,-1.32649,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 174 vertices:
#           (14,-2.565,-10)
#           (13.892,-2.564,-10)
#           (13.785,-2.563,-10)
#           (13.678,-2.56,-10)
#           (13.571,-2.555,-10)
#           (13.465,-2.55,-10)
#           (13.359,-2.544,-10)
#           (13.253,-2.536,-10)
#           (13.148,-2.528,-10)
#           (12.938,-2.508,-10)
#           (12.833,-2.496,-10)
#           (12.729,-2.484,-10)
#           (12.521,-2.456,-10)
#           (12.418,-2.441,-10)
#           (12.315,-2.425,-10)
#           (12.212,-2.408,-10)
#           (12.109,-2.39,-10)
#           (12.007,-2.372,-10)
#           (11.905,-2.353,-10)
#           (11.803,-2.333,-10)
#           (11.701,-2.312,-10)
#           (11.6,-2.291,-10)
#           (11.499,-2.269,-10)
#           (11.297,-2.223,-10)
#           (11.197,-2.2,-10)
#           (11.096,-2.175,-10)
#           (10.796,-2.1,-10)
#           (10.697,-2.073,-10)
#           (10.597,-2.047,-10)
#           (10.498,-2.02,-10)
#           (10.399,-1.992,-10)
#           (10.3,-1.965,-10)
#           (10.201,-1.937,-10)
#           (10.102,-1.908,-10)
#           (10.004,-1.88,-10)
#           (9.905,-1.851,-10)
#           (9.807,-1.822,-10)
#           (9.709,-1.792,-10)
#           (9.611,-1.763,-10)
#           (9.513,-1.733,-10)
#           (9.415,-1.704,-10)
#           (9.219,-1.644,-10)
#           (9.122,-1.614,-10)
#           (8.926,-1.554,-10)
#           (8.732,-1.494,-10)
#           (8.634,-1.464,-10)
#           (8.537,-1.434,-10)
#           (8.44,-1.405,-10)
#           (8.342,-1.375,-10)
#           (8.051,-1.288,-10)
#           (7.953,-1.259,-10)
#           (7.856,-1.23,-10)
#           (7.662,-1.174,-10)
#           (7.564,-1.147,-10)
#           (7.467,-1.119,-10)
#           (7.37,-1.092,-10)
#           (7.272,-1.066,-10)
#           (7.078,-1.014,-10)
#           (6.98,-0.989,-10)
#           (6.883,-0.965,-10)
#           (6.785,-0.94,-10)
#           (6.687,-0.917,-10)
#           (6.59,-0.894,-10)
#           (6.492,-0.871,-10)
#           (6.394,-0.849,-10)
#           (6.296,-0.828,-10)
#           (6.198,-0.808,-10)
#           (6.099,-0.788,-10)
#           (6.001,-0.769,-10)
#           (5.902,-0.75,-10)
#           (5.804,-0.732,-10)
#           (5.705,-0.715,-10)
#           (5.606,-0.699,-10)
#           (5.408,-0.669,-10)
#           (5.309,-0.655,-10)
#           (5.209,-0.643,-10)
#           (5.11,-0.631,-10)
#           (5.01,-0.62,-10)
#           (4.81,-0.6,-10)
#           (4.709,-0.592,-10)
#           (4.608,-0.585,-10)
#           (4.508,-0.579,-10)
#           (4.407,-0.574,-10)
#           (4.305,-0.57,-10)
#           (4.204,-0.567,-10)
#           (4,-0.565,-10)
#           (4,-0.065,-10)
#           (4.108,-0.066,-10)
#           (4.215,-0.067,-10)
#           (4.322,-0.07,-10)
#           (4.429,-0.075,-10)
#           (4.535,-0.08,-10)
#           (4.641,-0.086,-10)
#           (4.747,-0.094,-10)
#           (4.852,-0.102,-10)
#           (5.062,-0.122,-10)
#           (5.167,-0.134,-10)
#           (5.271,-0.146,-10)
#           (5.479,-0.174,-10)
#           (5.582,-0.189,-10)
#           (5.685,-0.205,-10)
#           (5.788,-0.222,-10)
#           (5.891,-0.24,-10)
#           (5.993,-0.258,-10)
#           (6.095,-0.277,-10)
#           (6.197,-0.297,-10)
#           (6.299,-0.318,-10)
#           (6.4,-0.339,-10)
#           (6.501,-0.361,-10)
#           (6.703,-0.407,-10)
#           (6.803,-0.43,-10)
#           (6.904,-0.455,-10)
#           (7.204,-0.53,-10)
#           (7.303,-0.557,-10)
#           (7.403,-0.583,-10)
#           (7.502,-0.61,-10)
#           (7.601,-0.638,-10)
#           (7.7,-0.665,-10)
#           (7.799,-0.693,-10)
#           (7.898,-0.722,-10)
#           (7.996,-0.75,-10)
#           (8.095,-0.779,-10)
#           (8.193,-0.808,-10)
#           (8.291,-0.838,-10)
#           (8.389,-0.867,-10)
#           (8.487,-0.897,-10)
#           (8.585,-0.926,-10)
#           (8.781,-0.986,-10)
#           (8.878,-1.016,-10)
#           (9.074,-1.076,-10)
#           (9.268,-1.136,-10)
#           (9.366,-1.166,-10)
#           (9.463,-1.196,-10)
#           (9.56,-1.225,-10)
#           (9.658,-1.255,-10)
#           (9.949,-1.342,-10)
#           (10.047,-1.371,-10)
#           (10.144,-1.4,-10)
#           (10.338,-1.456,-10)
#           (10.436,-1.483,-10)
#           (10.533,-1.511,-10)
#           (10.63,-1.538,-10)
#           (10.728,-1.564,-10)
#           (10.922,-1.616,-10)
#           (11.02,-1.641,-10)
#           (11.117,-1.665,-10)
#           (11.215,-1.69,-10)
#           (11.313,-1.713,-10)
#           (11.41,-1.736,-10)
#           (11.508,-1.759,-10)
#           (11.606,-1.781,-10)
#           (11.704,-1.802,-10)
#           (11.802,-1.822,-10)
#           (11.901,-1.842,-10)
#           (11.999,-1.861,-10)
#           (12.098,-1.88,-10)
#           (12.196,-1.898,-10)
#           (12.295,-1.915,-10)
#           (12.394,-1.931,-10)
#           (12.592,-1.961,-10)
#           (12.691,-1.975,-10)
#           (12.791,-1.987,-10)
#           (12.89,-1.999,-10)
#           (12.99,-2.01,-10)
#           (13.19,-2.03,-10)
#           (13.291,-2.038,-10)
#           (13.392,-2.045,-10)
#           (13.492,-2.051,-10)
#           (13.593,-2.056,-10)
#           (13.695,-2.06,-10)
#           (13.796,-2.063,-10)
#           (14,-2.065,-10)
#           (17.2,-2.065,-10)
#           (17.2,-2.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
#      prism, center = (0,-0.315,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 4 vertices:
#           (-4,-0.565,-10)
#           (-4,-0.065,-10)
#           (4,-0.065,-10)
#           (4,-0.565,-10)
#           dielectric constant epsilon diagonal = (12,12,12)
# subpixel-averaging is 11.0814% done, 33.1786 s remaining
# subpixel-averaging is 19.6062% done, 18.1602 s remaining
# subpixel-averaging is 28.1309% done, 11.2875 s remaining
# subpixel-averaging is 36.6557% done, 7.54536 s remaining
# subpixel-averaging is 69.9024% done, 1.87061 s remaining
# subpixel-averaging is 78.4272% done, 1.20449 s remaining
# subpixel-averaging is 86.0995% done, 0.648143 s remaining
# subpixel-averaging is 94.6243% done, 0.229099 s remaining
# subpixel-averaging is 11.0814% done, 33.2239 s remaining
# subpixel-averaging is 18.7537% done, 17.4253 s remaining
# subpixel-averaging is 27.2785% done, 11.8398 s remaining
# subpixel-averaging is 35.8032% done, 7.97832 s remaining
# subpixel-averaging is 68.1974% done, 1.91836 s remaining
# subpixel-averaging is 75.8697% done, 1.27933 s remaining
# subpixel-averaging is 83.542% done, 0.791791 s remaining
# subpixel-averaging is 92.0668% done, 0.381089 s remaining
# subpixel-averaging is 11.0814% done, 33.4611 s remaining
# subpixel-averaging is 18.7537% done, 17.4901 s remaining
# subpixel-averaging is 27.2785% done, 11.8309 s remaining
# subpixel-averaging is 35.8032% done, 7.98305 s remaining
# subpixel-averaging is 69.0499% done, 1.95288 s remaining
# subpixel-averaging is 76.7222% done, 1.21667 s remaining
# subpixel-averaging is 84.3945% done, 0.743449 s remaining
# subpixel-averaging is 92.9193% done, 0.336389 s remaining
# time for set_epsilon = 113.965 s
# -----------
# MPB solved for frequency_1(2.2349,0,0) = 0.686825 after 15 iters
# MPB solved for frequency_1(2.08585,0,0) = 0.645213 after 6 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 2 iters
# MPB solved for frequency_1(2.08567,0,0) = 0.645161 after 1 iters
# Meep progress: 86.84/400.0 = 21.7% done in 4.0s, 14.4s to go
# on time step 4342 (time=86.84), 0.000921385 s/step
# Meep progress: 175.68/400.0 = 43.9% done in 8.0s, 10.2s to go
# on time step 8785 (time=175.7), 0.00090037 s/step
# Meep progress: 262.02/400.0 = 65.5% done in 12.0s, 6.3s to go
# on time step 13103 (time=262.06), 0.000926373 s/step
# Meep progress: 350.84000000000003/400.0 = 87.7% done in 16.0s, 2.2s to go
# on time step 17546 (time=350.92), 0.000900467 s/step
# run 0 finished at t = 400.0 (20000 timesteps)
# /home/311514090/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/311514090/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
