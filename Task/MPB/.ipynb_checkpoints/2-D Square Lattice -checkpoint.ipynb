# %%
import math  
import meep as mp
from meep import mpb

# %%
def print_heading(h):
    stars = "*" * 10
    print("{0} {1} {0}".format(stars, h))

# %% [markdown]
# 簡述
# ===========
# 每個參數對應的 Modesolver 都有預設值，故使用時只需修改想改變的參數即可。
# 1. 參數 num_bands 控制每個k點計算多少條帶，預設值為1，因浴室值太小，將其改為8
# 2. 計算波段的 k 點（Bloch wavevectors）。這裡由參數 k_points 控制，它是一個最初為空的 3 向量列表。將它設置在方格的irreducible Brillouin zone的角上，$\Gamma$、X、M 和 $\Gamma$，形成重複週期。
# 3. 我們還需要計算許多中間 k 點的能帶，以便我們看到連續能帶結構，因此可以可以調用 pymeep 提供的函數 interpolate 來為我們插入它們，而不是手動指定所有這些中間點。example為在兩個連續點中線性插入新的四個點。由print可知已成功獲得16個點。
# 4. 程式中所有的空間向量都是長度標準化的晶格方向上制定，k 個點是根據（未歸一化的）倒易晶格向量指定的。在這種情況下，我們不必指定晶格方向，

# %%
num_bands = 8

# %%
k_points = [mp.Vector3(),
            mp.Vector3(0.5),
            mp.Vector3(0.5,0.5),
            mp.Vector3()]

# %%
k_points = mp.interpolate(4, k_points)

# %%
#print(k_points)

# %% [markdown]
# 設置系統的幾何形狀
# ------
# * 以原點為中心建立晶格的最小單位。
# * 此架構建立棒狀方形晶格。
# * 此架構　半徑0.2，沿軸的長度無窮大(z方向)
# * 由於幾何結構為三維，但現在要計算二維模擬，所以用geometry_lattice參數來控制，在計算單元的大小時，調整meep.Lattice，使某個維度大小設置成0，用此方式來降低維度。

# %%
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]

# %%
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1))

# %% [markdown]
# 模擬
# ---
# * 定義了一個 1x1 的二維單元格（默認為正方形）。該單元根據resolution參數離散化，默認為 10（像素/點陣單位），在此改成32。這樣就會形成32x32 的計算網格。(習慣上用2的冪次方倍較佳，)
# * 計算能帶結構最簡單的方式為 ms.run() ，但由於這是一個二維計算，因此將波段分成 TE 和 TM 偏振模式，藉由調整ms.run_te()和ms.run_tm()來完成

# %%
resolution = 32

# %%
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)

# %%
print_heading("Square lattice of rods: TE bands")
ms.run_te()
# Out:
# ********** Square lattice of rods: TE bands **********
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.023792028427124023
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 15.86234744884084 (194.117% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 6.98474714221614 (77.7132% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.105282684677089 (13.4372% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.820610837904765 (4.77401% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.696561284165865 (2.15417% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.631317799331819 (1.15191% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.591424052774011 (0.710945% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.572419909309857 (0.340459% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 5.564034362048796 (0.150596% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.559092401448836 (0.0888592% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.556977231286762 (0.0380561% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 5.555831256648106 (0.0206244% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 5.555104654636279 (0.013079% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 5.554600519842162 (0.00907557% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 5.553997616709917 (0.0108547% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 5.553185185365497 (0.0146289% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 5.551980205817248 (0.0217012% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.550605693359431 (0.0247602% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.549703791188357 (0.01625% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.549079452533944 (0.0112506% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 5.548725893710515 (0.00637169% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 5.548497735661519 (0.00411198% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 5.548339587220303 (0.00285033% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 5.548242410209323 (0.00175148% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 5.548174663247609 (0.00122106% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 5.548141089232068 (0.000605138% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 5.548130238512771 (0.000195574% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 5.548126024371549 (7.59561e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 5.548124207603002 (3.27456e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 5.548123236471261 (1.75038e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 5.548122633636467 (1.08656e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 5.548122186275779 (8.06328e-06% change)
# Finished solving for bands 2 to 8 after 32 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# elapsed time for k point: 0.16582083702087402
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.581268013417526 (0.239933% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.573794692042148 (0.13399% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.571427054818505 (0.042487% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.569947030360993 (0.0265681% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.569095489901032 (0.0152893% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.568405969825734 (0.012382% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.567974226664225 (0.00775374% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.567687379653339 (0.00515186% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.567547544826261 (0.00251157% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 5.56745698131924 (0.00162665% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 65.1975%)
#     iteration   11: trace = 5.567417768890456 (0.000704317% change)
#     iteration   12: trace = 5.567401963090941 (0.000283899% change)
#     iteration   13: trace = 5.567395351364055 (0.000118758% change)
#     iteration   14: trace = 5.567392813986743 (4.55757e-05% change)
#     iteration   15: trace = 5.567389808313047 (5.39871e-05% change)
#     iteration   16: trace = 5.56738501457933 (8.61038e-05% change)
#     iteration   17: trace = 5.567372460755278 (0.000225489% change)
#     switching back to exact line minimization
#     large trace change predicted (0.00869485%)
#     linmin: converged after 6 iterations.
#     iteration   18: trace = 5.567160894031175 (0.00380019% change)
#     large trace change predicted (0.0154971%)
#     linmin: converged after 6 iterations.
#     iteration   19: trace = 5.566976193977258 (0.00331773% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.566883065452995 (0.00167289% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.566808745865274 (0.00133504% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.566743315438312 (0.00117537% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 5.566682950009263 (0.0010844% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 5.566625713052395 (0.00102821% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.566570441570372 (0.000992913% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.566516327321144 (0.000972134% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 5.566462723710057 (0.00096297% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 5.566409045003574 (0.000964328% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 5.566354711331661 (0.000976104% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.566299120941096 (0.000998691% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.56624164196272 (0.00103263% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.566181621126166 (0.00107831% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 5.566118409927929 (0.00113564% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 5.566051410399929 (0.00120371% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 5.565980142074979 (0.00128042% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 5.565904327438171 (0.00136212% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 5.565823983808718 (0.00144351% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 5.565739496658859 (0.00151797% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.565651639933773 (0.00157854% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.565561514699189 (0.00161932% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.565470404935605 (0.00163704% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.565379587263356 (0.00163182% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.56529015396637 (0.00160697% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.565202899075888 (0.00156785% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.565118284821124 (0.00152043% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.565036474407506 (0.00147007% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.564957402422046 (0.00142088% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.564880855710888 (0.00137552% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.564806546816164 (0.00133533% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.564734171590991 (0.0013006% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.564663449195274 (0.00127091% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.564594146130473 (0.00124542% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.564526087301559 (0.00122308% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.564459157323469 (0.0012028% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.564393295067742 (0.00118363% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.564328484069014 (0.00116475% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.564264740970771 (0.00114557% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.564202103710677 (0.00112571% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 5.564140620653945 (0.00110498% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 5.564080341424107 (0.00108336% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 5.564021309795564 (0.00106095% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.563963558726542 (0.00103794% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.563907107420458 (0.00101459% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.56385196019183 (0.000991165% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.563798106851483 (0.000967919% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 5.563745524296931 (0.000945088% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 5.563694178983148 (0.000922859% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 5.563644029951114 (0.000901366% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 5.563595032105059 (0.000880683% change)
#     resetting CG direction...
#     large trace change predicted (0.180467%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 5.553480319463438 (0.181967% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 5.545291285286244 (0.147566% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 5.542773992624229 (0.0454054% change)
#     linmin: converged after 4 iterations.
#     iteration   73: trace = 5.541139384438798 (0.0294951% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 5.540751157199931 (0.00700652% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 5.5406574746623 (0.00169081% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 5.540621294152096 (0.000653002% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 5.540602939735672 (0.000331271% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 5.540583617924374 (0.000348732% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 5.540574174467231 (0.000170442% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 5.540565076700359 (0.000164203% change)
#     linmin: converged after 3 iterations.
#     iteration   81: trace = 5.540553068490778 (0.000216733% change)
#     linmin: converged after 3 iterations.
#     iteration   82: trace = 5.540531958187893 (0.000381015% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 5.540509985075561 (0.000396589% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.540502315995607 (0.000138418% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 5.540499218152354 (5.59127e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   86: trace = 5.540498040641295 (2.12528e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   87: trace = 5.540497677215403 (6.55944e-06% change)
# Finished solving for bands 1 to 8 after 87 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.1, 0.0897333, 0.551138, 0.7616, 0.774682, 0.907199, 1.00188, 1.00357, 1.10209
# elapsed time for k point: 0.38475894927978516
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.514279440213775 (0.408151% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.503844676150572 (0.189411% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.500836388011941 (0.0546729% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.499873711877154 (0.0175021% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.499509621275893 (0.0066202% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.499421833405242 (0.0015963% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.499394162219272 (0.000503167% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.499382431490401 (0.00021331% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.49937817384895 (7.74204e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.499376218022775 (3.55645e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.499375465527434 (1.36833e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.499375164692989 (5.47034e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.2, 0.178692, 0.544896, 0.728534, 0.778528, 0.880244, 1.00699, 1.01696, 1.10027
# elapsed time for k point: 0.05771207809448242
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.496159454433146 (0.277878% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.489510036277228 (0.121056% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.487055335890695 (0.0447262% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 59.7434%)
#     iteration    4: trace = 5.486204317308625 (0.0155108% change)
#     iteration    5: trace = 5.485738874135309 (0.00848424% change)
#     iteration    6: trace = 5.485576300319965 (0.00296362% change)
#     iteration    7: trace = 5.485498718883634 (0.00141429% change)
#     iteration    8: trace = 5.485469816869335 (0.000526882% change)
#     switching back to exact line minimization
#     iteration    9: trace = 5.485462047973842 (0.000141627% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.485459953406297 (3.8184e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.485459329328776 (1.13769e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.485459178146303 (2.75606e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.3, 0.265798, 0.528176, 0.685449, 0.783377, 0.860714, 1.01515, 1.03843, 1.09664
# elapsed time for k point: 0.05698227882385254
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.518168782475065 (0.240394% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.511317259288193 (0.12424% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.507826807404666 (0.0633525% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.506159371953618 (0.0302785% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.505015638334223 (0.0207741% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.504616467802651 (0.0072513% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.504453328494979 (0.00296373% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.504401077661905 (0.000949251% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.504383247487638 (0.000323926% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.504375648342567 (0.000138056% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 65.4752%)
#     iteration   11: trace = 5.504370454040485 (9.43668e-05% change)
#     iteration   12: trace = 5.504366823934431 (6.59495e-05% change)
#     iteration   13: trace = 5.504364142161014 (4.87208e-05% change)
#     iteration   14: trace = 5.504362901029688 (2.25481e-05% change)
#     iteration   15: trace = 5.50436243075062 (8.54375e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.4, 0.348956, 0.490738, 0.652797, 0.787382, 0.849999, 1.02443, 1.06441, 1.09121
# elapsed time for k point: 0.09450984001159668
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.568058595276797 (0.237297% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.559204726955513 (0.159138% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.5537456160964 (0.0982477% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.550308550679302 (0.0619065% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.9745%)
#     iteration    5: trace = 5.547656114837213 (0.0478004% change)
#     iteration    6: trace = 5.546448492894132 (0.0217705% change)
#     iteration    7: trace = 5.545505856850322 (0.0169968% change)
#     switching back to exact line minimization
#     iteration    8: trace = 5.544439472755369 (0.0192315% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 5.542889446090248 (0.0279603% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.541154704304763 (0.0313016% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.539947507982056 (0.0217884% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.539377851540115 (0.0102832% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.539088077845922 (0.0052313% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.538951286478017 (0.0024696% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.538901827294652 (0.000892938% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.538882111952842 (0.000355944% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.538873489231703 (0.000155676% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.53886901260822 (8.08219e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 5.538867814732773 (2.16267e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 5.538867401934853 (7.45275e-06% change)
# Finished solving for bands 1 to 8 after 20 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.5, 0.412791, 0.441588, 0.641998, 0.788933, 0.846588, 1.02916, 1.08607, 1.08787
# elapsed time for k point: 0.0927426815032959
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.490820392835136 (1.61949% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.441582112659419 (0.900777% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.429096318198534 (0.229715% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.4239171854966 (0.0954414% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.421563790340721 (0.0433986% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.420537997600669 (0.0189224% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.420080190938283 (0.00844614% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.41992205567898 (0.00291762% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.419861597576961 (0.00111549% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.4198277452672 (0.000624599% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.419810504617431 (0.000318104% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.419802232249351 (0.000152632% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.419799017954144 (5.93065e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.419798178645564 (1.5486e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 69.036%)
#     iteration   15: trace = 5.419797876779603 (5.56969e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 7, 0.5, 0.1, 0, 0.509902, 0.423741, 0.445781, 0.63823, 0.793147, 0.842943, 0.986523, 1.05018, 1.10383
# elapsed time for k point: 0.06745553016662598
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.256821523453596 (0.493559% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.245517038107911 (0.215276% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.2428595398752 (0.0506751% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 52.8722%)
#     iteration    4: trace = 5.241807996012487 (0.0200587% change)
#     iteration    5: trace = 5.241214464949407 (0.0113237% change)
#     iteration    6: trace = 5.241004386999872 (0.00400827% change)
#     switching back to exact line minimization
#     iteration    7: trace = 5.240908518943573 (0.00182921% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.240871722258543 (0.000702108% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.240860260412558 (0.000218701% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.240855485168549 (9.11157e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.240854378184056 (2.11222e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.240854061291608 (6.04658e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 8, 0.5, 0.2, 0, 0.538516, 0.454781, 0.457434, 0.627898, 0.805254, 0.826101, 0.927945, 1.00456, 1.10879
# elapsed time for k point: 0.0644228458404541
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.102473640114713 (0.252137% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.098134771330231 (0.0850708% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.097086988455736 (0.0205544% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.096768787188819 (0.006243% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.096616729262914 (0.00298346% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.096573230260986 (0.000853491% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.0965564550285 (0.000329148% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.096548140402659 (0.000163142% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.096545549734883 (5.08318e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.096544560373406 (1.94124e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.096544349186038 (4.14374e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 9, 0.5, 0.3, 0, 0.583095, 0.473767, 0.501279, 0.61358, 0.781467, 0.824181, 0.894949, 0.959051, 1.1107
# elapsed time for k point: 0.05998659133911133
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.010056895597106 (0.187149% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.007389031566078 (0.0532644% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.006708641237307 (0.0135886% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.006529315296095 (0.00358178% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.006460346579784 (0.00137758% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.0064435298432 (0.000335901% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.006439514151653 (8.02105e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.006437614914727 (3.79359e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.006436976453345 (1.27528e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.006436645156816 (6.61741e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 10, 0.5, 0.4, 0, 0.640312, 0.489649, 0.556045, 0.59957, 0.719611, 0.849247, 0.884337, 0.917168, 1.11162
# elapsed time for k point: 0.04334068298339844
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.978991947531677 (0.165157% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.976789314611806 (0.0442483% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.976199297510602 (0.0118561% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.976051138597764 (0.0029774% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.975999318140676 (0.0010414% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.975987205305489 (0.000243425% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.975985145977403 (4.13853e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.975984480840806 (1.33669e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.975984361316443 (2.40202e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 11, 0.5, 0.5, 0, 0.707107, 0.496836, 0.593141, 0.593154, 0.679169, 0.878684, 0.881977, 0.881982, 1.11192
# elapsed time for k point: 0.02912759780883789
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.989%)
#     iteration    1: trace = 5.042734213440628 (0.320848% change)
#     iteration    2: trace = 5.03822196664291 (0.0895202% change)
#     iteration    3: trace = 5.036944052927095 (0.0253676% change)
#     iteration    4: trace = 5.036564793043988 (0.00752985% change)
#     iteration    5: trace = 5.036423083412832 (0.00281366% change)
#     iteration    6: trace = 5.036388324290876 (0.000690157% change)
#     iteration    7: trace = 5.036381761551988 (0.000130307% change)
#     iteration    8: trace = 5.036379353830021 (4.78066e-05% change)
#     iteration    9: trace = 5.036378799626515 (1.1004e-05% change)
#     iteration   10: trace = 5.036378569047809 (4.57826e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 12, 0.4, 0.4, 0, 0.565685, 0.470987, 0.546003, 0.606732, 0.743602, 0.839223, 0.882254, 0.93697, 1.11121
# elapsed time for k point: 0.03600573539733887
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.219135858824885 (0.375871% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.211338342388775 (0.149514% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.208588769207163 (0.0527753% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.207408942859939 (0.0226541% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.206822773216354 (0.0112571% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.206658321053173 (0.00315845% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.206604946820351 (0.00102512% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.206579368051209 (0.000491277% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.206571416059294 (0.00015273% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.206567829653131 (6.88823e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.206566743886605 (2.08538e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.206566436914221 (5.89587e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.372435, 0.536186, 0.644572, 0.809689, 0.825804, 0.883642, 1.0102, 1.10725
# elapsed time for k point: 0.05393791198730469
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.468253992504001 (0.621988% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.443228314088518 (0.458704% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.431414181812943 (0.217279% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.424247372175833 (0.132038% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.419939659662342 (0.0794474% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.41854036827307 (0.0258208% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.417858691276216 (0.0125812% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.417473749154261 (0.00710531% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.417269306428964 (0.00377384% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 5.417145778814938 (0.00228028% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.417106290569913 (0.000728952% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.417094608924549 (0.000215644% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.417090468074665 (7.64404e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.417089423845839 (1.92766e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.417088993058021 (7.95239e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 14, 0.2, 0.2, 0, 0.282843, 0.252088, 0.542887, 0.698081, 0.789371, 0.888483, 0.897858, 1.07884, 1.09039
# elapsed time for k point: 0.06367230415344238
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.60008581791752 (1.22437% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.549461224359248 (0.908101% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.534348243283239 (0.272704% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.527266313330292 (0.128045% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.524126040483111 (0.0568304% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.523241485303789 (0.0160139% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.52291934419085 (0.00583263% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.522755157120697 (0.00297288% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.522648375074845 (0.00193351% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.52253995495583 (0.00196321% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.522446227922329 (0.00169719% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.522358274976686 (0.00159266% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.522300657929141 (0.00104335% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.522279600471084 (0.000381317% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.522271221037079 (0.000151739% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.522268620891823 (4.70847e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.522267958223786 (1.19999e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.52226775859822 (3.61492e-06% change)
# Finished solving for bands 1 to 8 after 18 iterations.
# tefreqs:, 15, 0.1, 0.1, 0, 0.141421, 0.126841, 0.549908, 0.750378, 0.777261, 0.903059, 0.961984, 1.04191, 1.10004
# elapsed time for k point: 0.07627749443054199
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.623403457645355 (0.879778% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.591472124104053 (0.569446% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 61.0809%)
#     iteration    3: trace = 5.58092458526113 (0.188814% change)
#     iteration    4: trace = 5.575052744796789 (0.105268% change)
#     iteration    5: trace = 5.571627491918577 (0.0614578% change)
#     iteration    6: trace = 5.570329147193887 (0.0233055% change)
#     switching back to exact line minimization
#     iteration    7: trace = 5.569685509532335 (0.0115554% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.569457465864298 (0.00409446% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.569340746946714 (0.00209572% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.569285102848536 (0.00099912% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.7535%)
#     iteration   11: trace = 5.569251740503281 (0.000599044% change)
#     iteration   12: trace = 5.569202546685839 (0.000883315% change)
#     switching back to exact line minimization
#     iteration   13: trace = 5.569127850559984 (0.00134124% change)
#     large trace change predicted (0.00879282%)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 5.568658595892979 (0.00842635% change)
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration   15: trace = 5.566312842737084 (0.0421331% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 5.565421572174485 (0.0160131% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 5.564550490913019 (0.0156529% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.563573776758572 (0.017554% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.562391975614636 (0.021244% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.560992972298158 (0.0251543% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.559493420515482 (0.0269692% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.558043388176747 (0.0260855% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 5.556775003691211 (0.0228233% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 5.555703886730864 (0.0192777% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.554793680252506 (0.0163846% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.554043221088632 (0.013511% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 5.553459402787853 (0.0105121% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 5.553015359982112 (0.00799611% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 5.552664455276122 (0.00631937% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.552365649313948 (0.00538145% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.552092074596595 (0.0049273% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.551831139782633 (0.00469987% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 5.551582502492757 (0.00447857% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 5.551352322232248 (0.0041463% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 5.55114481673616 (0.003738% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 5.550958146343981 (0.00336279% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 5.55078698877303 (0.00308344% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 5.550626954900569 (0.00288313% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.550476619404883 (0.00270848% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.550336455025691 (0.0025253% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.550206589446441 (0.00233981% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.550085906271828 (0.00217441% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.549972935591061 (0.0020355% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.549866993765409 (0.00190889% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.549768306455784 (0.00177821% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.549677269452713 (0.00164039% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.549593773949285 (0.00150452% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.54951704383326 (0.00138264% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.549445784183101 (0.00128408% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.549378501867926 (0.00121242% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.549314038113534 (0.00116165% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.549252082242668 (0.00111647% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.549193122810761 (0.00106248% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.549137688552015 (0.000998966% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.549085655691266 (0.000937679% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.54903642129003 (0.000887256% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.54898965242043 (0.000842832% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.548945611578927 (0.000793676% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 5.548904545434412 (0.000740074% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 5.548865842161239 (0.000697496% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 5.548827997784528 (0.000682022% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.548789478860163 (0.000694184% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.548749846042813 (0.000714263% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.548710233729323 (0.000713899% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.548672512731649 (0.000679818% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 5.548637959481618 (0.000622732% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 5.548606942659074 (0.000559% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 5.548579526267434 (0.000494114% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 5.548555810755752 (0.000427417% change)
#     resetting CG direction...
#     large trace change predicted (0.00363113%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 5.548354310781105 (0.00363164% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 5.548249218055657 (0.00189414% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 5.548189462835892 (0.00107702% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 5.548161428615873 (0.000505287% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 5.548149198553203 (0.000220435% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 5.548144861740389 (7.81669e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 5.548141982455459 (5.18964e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 5.548139217852907 (4.98294e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 5.548135292684105 (7.07475e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 5.548129894664455 (9.72944e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 5.548124829189203 (9.13006e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 5.548121412859118 (6.15763e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 5.548119116941167 (4.13819e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 5.5481182562759 (1.55127e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.548117900274216 (6.41662e-06% change)
# Finished solving for bands 2 to 8 after 84 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# elapsed time for k point: 0.2654726505279541
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.4968358657275991 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.44158846876525454 at Vector3<0.5, 0.0, 0.0> to 0.593140518212173 at Vector3<0.5, 0.5, 0.0>
# Band 3 range: 0.5931535893294243 at Vector3<0.5, 0.5, 0.0> to 0.7732265706612217 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.6791690135224915 at Vector3<0.5, 0.5, 0.0> to 0.8096891662210685 at Vector3<0.3, 0.3, 0.0>
# Band 5 range: 0.824181449203906 at Vector3<0.5, 0.30000000000000004, 0.0> to 0.9229965351767663 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.881977093652573 at Vector3<0.5, 0.5, 0.0> to 1.0291597260854988 at Vector3<0.5, 0.0, 0.0>
# Band 7 range: 0.8819818143091538 at Vector3<0.5, 0.5, 0.0> to 1.0860729882459754 at Vector3<0.5, 0.0, 0.0>
# Band 8 range: 1.0878691064006112 at Vector3<0.5, 0.0, 0.0> to 1.1119174049024951 at Vector3<0.5, 0.5, 0.0>
# Gap from band 2 (0.593140518212173) to band 3 (0.5931535893294243), 0.002203689147278778%
# Gap from band 4 (0.8096891662210685) to band 5 (0.824181449203906), 1.773981715078225%
# Gap from band 7 (1.0860729882459754) to band 8 (1.0878691064006112), 0.16524066202671814%
# total elapsed time for run: 1.63789701461792
# done
