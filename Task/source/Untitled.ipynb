# %%
## linear-chirped pulse planewave with higher frequencies at the front (down-chirp)
import numpy as np

import meep as mp

resolution = 40

dpml = 2
pml_layers = [mp.PML(thickness=dpml, direction=mp.X)]

sx = 40
sy = 6
cell_size = mp.Vector3(sx + 2 * dpml, sy)

v0 = 1.0  # pulse center frequency
a = 0.2  # Gaussian envelope half-width
b = -0.5  # linear chirp rate (positive: up-chirp, negative: down-chirp)
t0 = 15  # peak time

chirp = lambda t: np.exp(1j * 2 * np.pi * v0 * (t - t0)) * np.exp(
    -a * (t - t0) ** 2 + 1j * b * (t - t0) ** 2
)

sources = [
    mp.Source(
        src=mp.CustomSource(src_func=chirp),
        center=mp.Vector3(-0.5 * sx),
        size=mp.Vector3(y=sy),
        component=mp.Ez,
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    resolution=resolution,
    k_point=mp.Vector3(),
    sources=sources,
    symmetries=[mp.Mirror(mp.Y)],
)

sim.run(
    mp.in_volume(
        mp.Volume(center=mp.Vector3(), size=mp.Vector3(sx, sy)),
        mp.at_every(2.7, mp.output_efield_z),
    ),
    until=t0 + 50,
)
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000868797 s
# Working in 2D dimensions.
# Computational cell is 44 x 6 x 0 with resolution 40
# time for set_epsilon = 0.854275 s
# -----------
# creating output file "./ez-000002.70.h5"...
# creating output file "./ez-000005.40.h5"...
# creating output file "./ez-000008.10.h5"...
# creating output file "./ez-000010.80.h5"...
# creating output file "./ez-000013.50.h5"...
# creating output file "./ez-000016.20.h5"...
# creating output file "./ez-000018.90.h5"...
# creating output file "./ez-000021.60.h5"...
# creating output file "./ez-000024.30.h5"...
# Meep progress: 24.3/65.0 = 37.4% done in 5.3s, 8.9s to go
# on time step 1944 (time=24.3), 0.00273622 s/step
# creating output file "./ez-000027.00.h5"...
# creating output file "./ez-000029.70.h5"...
# creating output file "./ez-000032.40.h5"...
# creating output file "./ez-000035.10.h5"...
# creating output file "./ez-000037.80.h5"...
# creating output file "./ez-000040.50.h5"...
# creating output file "./ez-000043.20.h5"...
# creating output file "./ez-000045.90.h5"...
# creating output file "./ez-000048.60.h5"...
# creating output file "./ez-000051.30.h5"...
# creating output file "./ez-000054.00.h5"...
# creating output file "./ez-000056.70.h5"...
# creating output file "./ez-000059.40.h5"...
# creating output file "./ez-000062.10.h5"...
# creating output file "./ez-000064.80.h5"...
# run 0 finished at t = 65.0 (5200 timesteps)
